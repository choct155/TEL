# %% [markdown]
# # Social Indicators from [Censtats](http://censtats.census.gov/)

# %% [markdown]
# In building the instrument to capture baseline preferences by county, I have decided to pull a few variables from the Censtats database.  Even though it is no longer maintained, it covers the study period.  Specifically, the following variables have been pulled:
#
# + Median Age
# + Percent Bachelor's or Higher
# + Vote Cast for President - Percent Democratic
# + Persons Below Poverty Level
#
# I am embarassed to say that, for time reasons, I opted not to build the entire database or even devise a method to programmatically query the same (acquire the relevant Excel workbooks and search through the tabs).  I only needed a few variables, so I literally copied and pasted them into a new csv (gasp).
#
# Be that as it may, the Census stores this information in a somewhat bizarre fashion.  The time period of the observation is embedded as a code into the variable name.  Thus, the same concept (say, median age) observed in 1990, 2000, and 2010, is actually three separate variables.  I am not clear on why this made sense at the time, but dealing with it is the first purpose of this Notebook.
#
# The Censtats data are observed sparingly.  To preserve some "smoothness" in the annual mapping of this data, the second purpose of this Notebook is to interpolate annual values between observations.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# Out:
# /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /home/choct155/analysis/Anaconda/lib/python2.7/argparse.pyc, but /home/choct155/analysis/Anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# ## Data Input

# %% [markdown]
# There are two files to read.  The first contains descriptions of the variables, while the second contains the actual data.

# %%
#Establish working directory
workdir='/home/choct155/dissertation/TEL/CO_lit/'

#Read in descriptions
desc=pd.read_csv(workdir+'censtat_var_desc.csv')
d=pd.read_csv(workdir+'censtat_social_cov.csv')

print desc
d.head()
# Out:
#                                             var\tdesc
# 0   AGE050190D\tResident population: Median age (c...
# 1   AGE050200D\tResident population: Median age (A...
# 2   AGE050210D\tResident population: Median age (A...
# 3   EDU685190D\tEducational attainment - persons 2...
# 4   EDU685200D\tEducational attainment - persons 2...
# 5   EDU685209D\tEducational attainment - persons 2...
# 6   ELE025192D\tVote cast for president- percent D...
# 7   ELE025196D\tVote cast for president- percent D...
# 8   ELE025200D\tVote cast for president - percent ...
# 9   ELE025204D\tVote cast for president - percent ...
# 10  ELE025208D\tVote cast for president - percent ...
# 11       PVY020189D\tPersons below poverty level 1989
# 12    PVY020199D\tPopulation below poverty level 1999
# 13  PVY020209D\tPopulation below poverty level 200...
#
# [14 rows x 1 columns]
#         Areaname  STCOU  AGE050190D  AGE050200D  AGE050210D  EDU685190D  \
# 0  UNITED STATES      0        32.9        35.3        37.2        20.3
# 1        ALABAMA   1000        33.0        35.8        37.9        15.7
# 2    Autauga, AL   1001        31.7        35.1        37.0        14.5
# 3    Baldwin, AL   1003        35.5        39.0        41.1        16.8
# 4    Barbour, AL   1005        32.8        35.8        39.0        11.8
#
#    EDU685200D  EDU685209D  ELE025192D  ELE025196D  ELE025200D  ELE025204D  \
# 0        24.4        27.5        43.0        49.2        48.4        48.3
# 1        19.0        21.5        40.9        43.2        41.6        36.8
# 2        18.0        21.8        30.9        32.5        28.7        23.7
# 3        23.1        26.6        26.2        27.1        24.8        22.5
# 4        10.9        12.4        46.4        53.5        53.4        44.8
#
#    ELE025208D  PVY020189D  PVY020199D  PVY020209D
# 0        52.9    31742864    33899812    39537240
# 1        38.7      723614      698097      757833
# 2        25.8        5324        4738        5103
# 3        23.8       13947       14018       20265
# 4        49.0        6244        7032        6673
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Converting Data to Long Format

# %% [markdown]
# The following years are represented in the data set (in a `'code':year` mapping), though not all variables are observed in each year:
#
#     {'189':1989,
#      '190':1990,
#      '192':1992,
#      '196':1996,
#      '199':1999,
#      '200':2000,
#      '204':2004,
#      '209':2007,
#      '208':2008,
#      '210':2010}
#
# Note that 2007 is actually the mid-year for the data taken from the 2005-2009 [ACS](https://www.census.gov/acs/www/).  The codes are taken from the variable names, which have the following format:
#
# + Characters 0-2 = High Level Concept (e.g. Age)
# + Characters 3-5 = Low Level Concept (e.g. Median Age)
# + Characters 6-8 = Year Code
# + Character 9 = Data Identifier
#
# I think my approach will be to define a function that stacks different observations of the same measure while attaching the appropriate year identifier.

# %%
#Define code:year map
yr_map={'189':1989,
        '190':1990,
        '192':1992,
        '196':1996,
        '199':1999,
        '200':2000,
        '204':2004,
        '209':2007,
        '208':2008,
        '210':2010}

#Grab front portion of indicators
concepts=list(set([x[:6] for x in d if x not in ['Areaname','STCOU']]))

#Define function to stack data observations
def concept_stack(cncpt):
    #Create container to facilitate concatenation of observations
    var_obs=[]
    #For each instance of a concept...
    for var in [x for x in d if x.startswith(cncpt)]:
        #...define a temp DF...
        temp_df=d[['Areaname','STCOU',var]]
        #...add a year identifier...
        temp_df['year']=yr_map[var[6:9]]
        #..rename the variable to just the concept portion...
        temp_df2=temp_df.rename(columns={var:cncpt})
        #...and throw it in the list
        var_obs.append(temp_df2)
    #Concatenate temporary DFs together
    var_series=pd.concat(var_obs).set_index(['Areaname','STCOU','year'])
    return var_series

#Create container for concept specific sets
concept_data=[]

#For each concept...
for concept in concepts:
    #...throw the concept in the container
    concept_data.append(concept_stack(concept))

#Concatenate along the horizontal axis
d2=pd.concat(concept_data,axis=1).reset_index('Areaname')

d2.head(25)
# Out:
#            Areaname  EDU685  AGE050  PVY020  ELE025
# STCOU year
# 1000  1989  ALABAMA     NaN     NaN  723614     NaN
#       1990  ALABAMA    15.7    33.0     NaN     NaN
#       1992  ALABAMA     NaN     NaN     NaN    40.9
#       1996  ALABAMA     NaN     NaN     NaN    43.2
#       1999  ALABAMA     NaN     NaN  698097     NaN
#       2000  ALABAMA    19.0    35.8     NaN    41.6
#       2004  ALABAMA     NaN     NaN     NaN    36.8
#       2007  ALABAMA    21.5     NaN  757833     NaN
#       2008  ALABAMA     NaN     NaN     NaN    38.7
#       2010  ALABAMA     NaN    37.9     NaN     NaN
# 2000  1989   ALASKA     NaN     NaN   47906     NaN
#       1990   ALASKA    23.0    29.4     NaN     NaN
#       1992   ALASKA     NaN     NaN     NaN    30.3
#       1996   ALASKA     NaN     NaN     NaN    33.3
#       1999   ALASKA     NaN     NaN   57602     NaN
#       2000   ALASKA    24.7    32.4     NaN    27.7
#       2004   ALASKA     NaN     NaN     NaN    35.5
#       2007   ALASKA    26.5     NaN   64038     NaN
#       2008   ALASKA     NaN     NaN     NaN    37.9
#       2010   ALASKA     NaN    33.8     NaN     NaN
# 4000  1989  ARIZONA     NaN     NaN  564362     NaN
#       1990  ARIZONA    20.3    32.2     NaN     NaN
#       1992  ARIZONA     NaN     NaN     NaN    36.5
#       1996  ARIZONA     NaN     NaN     NaN    46.5
#       1999  ARIZONA     NaN     NaN  698669     NaN
#
# [25 rows x 5 columns]

# %% [markdown]
# ## Interpolation

# %% [markdown]
# So we are now in ok shape regarding the long format.  However, to interpolate, we need all of the years in the range to be represented.  Thus, area-wise reindexing is in order.

# %%
#Create a container for reindexed subsets
reindexed=[]

#For each area...
for code in set(d2.index.get_level_values('STCOU')):
    #...subset via the code...
    code_sub=d2.ix[code]
    #...add the code id back in...
    code_sub['STCOU']=code
    #...reindex to the 1989-2010 time period
    reindexed.append(code_sub.reindex(range(1989,2011)))

#Re-concatenate data
d3=pd.concat(reindexed).reset_index().rename(columns={'index':'year'})
    
#Fill in ID info
d3['Areaname'].fillna(method='ffill',inplace=True)
d3['STCOU'].fillna(method='ffill',inplace=True)

#Create dictionary mapping codes to area names
code_area_map=dict(zip(d3['STCOU'],d3['Areaname']))

#Drop Areaname (it's redundant at the current time)
d3.pop('Areaname')

#Set index
d3.set_index(['STCOU','year'],inplace=True)

    
d3.sortlevel(0)
# Out:
#             EDU685  AGE050    PVY020  ELE025
# STCOU year
# 0     1989     NaN     NaN  31742864     NaN
#       1990    20.3    32.9       NaN     NaN
#       1991     NaN     NaN       NaN     NaN
#       1992     NaN     NaN       NaN    43.0
#       1993     NaN     NaN       NaN     NaN
#       1994     NaN     NaN       NaN     NaN
#       1995     NaN     NaN       NaN     NaN
#       1996     NaN     NaN       NaN    49.2
#       1997     NaN     NaN       NaN     NaN
#       1998     NaN     NaN       NaN     NaN
#       1999     NaN     NaN  33899812     NaN
#       2000    24.4    35.3       NaN    48.4
#       2001     NaN     NaN       NaN     NaN
#       2002     NaN     NaN       NaN     NaN
#       2003     NaN     NaN       NaN     NaN
#       2004     NaN     NaN       NaN    48.3
#       2005     NaN     NaN       NaN     NaN
#       2006     NaN     NaN       NaN     NaN
#       2007    27.5     NaN  39537240     NaN
#       2008     NaN     NaN       NaN    52.9
#       2009     NaN     NaN       NaN     NaN
#       2010     NaN    37.2       NaN     NaN
# 1000  1989     NaN     NaN    723614     NaN
#       1990    15.7    33.0       NaN     NaN
#       1991     NaN     NaN       NaN     NaN
#       1992     NaN     NaN       NaN    40.9
#       1993     NaN     NaN       NaN     NaN
#       1994     NaN     NaN       NaN     NaN
#       1995     NaN     NaN       NaN     NaN
#       1996     NaN     NaN       NaN    43.2
#       1997     NaN     NaN       NaN     NaN
#       1998     NaN     NaN       NaN     NaN
#       1999     NaN     NaN    698097     NaN
#       2000    19.0    35.8       NaN    41.6
#       2001     NaN     NaN       NaN     NaN
#       2002     NaN     NaN       NaN     NaN
#       2003     NaN     NaN       NaN     NaN
#       2004     NaN     NaN       NaN    36.8
#       2005     NaN     NaN       NaN     NaN
#       2006     NaN     NaN       NaN     NaN
#       2007    21.5     NaN    757833     NaN
#       2008     NaN     NaN       NaN    38.7
#       2009     NaN     NaN       NaN     NaN
#       2010     NaN    37.9       NaN     NaN
# 1001  1989     NaN     NaN      5324     NaN
#       1990    14.5    31.7       NaN     NaN
#       1991     NaN     NaN       NaN     NaN
#       1992     NaN     NaN       NaN    30.9
#       1993     NaN     NaN       NaN     NaN
#       1994     NaN     NaN       NaN     NaN
#       1995     NaN     NaN       NaN     NaN
#       1996     NaN     NaN       NaN    32.5
#       1997     NaN     NaN       NaN     NaN
#       1998     NaN     NaN       NaN     NaN
#       1999     NaN     NaN      4738     NaN
#       2000    18.0    35.1       NaN    28.7
#       2001     NaN     NaN       NaN     NaN
#       2002     NaN     NaN       NaN     NaN
#       2003     NaN     NaN       NaN     NaN
#       2004     NaN     NaN       NaN    23.7
#                ...     ...       ...     ...
#
# [70356 rows x 4 columns]

# %% [markdown]
# We need to interpolate, but `interpolate()` seems to `ffill()` instead of leaving out of range values alone...
#
# Consequently, we will have to limit the time scope of the interpolation by variable.  The last year of data for each variable is as follows:
#
#     {'EDU685':2007,
#      'AGE050':2010,
#      'PVY020':2007,
#      'ELE025':2008}

# %%
#Generate variable to last data year map
var_lstyr_map={'EDU685':2007,
               'AGE050':2010,
               'PVY020':2007,
               'ELE025':2008}

#Create container for county sets
cty_dfs=[]

#For each county code...
for code in sorted(set(d3.index.get_level_values(level='STCOU'))):
    #print code
    #...generate a container for county specific series...
    cty_ser=[]
    #...and for each variable...
    for var in var_lstyr_map.keys():
        #...create an interpolated version of the related series up through the last data year...
        temp_ser=DataFrame(d3.ix[code][var].ix[:var_lstyr_map[var]].interpolate())
        #print temp_ser.head(3)
        #...and capture it...
        cty_ser.append(temp_ser)
    #...consolidate the series into one DF...   
    cty_df=pd.concat(cty_ser,axis=1)
    #...reincorporate the county code...
    cty_df['STCOU']=code
    #...and throw it in the big container of county sets
    cty_dfs.append(cty_df)

#Consolidate into one DF
cty_interp=pd.concat(cty_dfs)

cty_interp
# Out:
#          EDU685  AGE050        PVY020  ELE025  STCOU
# year
# 1989        NaN     NaN  31742864.000     NaN      0
# 1990  20.300000   32.90  31958559.000     NaN      0
# 1991  20.710000   33.14  32174254.000     NaN      0
# 1992  21.120000   33.38  32389948.000  43.000      0
# 1993  21.530000   33.62  32605643.000  44.550      0
# 1994  21.940000   33.86  32821338.000  46.100      0
# 1995  22.350000   34.10  33037033.000  47.650      0
# 1996  22.760000   34.34  33252728.000  49.200      0
# 1997  23.170000   34.58  33468422.000  49.000      0
# 1998  23.580000   34.82  33684117.000  48.800      0
# 1999  23.990000   35.06  33899812.000  48.600      0
# 2000  24.400000   35.30  34604490.000  48.400      0
# 2001  24.842857   35.49  35309169.000  48.375      0
# 2002  25.285714   35.68  36013848.000  48.350      0
# 2003  25.728571   35.87  36718526.000  48.325      0
# 2004  26.171429   36.06  37423204.000  48.300      0
# 2005  26.614286   36.25  38127883.000  49.450      0
# 2006  27.057143   36.44  38832562.000  50.600      0
# 2007  27.500000   36.63  39537240.000  51.750      0
# 2008        NaN   36.82           NaN  52.900      0
# 2009        NaN   37.01           NaN     NaN      0
# 2010        NaN   37.20           NaN     NaN      0
# 1989        NaN     NaN    723614.000     NaN   1000
# 1990  15.700000   33.00    721062.000     NaN   1000
# 1991  16.030000   33.28    718511.000     NaN   1000
# 1992  16.360000   33.56    715959.000  40.900   1000
# 1993  16.690000   33.84    713407.000  41.475   1000
# 1994  17.020000   34.12    710856.000  42.050   1000
# 1995  17.350000   34.40    708304.000  42.625   1000
# 1996  17.680000   34.68    705752.000  43.200   1000
# 1997  18.010000   34.96    703200.000  42.800   1000
# 1998  18.340000   35.24    700649.000  42.400   1000
# 1999  18.670000   35.52    698097.000  42.000   1000
# 2000  19.000000   35.80    705564.000  41.600   1000
# 2001  19.357143   36.01    713031.000  40.400   1000
# 2002  19.714286   36.22    720498.000  39.200   1000
# 2003  20.071429   36.43    727965.000  38.000   1000
# 2004  20.428571   36.64    735432.000  36.800   1000
# 2005  20.785714   36.85    742899.000  37.275   1000
# 2006  21.142857   37.06    750366.000  37.750   1000
# 2007  21.500000   37.27    757833.000  38.225   1000
# 2008        NaN   37.48           NaN  38.700   1000
# 2009        NaN   37.69           NaN     NaN   1000
# 2010        NaN   37.90           NaN     NaN   1000
# 1989        NaN     NaN      5324.000     NaN   1001
# 1990  14.500000   31.70      5265.400     NaN   1001
# 1991  14.850000   32.04      5206.800     NaN   1001
# 1992  15.200000   32.38      5148.200  30.900   1001
# 1993  15.550000   32.72      5089.600  31.300   1001
# 1994  15.900000   33.06      5031.000  31.700   1001
# 1995  16.250000   33.40      4972.400  32.100   1001
# 1996  16.600000   33.74      4913.800  32.500   1001
# 1997  16.950000   34.08      4855.200  31.550   1001
# 1998  17.300000   34.42      4796.600  30.600   1001
# 1999  17.650000   34.76      4738.000  29.650   1001
# 2000  18.000000   35.10      4783.625  28.700   1001
# 2001  18.542857   35.29      4829.250  27.450   1001
# 2002  19.085714   35.48      4874.875  26.200   1001
# 2003  19.628571   35.67      4920.500  24.950   1001
# 2004  20.171429   35.86      4966.125  23.700   1001
#             ...     ...           ...     ...    ...
#
# [70356 rows x 5 columns]

# %% [markdown]
# To deal with the missing values, we could attempt to extrapolate beyond the first and last values.  However, we have a tenuous basis for assumption regarding the gradient of the extrapolation.  A better alternative to minimize the impact of these observations would be setting them to the year specific means (thereby capturing the temporal trend while not differentiating one county from another in a given year).  However, the missing values are a function of year.
#
# Thus, to retain these observations, we must rely on the county mean across years.  This has the effect of capturing the "fixed effect" of the variable in question, a general propensity.

# %%
cty_interp2=cty_interp.fillna(cty_interp.mean())

cty_interp2
# Out:
#          EDU685     AGE050           PVY020     ELE025  STCOU       cty_temp
# year
# 1989  16.189218  37.264776  31742864.000000  40.468954      0  UNITED STATES
# 1990  20.300000  32.900000  31958559.000000  40.468954      0  UNITED STATES
# 1991  20.710000  33.140000  32174254.000000  40.468954      0  UNITED STATES
# 1992  21.120000  33.380000  32389948.000000  43.000000      0  UNITED STATES
# 1993  21.530000  33.620000  32605643.000000  44.550000      0  UNITED STATES
# 1994  21.940000  33.860000  32821338.000000  46.100000      0  UNITED STATES
# 1995  22.350000  34.100000  33037033.000000  47.650000      0  UNITED STATES
# 1996  22.760000  34.340000  33252728.000000  49.200000      0  UNITED STATES
# 1996  16.600000  33.740000      4913.800000  32.500000   1001    Autauga, AL
# 1997  16.950000  34.080000      4855.200000  31.550000   1001    Autauga, AL
# 1998  17.300000  34.420000      4796.600000  30.600000   1001    Autauga, AL
# 1999  17.650000  34.760000      4738.000000  29.650000   1001    Autauga, AL
# 2000  18.000000  35.100000      4783.625000  28.700000   1001    Autauga, AL
# 2001  18.542857  35.290000      4829.250000  27.450000   1001    Autauga, AL
# 2002  19.085714  35.480000      4874.875000  26.200000   1001    Autauga, AL
# 2003  19.628571  35.670000      4920.500000  24.950000   1001    Autauga, AL
# 2004  20.171429  35.860000      4966.125000  23.700000   1001    Autauga, AL
#             ...        ...              ...        ...    ...            ...
#
# [70356 rows x 6 columns]

# %% [markdown]
# ## Reincorporating/Fixing County Name

# %% [markdown]
# Now that we have our observations, we can regenerate the county name (which was a bit of a nuisance above).

# %%
cty_interp2['cty_temp']=cty_interp2['STCOU'].map(code_area_map)

cty_interp2.head()
# Out:
#          EDU685     AGE050    PVY020     ELE025  STCOU       cty_temp
# year
# 1989  16.189218  37.264776  31742864  40.468954      0  UNITED STATES
# 1990  20.300000  32.900000  31958559  40.468954      0  UNITED STATES
# 1991  20.710000  33.140000  32174254  40.468954      0  UNITED STATES
# 1992  21.120000  33.380000  32389948  43.000000      0  UNITED STATES
# 1993  21.530000  33.620000  32605643  44.550000      0  UNITED STATES
#
# [5 rows x 6 columns]

# %% [markdown]
# Let's subset to relevant counties (those in Colorado), and split off the county name.

# %%
#Subset to CO
co_cty=cty_interp2[cty_interp2['STCOU'].apply(lambda x: str(x).startswith('8'))]

#Create cty variable
co_cty['cty']=co_cty['cty_temp'].apply(lambda x: x.split(',')[0])

#Drop county totals
co_cty2=co_cty[co_cty['cty'] != 'COLORADO']

#Drop cty_temp
co_cty2.pop('cty_temp')

#Rename columns
co_cty2.columns=['edu_yrs','med_age','pov_pop','perc_dem','stcou','cty']

co_cty2.head(100)
# Out:
#         edu_yrs    med_age       pov_pop   perc_dem  stcou       cty
# year
# 1989  16.189218  37.264776  27267.000000  40.468954   8001     Adams
# 1990  13.000000  30.700000  27743.900000  40.468954   8001     Adams
# 1991  13.440000  30.770000  28220.800000  40.468954   8001     Adams
# 1992  13.880000  30.840000  28697.700000  44.000000   8001     Adams
# 1993  14.320000  30.910000  29174.600000  45.825000   8001     Adams
# 1994  14.760000  30.980000  29651.500000  47.650000   8001     Adams
# 1995  15.200000  31.050000  30128.400000  49.475000   8001     Adams
# 1996  15.640000  31.120000  30605.300000  51.300000   8001     Adams
# 1997  16.080000  31.190000  31082.200000  51.025000   8001     Adams
# 1998  16.520000  31.260000  31559.100000  50.750000   8001     Adams
# 1999  16.960000  31.330000  32036.000000  50.475000   8001     Adams
# 2000  17.400000  31.400000  34834.000000  50.200000   8001     Adams
# 2001  17.771429  31.500000  37632.000000  50.300000   8001     Adams
# 2002  18.142857  31.600000  40430.000000  50.400000   8001     Adams
# 2003  18.514286  31.700000  43228.000000  50.500000   8001     Adams
# 2004  18.885714  31.800000  46026.000000  50.600000   8001     Adams

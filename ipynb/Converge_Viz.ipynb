# %% [markdown]
# # Visualization of Fiscal Convergence Models

# %% [markdown]
# This Notebook is just an extension of *TEL_converge_recession* that simply seeks to visualize the results of the repeated cross-section OLS and SL models.  I am starting a new script because I already wrote the results to disk, and I don't want to deal with that large Notebook for this relatively minor task.

# %%
#Basic data manipulation
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

#Visualization
from mpltools import color

#Set print length
pd.set_option('line_width',120)

def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %% [markdown]
# The data are housed in the Google Drive Data folder.

# %%
#Establish working directory
workdir='/home/choct155/projects/gdrive_data/Google Drive/Google Drive/Dissertation/Data/'

#Read in model results
ols_res=pd.read_csv(workdir+'tcr_ols_results.csv').rename(columns={'r2':'rsq'})
slm_res=pd.read_csv(workdir+'tcr_slm_results.csv').rename(columns={'pr2':'rsq'})
fe_rev=pd.read_csv(workdir+'fe_rev_results.csv').rename(columns={'Unnamed: 0':'var',
                                                                 'beta':'est',
                                                                 'p-value':'pval'})
fe_econ=pd.read_csv(workdir+'fe_econ_results.csv').rename(columns={'Unnamed: 0':'var',
                                                                   'beta':'est',
                                                                   'p-value':'pval'})


print ols_res.head()
print slm_res.head()
print fe_rev.head()
print fe_econ.head()
# Out:
#             var            model          est          pval       rsq
# 0  cty_rev_prop         ols_econ  2878.627988  6.328202e-02  0.372988
# 1  cty_rev_prop          ols_rev  2302.838682  2.975194e-52  0.682272
# 2  cty_rev_prop     ols_w_db_b_g    -0.830914  5.391420e-03  0.278513
# 3  cty_rev_prop  ols_w_db_b_g_ap     0.652703  1.601728e-02  0.033867
# 4  cty_rev_prop     ols_w_db_b_i     2.678029  9.254931e-15  0.227346
#    Unnamed: 0           est      pval            var       rsq     model  year  st_unempr
# 0           0     46.682831  0.255709       vac_rate  0.394891  slm_econ  1995          4
# 1           1      0.000006  0.000114  r_all_gov_rev  0.394891  slm_econ  1995          4
# 2           2  -1157.524461  0.600467     prop_ratio  0.394891  slm_econ  1995          4
# 3           3 -27689.718087  0.509064    permit_rate  0.394891  slm_econ  1995          4
# 4           4  -9638.313675  0.054289    lpop_growth  0.394891  slm_econ  1995          4
#            var          est          pval     std err    t-stat       rsq
# 0          gsp     0.000511  5.888039e-03    0.000185  2.759850  0.958506
# 1  lpop_growth   -29.018449  6.006953e-01   55.424530 -0.523567  0.958506
# 2    st_unempr    17.772265  1.309965e-04    4.628782  3.839512  0.958506
# 3  permit_rate  2911.949576  8.085577e-08  538.725437  5.405257  0.958506
# 4     vac_rate     3.969369  2.701242e-02    1.792375  2.214586  0.958506
#            var          est          pval      std err     t-stat       rsq
# 0          gsp     0.024395  5.753105e-58     0.001423  17.139830  0.952825
# 1  lpop_growth  -535.619122  2.689533e-01   484.246579  -1.106088  0.952825
# 2    st_unempr   -61.949640  1.256705e-01    40.419275  -1.532676  0.952825
# 3  permit_rate -2625.838357  5.772275e-01  4709.003737  -0.557621  0.952825
# 4     vac_rate    44.087614  4.825736e-03    15.607753   2.824725  0.952825

# %%
print ols_res.to_string()
# Out:
#                  var             model           est          pval       rsq
# 0       cty_rev_prop          ols_econ  2.878628e+03  6.328202e-02  0.372988
# 1       cty_rev_prop           ols_rev  2.302839e+03  2.975194e-52  0.682272
# 2       cty_rev_prop      ols_w_db_b_g -8.309145e-01  5.391420e-03  0.278513
# 3       cty_rev_prop   ols_w_db_b_g_ap  6.527032e-01  1.601728e-02  0.033867
# 4       cty_rev_prop      ols_w_db_b_i  2.678029e+00  9.254931e-15  0.227346
# 5       cty_rev_prop   ols_w_db_b_i_ap  4.703690e-01  1.120819e-02  0.033015
# 6       cty_rev_prop      ols_w_db_c_g -4.467555e-01  1.577602e-01  0.266184
# 7       cty_rev_prop   ols_w_db_c_g_ap  9.501803e-01  2.088166e-03  0.036741
# 8       cty_rev_prop      ols_w_db_c_i  3.341497e+00  1.617543e-20  0.269451
# 9       cty_rev_prop   ols_w_db_c_i_ap  3.559999e-01  5.697355e-02  0.030820
# 10      cty_rev_prop      ols_w_kern_g  1.659849e-01  5.906890e-01  0.334756
# 11      cty_rev_prop   ols_w_kern_g_ap  4.991857e-01  1.018785e-01  0.047510
# 12      cty_rev_prop      ols_w_kern_i  3.731920e+00  6.269699e-17  0.203640
# 13      cty_rev_prop   ols_w_kern_i_ap -3.540847e+00  8.110579e-07  0.033697
# 14      cty_rev_prop     ols_w_queen_g -1.080299e+00  3.291680e-04  0.241887
# 15      cty_rev_prop  ols_w_queen_g_ap  7.983390e-01  1.816273e-03  0.075246
# 16      cty_rev_prop     ols_w_queen_i  8.440045e-01  5.312721e-03  0.204874
# 17      cty_rev_prop  ols_w_queen_i_ap  4.202619e-01  1.134064e-02  0.032189
# 18      cty_rev_prop      ols_w_rook_g -6.637729e-01  2.173678e-02  0.263564
# 19      cty_rev_prop   ols_w_rook_g_ap  1.045426e+00  1.138571e-04  0.083685
# 20      cty_rev_prop      ols_w_rook_i  1.093696e+00  7.630518e-04  0.189249
# 21      cty_rev_prop   ols_w_rook_i_ap  3.495726e-01  3.895048e-02  0.030577
# 22               gsp          ols_econ  2.819849e-02  3.246410e-10  0.372988
# 23               gsp           ols_rev -5.247031e-04  3.494424e-01  0.682272
# 24               gsp      ols_w_db_b_g -1.221648e-06  2.985986e-01  0.278513
# 25               gsp   ols_w_db_b_g_ap  2.539922e-07  8.097404e-01  0.033867
# 26               gsp      ols_w_db_b_i -6.848159e-07  6.095978e-01  0.227346
# 27               gsp   ols_w_db_b_i_ap -5.263658e-07  4.659567e-01  0.033015
# 28               gsp      ols_w_db_c_g -1.527897e-06  2.204062e-01  0.266184
# 29               gsp   ols_w_db_c_g_ap  2.031252e-07  8.656704e-01  0.036741
# 30               gsp      ols_w_db_c_i -1.097153e-06  4.288848e-01  0.269451
# 31               gsp   ols_w_db_c_i_ap -5.127381e-07  4.815755e-01  0.030820
# 32               gsp      ols_w_kern_g -1.535047e-06  2.072878e-01  0.334756
# 33               gsp   ols_w_kern_g_ap -2.005275e-08  9.865432e-01  0.047510
# 34               gsp      ols_w_kern_i -1.780826e-06  3.027567e-01  0.203640
# 35               gsp   ols_w_kern_i_ap  2.081260e-06  4.542373e-01  0.033697
# 36               gsp     ols_w_queen_g -1.117534e-06  3.445587e-01  0.241887
# 37               gsp  ols_w_queen_g_ap -1.804195e-08  9.855396e-01  0.075246
# 38               gsp     ols_w_queen_i  3.055487e-06  1.046338e-02  0.204874
# 39               gsp  ols_w_queen_i_ap -6.806042e-07  2.922364e-01  0.032189
# 40               gsp      ols_w_rook_g -1.335870e-06  2.409614e-01  0.263564
# 41               gsp   ols_w_rook_g_ap -1.688792e-07  8.724682e-01  0.083685
# 42               gsp      ols_w_rook_i  3.041995e-06  1.741139e-02  0.189249
# 43               gsp   ols_w_rook_i_ap -6.748652e-07  3.061935e-01  0.030577
# 44   intensity_stock          ols_econ  1.077703e+03  2.447028e-03  0.372988
# 45   intensity_stock           ols_rev -1.595762e+02  3.756120e-07  0.682272
# 46   intensity_stock      ols_w_db_b_g  1.066972e-01  1.028759e-01  0.278513
# 47   intensity_stock   ols_w_db_b_g_ap -1.977181e-01  8.679743e-04  0.033867
# 48   intensity_stock      ols_w_db_b_i -8.984963e-03  9.041416e-01  0.227346
# 49   intensity_stock   ols_w_db_b_i_ap  7.337884e-02  7.030602e-02  0.033015
# 50   intensity_stock      ols_w_db_c_g  1.466294e-01  3.467247e-02  0.266184
# 51   intensity_stock   ols_w_db_c_g_ap -2.169533e-01  1.322733e-03  0.036741
# 52   intensity_stock      ols_w_db_c_i  2.010061e-02  7.944422e-01  0.269451
# 53   intensity_stock   ols_w_db_c_i_ap  7.787326e-02  5.701231e-02  0.030820
# 54   intensity_stock      ols_w_kern_g -5.504641e-02  4.162114e-01  0.334756
# 55   intensity_stock   ols_w_kern_g_ap -6.054512e-02  3.642404e-01  0.047510
# 56   intensity_stock      ols_w_kern_i -5.254671e-02  5.846067e-01  0.203640
# 57   intensity_stock   ols_w_kern_i_ap -2.485343e-03  9.872917e-01  0.033697
# 58   intensity_stock     ols_w_queen_g  1.715376e-01  9.222745e-03  0.241887
# 59   intensity_stock  ols_w_queen_g_ap -9.011149e-02  1.069441e-01  0.075246
# 60   intensity_stock     ols_w_queen_i  8.785924e-02  1.852183e-01  0.204874
# 61   intensity_stock  ols_w_queen_i_ap  2.398068e-02  5.083295e-01  0.032189
# 62   intensity_stock      ols_w_rook_g  1.759164e-01  5.591680e-03  0.263564
# 63   intensity_stock   ols_w_rook_g_ap -1.035710e-01  7.960638e-02  0.083685
# 64   intensity_stock      ols_w_rook_i  3.239381e-02  6.485348e-01  0.189249
# 65   intensity_stock   ols_w_rook_i_ap  2.718014e-02  4.626398e-01  0.030577
# 66       lpop_growth          ols_econ -1.465286e+03  3.881418e-01  0.372988
# 67       lpop_growth           ols_rev  5.179315e+01  7.535720e-01  0.682272
# 68       lpop_growth      ols_w_db_b_g  9.025974e-03  9.791729e-01  0.278513
# 69       lpop_growth   ols_w_db_b_g_ap  4.846161e-02  8.774732e-01  0.033867
# 70       lpop_growth      ols_w_db_b_i  3.320796e-02  9.329326e-01  0.227346
# 71       lpop_growth   ols_w_db_b_i_ap -1.737391e-02  9.356200e-01  0.033015
# 72       lpop_growth      ols_w_db_c_g -8.076967e-04  9.982428e-01  0.266184
# 73       lpop_growth   ols_w_db_c_g_ap  3.802556e-02  9.153597e-01  0.036741
# 74       lpop_growth      ols_w_db_c_i  3.119945e-02  9.390512e-01  0.269451
# 75       lpop_growth   ols_w_db_c_i_ap -1.152483e-02  9.576548e-01  0.030820
# 76       lpop_growth      ols_w_kern_g  1.121356e-01  7.541437e-01  0.334756
# 77       lpop_growth   ols_w_kern_g_ap -9.601089e-02  7.863751e-01  0.047510
# 78       lpop_growth      ols_w_kern_i -1.387257e-02  9.782292e-01  0.203640
# 79       lpop_growth   ols_w_kern_i_ap -9.060507e-03  9.912747e-01  0.033697
# 80       lpop_growth     ols_w_queen_g -1.527474e-01  6.605762e-01  0.241887
# 81       lpop_growth  ols_w_queen_g_ap  2.376289e-02  9.361446e-01  0.075246
# 82       lpop_growth     ols_w_queen_i -7.069052e-02  8.402046e-01  0.204874
# 83       lpop_growth  ols_w_queen_i_ap -2.482998e-02  8.973620e-01  0.032189
# 84       lpop_growth      ols_w_rook_g -1.593962e-01  6.343478e-01  0.263564
# 85       lpop_growth   ols_w_rook_g_ap  9.412016e-03  9.760467e-01  0.083685
# 86       lpop_growth      ols_w_rook_i -1.147279e-01  7.601994e-01  0.189249
# 87       lpop_growth   ols_w_rook_i_ap -2.181404e-02  9.115890e-01  0.030577
# 88              pcap           ols_rev  4.121562e-02  5.245640e-46  0.682272
# 89              pcap      ols_w_db_b_g  4.409348e-05  3.971521e-14  0.278513
# 90              pcap      ols_w_db_b_i -4.100901e-05  5.890413e-10  0.227346
# 91              pcap      ols_w_db_c_g  4.545539e-05  1.905769e-13  0.266184
# 92              pcap      ols_w_db_c_i -4.893006e-05  1.058629e-12  0.269451
# 93              pcap      ols_w_kern_g  4.016319e-05  2.492197e-11  0.334756
# 94              pcap      ols_w_kern_i -3.426157e-05  5.342459e-05  0.203640
# 95              pcap     ols_w_queen_g  3.056884e-05  1.501076e-07  0.241887
# 96              pcap     ols_w_queen_i -6.799004e-05  1.583957e-29  0.204874
# 97              pcap      ols_w_rook_g  2.658735e-05  2.053822e-06  0.263564
# 98              pcap      ols_w_rook_i -6.739171e-05  1.054312e-25  0.189249
# 99       permit_rate          ols_econ  3.544505e+04  1.155154e-03  0.372988
# 100      permit_rate           ols_rev -6.851308e+03  3.443773e-10  0.682272
# 101      permit_rate      ols_w_db_b_g  3.136407e+00  1.660594e-01  0.278513
# 102      permit_rate   ols_w_db_b_g_ap  2.529050e-01  9.016213e-01  0.033867
# 103      permit_rate      ols_w_db_b_i -3.597061e-01  8.892576e-01  0.227346
# 104      permit_rate   ols_w_db_b_i_ap -1.214913e+00  3.855898e-01  0.033015
# 105      permit_rate      ols_w_db_c_g  2.645647e+00  2.706418e-01  0.266184
# 106      permit_rate   ols_w_db_c_g_ap  3.951643e-01  8.652557e-01  0.036741
# 107      permit_rate      ols_w_db_c_i -2.425182e+00  3.640410e-01  0.269451
# 108      permit_rate   ols_w_db_c_i_ap -1.225760e+00  3.856901e-01  0.030820
# 109      permit_rate      ols_w_kern_g  1.232797e+00  5.989527e-01  0.334756
# 110      permit_rate   ols_w_kern_g_ap  9.541938e-01  6.790112e-01  0.047510
# 111      permit_rate      ols_w_kern_i -6.777165e+00  4.193376e-02  0.203640
# 112      permit_rate   ols_w_kern_i_ap  5.119464e+00  3.425688e-01  0.033697
# 113      permit_rate     ols_w_queen_g -3.551905e+00  1.190377e-01  0.241887
# 114      permit_rate  ols_w_queen_g_ap  3.530454e+00  6.768260e-02  0.075246
# 115      permit_rate     ols_w_queen_i  6.546547e+00  4.424293e-03  0.204874
# 116      permit_rate  ols_w_queen_i_ap -1.863366e+00  1.371721e-01  0.032189
# 117      permit_rate      ols_w_rook_g -3.221627e+00  1.422028e-01  0.263564
# 118      permit_rate   ols_w_rook_g_ap  2.959414e+00  1.471512e-01  0.083685
# 119      permit_rate      ols_w_rook_i  5.187026e+00  3.525118e-02  0.189249
# 120      permit_rate   ols_w_rook_i_ap -1.760096e+00  1.689005e-01  0.030577
# 121       prop_ratio          ols_econ  2.570238e+03  4.302527e-08  0.372988
# 122       prop_ratio           ols_rev -4.830888e+02  1.635463e-27  0.682272
# 123       prop_ratio      ols_w_db_b_g -5.003155e-01  3.813594e-08  0.278513
# 124       prop_ratio   ols_w_db_b_g_ap -3.683798e-03  9.637195e-01  0.033867
# 125       prop_ratio      ols_w_db_b_i  3.901074e-01  1.612398e-04  0.227346
# 126       prop_ratio   ols_w_db_b_i_ap  3.100819e-02  5.758208e-01  0.033015
# 127       prop_ratio      ols_w_db_c_g -5.080030e-01  1.382294e-07  0.266184
# 128       prop_ratio   ols_w_db_c_g_ap -2.343555e-02  7.993207e-01  0.036741
# 129       prop_ratio      ols_w_db_c_i  4.753929e-01  8.992411e-06  0.269451
# 130       prop_ratio   ols_w_db_c_i_ap  3.793291e-02  4.976324e-01  0.030820
# 131       prop_ratio      ols_w_kern_g -5.538597e-01  4.305196e-09  0.334756
# 132       prop_ratio   ols_w_kern_g_ap  3.946489e-03  9.655111e-01  0.047510
# 133       prop_ratio      ols_w_kern_i  4.029702e-01  2.450306e-03  0.203640
# 134       prop_ratio   ols_w_kern_i_ap -1.563180e-01  4.640605e-01  0.033697
# 135       prop_ratio     ols_w_queen_g -5.278274e-01  8.298182e-09  0.241887
# 136       prop_ratio  ols_w_queen_g_ap -2.213371e-02  7.721006e-01  0.075246
# 137       prop_ratio     ols_w_queen_i  5.938009e-01  1.382052e-10  0.204874
# 138       prop_ratio  ols_w_queen_i_ap  1.763412e-02  7.221723e-01  0.032189
# 139       prop_ratio      ols_w_rook_g -5.349073e-01  1.399251e-09  0.263564
# 140       prop_ratio   ols_w_rook_g_ap -4.229246e-02  6.005456e-01  0.083685
# 141       prop_ratio      ols_w_rook_i  5.339315e-01  6.669837e-08  0.189249
# 142       prop_ratio   ols_w_rook_i_ap  2.087374e-02  6.800752e-01  0.030577
# 143    r_all_gov_rev          ols_econ  5.516009e-06  5.435956e-60  0.372988
# 144    r_all_gov_rev           ols_rev -8.618671e-10  9.787153e-01  0.682272
# 145    r_all_gov_rev      ols_w_db_b_g -2.323077e-10  6.245138e-04  0.278513
# 146    r_all_gov_rev   ols_w_db_b_g_ap -1.246274e-10  2.216912e-02  0.033867
# 147    r_all_gov_rev      ols_w_db_b_i  3.806521e-10  9.823887e-07  0.227346
# 148    r_all_gov_rev   ols_w_db_b_i_ap  7.317432e-11  4.958885e-02  0.033015
# 149    r_all_gov_rev      ols_w_db_c_g -2.566933e-10  3.673806e-04  0.266184
# 150    r_all_gov_rev   ols_w_db_c_g_ap -1.367120e-10  2.747317e-02  0.036741
# 151    r_all_gov_rev      ols_w_db_c_i  4.544755e-10  1.698263e-08  0.269451
# 152    r_all_gov_rev   ols_w_db_c_i_ap  7.513831e-11  4.573221e-02  0.030820
# 153    r_all_gov_rev      ols_w_kern_g -3.234334e-10  4.485336e-06  0.334756
# 154    r_all_gov_rev   ols_w_kern_g_ap -1.836081e-10  2.814308e-03  0.047510
# 155    r_all_gov_rev      ols_w_kern_i  4.176127e-10  2.967696e-05  0.203640
# 156    r_all_gov_rev   ols_w_kern_i_ap -1.564567e-10  2.754311e-01  0.033697
# 157    r_all_gov_rev     ols_w_queen_g -4.724626e-10  7.356623e-12  0.241887
# 158    r_all_gov_rev  ols_w_queen_g_ap -8.698265e-11  9.045734e-02  0.075246
# 159    r_all_gov_rev     ols_w_queen_i  9.577041e-11  1.632116e-01  0.204874
# 160    r_all_gov_rev  ols_w_queen_i_ap  5.920178e-11  7.583112e-02  0.032189
# 161    r_all_gov_rev      ols_w_rook_g -4.181619e-10  2.874881e-10  0.263564
# 162    r_all_gov_rev   ols_w_rook_g_ap -7.439919e-11  1.705211e-01  0.083685
# 163    r_all_gov_rev      ols_w_rook_i  1.081741e-10  1.418617e-01  0.189249
# 164    r_all_gov_rev   ols_w_rook_i_ap  5.835259e-11  8.641094e-02  0.030577
# 165        st_unempr          ols_econ  2.019952e+01  8.844978e-01  0.372988
# 166        st_unempr           ols_rev  1.286955e+01  3.299761e-01  0.682272
# 167        st_unempr      ols_w_db_b_g -5.659832e-03  8.379808e-01  0.278513
# 168        st_unempr   ols_w_db_b_g_ap  5.588833e-03  8.243360e-01  0.033867
# 169        st_unempr      ols_w_db_b_i -4.090576e-03  8.969722e-01  0.227346
# 170        st_unempr   ols_w_db_b_i_ap -4.708492e-03  7.846284e-01  0.033015
# 171        st_unempr      ols_w_db_c_g -8.240553e-03  7.789676e-01  0.266184
# 172        st_unempr   ols_w_db_c_g_ap  4.138937e-03  8.851670e-01  0.036741
# 173        st_unempr      ols_w_db_c_i -9.329036e-03  7.751984e-01  0.269451
# 174        st_unempr   ols_w_db_c_i_ap -4.596769e-03  7.914786e-01  0.030820
# 175        st_unempr      ols_w_kern_g -3.044447e-03  9.154147e-01  0.334756
# 176        st_unempr   ols_w_kern_g_ap -5.365655e-03  8.500193e-01  0.047510
# 177        st_unempr      ols_w_kern_i -1.187566e-02  7.704422e-01  0.203640
# 178        st_unempr   ols_w_kern_i_ap  1.283540e-02  8.466414e-01  0.033697
# 179        st_unempr     ols_w_queen_g -1.312842e-02  6.373336e-01  0.241887
# 180        st_unempr  ols_w_queen_g_ap -2.313670e-03  9.224207e-01  0.075246
# 181        st_unempr     ols_w_queen_i  4.062621e-03  8.849112e-01  0.204874
# 182        st_unempr  ols_w_queen_i_ap -5.641707e-03  7.144411e-01  0.032189
# 183        st_unempr      ols_w_rook_g -1.533451e-02  5.676412e-01  0.263564
# 184        st_unempr   ols_w_rook_g_ap -3.280730e-03  8.960437e-01  0.083685
# 185        st_unempr      ols_w_rook_i  1.893875e-03  9.498168e-01  0.189249
# 186        st_unempr   ols_w_rook_i_ap -5.722126e-03  7.161507e-01  0.030577
# 187         vac_rate          ols_econ  3.558819e+01  2.101546e-03  0.372988
# 188         vac_rate           ols_rev  2.401607e+01  3.780369e-88  0.682272
# 189         vac_rate      ols_w_db_b_g  3.199591e-02  3.642848e-41  0.278513
# 190         vac_rate   ols_w_db_b_g_ap  8.860014e-04  6.665014e-01  0.033867
# 191         vac_rate      ols_w_db_b_i  2.179640e-02  1.355567e-16  0.227346
# 192         vac_rate   ols_w_db_b_i_ap -5.649664e-03  6.356745e-05  0.033015
# 193         vac_rate      ols_w_db_c_g  3.124564e-02  1.276201e-35  0.266184
# 194         vac_rate   ols_w_db_c_g_ap -5.241368e-05  9.821297e-01  0.036741
# 195         vac_rate      ols_w_db_c_i  2.349755e-02  7.487453e-18  0.269451
# 196         vac_rate   ols_w_db_c_i_ap -5.217119e-03  2.502148e-04  0.030820
# 197         vac_rate      ols_w_kern_g  3.456671e-02  2.613520e-44  0.334756
# 198         vac_rate   ols_w_kern_g_ap  6.893664e-03  2.993059e-03  0.047510
# 199         vac_rate      ols_w_kern_i  2.415247e-02  8.986958e-13  0.203640
# 200         vac_rate   ols_w_kern_i_ap  2.167792e-02  6.784852e-05  0.033697
# 201         vac_rate     ols_w_queen_g  2.397133e-02  1.669749e-24  0.241887
# 202         vac_rate  ols_w_queen_g_ap  7.955659e-03  4.445483e-05  0.075246
# 203         vac_rate     ols_w_queen_i  1.024073e-02  9.424178e-06  0.204874
# 204         vac_rate  ols_w_queen_i_ap -5.197450e-03  3.956322e-05  0.032189
# 205         vac_rate      ols_w_rook_g  2.497748e-02  3.827352e-28  0.263564
# 206         vac_rate   ols_w_rook_g_ap  8.508680e-03  3.604258e-05  0.083685
# 207         vac_rate      ols_w_rook_i  1.212419e-02  1.027377e-06  0.189249
# 208         vac_rate   ols_w_rook_i_ap -5.160894e-03  6.347105e-05  0.030577

# %% [markdown]
# We need to define a few things:
#
# + The color maps we will use.  If a variable contains a p-value below the threshold in any given year, it will be colored with a diverging color scale.  If it does not, the color scheme will be monochromatic.
# + To set a color break point at a given p-value, we need to calculate the percentile value associated with said break point (aka - threshold) for each vector of variable-specific p-values.
# + We need general functions that will produce our plots in a consistent manner.  One will parse the data by model, and one by year.

# %%
set(ols_res['var'])
# Out:
# {'cty_rev_prop',
#  'gsp',
#  'intensity_stock',
#  'lpop_growth',
#  'pcap',
#  'permit_rate',
#  'prop_ratio',
#  'r_all_gov_rev',
#  'st_unempr',
#  'vac_rate'}

# %%
#Create color mapping with mpltools
bcr_rgba = [(0.02, 0.2, 0.4, 1),    # grayish blue, opaque
            (0.02, 0.2, 0.4, 0.3),  # grayish blue, transparent
            (0.4,  0.0, 0.1, 0.3),  # dark red, transparent
            (0.4,  0.0, 0.1, 1)]    # dark red, opaque
red_rgba= [(0.4,  0.0, 0.1, 0.3),  # dark red, transparent
           (0.4,  0.0, 0.1, 1)]    # dark red, opaque

#Define percentile position calculator
def perc_calc(seq,thresh):
    if thresh < seq.min():
        return 0
    elif thresh > seq.max():
        return 1
    else:
        perc=(thresh - seq.min())/(seq.max() - seq.min())
        return perc

#Create plotting object
fig,ax=plt.subplots(figsize=(18,4))
    
#Define function to plot coefficient estimates by model
def coef_mod(df_in,model,p,fig=fig,ax=ax):
    '''Function isolates a model and plots variable impacts on the model dependent.  
    The estimates are colored by p-value and sized by R-squared.'''
    #Subset to variable of interest
    df=df_in[df_in['model']==model].reset_index()
    #Identify percentile of the desired p-value
    thresh=perc_calc(df['pval'].values,p)
    #If the desired p-value is in the set...
    if thresh>0:
        #...create a diverging color scale that splits at the p-value...
        blue_clear_red = color.LinearColormap('blue_clear_red', bcr_rgba,
                                          index=[0, thresh, thresh, 1])
        #...and plot
        plot=ax.scatter(df.index,df['est'],c=df['pval'],cmap=blue_clear_red,s=5000*df['rsq'],alpha=.4)
    else:
        #...otherwise create a monochromatic scale...
        reds=color.LinearColormap('blue_clear_red', red_rgba,
                                          index=[0, 1])
        #...and plot
        plot=ax.scatter(df.index,df['est'],c=df['pval'],cmap=reds,s=5000*df['rsq'],alpha=.4)
    #Set title for plot
    ax.set_title(model+' (R^2 = '+str('{0:.4f}'.format(df['rsq'][0]))+')',fontsize=18)
    #Set x-axis scope
    ax.set_xlim(-.5,len(df['var'])+.5)
    #Set xticks
    ax.set_xticks(range(len(df)))
#     fig.subplots_adjust(hspace=10)
    #Set xtick labels
    ax.set_xticklabels(list(df['var']),rotation=40)
    #Generate an axis-specific colorbar
    fig.colorbar(plot,ax=ax,shrink=.9)
    #Adjust padding
    plt.tight_layout()
    
coef_mod(ols_res,'ols_rev',0.1,ax=ax)

# %%
#Create plotting object
fig,ax=plt.subplots(figsize=(18,2))

def coef_yr(var,p,df_in,fig=fig,ax=ax):
    '''Function isolates a variable and plots its estimated impact on intensity_stock for each annual
    cross-section.  The estimates are colored by p-value and sized by R-squared.'''
    #Subset to variable of interest
    df=df_in[df_in['var']==var].reset_index()
    #Identify percentile of the desired p-value
    thresh=perc_calc(df['pval'].values,p)
    #If the desired p-value is in the set...
    if thresh>0:
        #...create a diverging color scale that splits at the p-value...
        blue_clear_red = color.LinearColormap('blue_clear_red', bcr_rgba,
                                          index=[0, thresh, thresh, 1])
        #...and plot
        plot=ax.scatter(df['year'],df['est'],c=df['pval'],cmap=blue_clear_red,s=5000*df['rsq'])
    else:
        #...otherwise create a monochromatic scale...
        reds=color.LinearColormap('blue_clear_red', red_rgba,
                                          index=[0, 1])
        #...and plot
        plot=ax.scatter(df['year'],df['est'],c=df['pval'],cmap=reds,s=5000*df['rsq'])
    #Set title for plot
    ax.set_title(var,fontsize=18)
    #Set x-axis scope
    ax.set_xlim([df['year'].min()-.5,df['year'].max()+.5])
    #Generate an axis-specific colorbar
    fig.colorbar(plot,ax=ax,shrink=.9)
    
coef_yr('intensity_stock',.1,slm_res[slm_res['model']=='slm_econ'])

# %% [markdown]
# Capture spatial and non-spatial OLS models.

# %%
spat_ols=list(set([mod for mod in ols_res['model'] if mod.startswith('ols_w')]))
non_spat_ols=list(set([mod for mod in ols_res['model'] if mod not in spat_ols]))
print spat_ols
print non_spat_ols
# Out:
# ['ols_w_kern_i', 'ols_w_db_b_i_ap', 'ols_w_db_b_i', 'ols_w_rook_i', 'ols_w_rook_g', 'ols_w_db_c_g_ap', 'ols_w_db_b_g_ap', 'ols_w_db_c_i', 'ols_w_db_c_i_ap', 'ols_w_queen_g', 'ols_w_db_c_g', 'ols_w_queen_g_ap', 'ols_w_kern_g_ap', 'ols_w_rook_g_ap', 'ols_w_queen_i_ap', 'ols_w_kern_i_ap', 'ols_w_kern_g', 'ols_w_queen_i', 'ols_w_db_b_g', 'ols_w_rook_i_ap']
# ['ols_rev', 'ols_econ']

# %% [markdown]
# Plot model results.

# %%
#Create plotting object
fig,ax=plt.subplots(2,figsize=(10,10))

#Create R-squared dict
nonspat_rsq_dict=dict(zip(ols_res[ols_res['model'].isin(non_spat_ols)]['model'],ols_res[ols_res['model'].isin(non_spat_ols)]['rsq']))

#Create title dict
nonspat_title_dict={'ols_econ':'Per Capita Annual Payroll',
                    'ols_rev':'Per Capita Revenue'}

#For each variable...
for i,mod in enumerate(non_spat_ols):
    #...plot the coefficient estimates in a subplot...
    coef_mod(ols_res,mod,0.1,ax=ax[i])
    #...and set titles
    ax[i].set_title(nonspat_title_dict[mod]+r'  ($R^2$='+'{0:.3f}'.format(nonspat_rsq_dict[mod])+')',fontsize=16)
    simpleaxis(ax[i])
    
plt.savefig('../out/figures/converge_pooled_ols.png')

# %%
#Build lists for summary descriptions
non_spat_ols=['ols_econ','ols_rev']
mi_rev=['ols_w_db_b_i','ols_w_db_c_i','ols_w_kern_i','ols_w_queen_i','ols_w_rook_i']
mi_econ=['ols_w_db_b_i_ap','ols_w_db_c_i_ap','ols_w_kern_i_ap','ols_w_queen_i_ap','ols_w_rook_i_ap']
go_rev=['ols_w_db_b_g','ols_w_db_c_g','ols_w_kern_g','ols_w_queen_g','ols_w_rook_g']
go_econ=['ols_w_db_b_g_ap','ols_w_db_c_g_ap','ols_w_kern_g_ap','ols_w_queen_g_ap','ols_w_rook_g_ap']

#Create sub-DFs by model summary group
ns_ols=ols_res[ols_res['model'].isin(non_spat_ols)]
mi_rev_ols=ols_res[ols_res['model'].isin(mi_rev)]
mi_econ_ols=ols_res[ols_res['model'].isin(mi_econ)]
go_rev_ols=ols_res[ols_res['model'].isin(go_rev)]
go_econ_ols=ols_res[ols_res['model'].isin(go_econ)]

#Create spatial model group names list
summary_names=['mi_rev','mi_econ','go_rev','go_econ']

#Create container for spatial model summaries
spat_summary=[]

#For each model group...
for i,mod_group in enumerate([mi_rev_ols,mi_econ_ols,go_rev_ols,go_econ_ols]):
    #...create a summary file with average estimates and p-values, as well as estimate coefficient of variation...
    summ_df=mod_group.groupby('var').mean().join(\
            DataFrame(abs(mod_group.groupby('var').std()['est']/mod_group.groupby('var').mean()['est'])).rename(columns={'est':'CoV'}))
    #...add a label for the model group...
    summ_df['model']=summary_names[i]
    #...and throw it in the list
    spat_summary.append(summ_df)
    
#Concatenate into one DF
spat_summ_df=pd.concat(spat_summary)

#Create R-squared dict
spat_rsq_dict=dict(zip(spat_summ_df['model'],spat_summ_df['rsq']))

#Create title dict
spat_title_dict={'mi_rev':'Local Moran\'s I - Per Capita Revenue',
                 'mi_econ':'Local Moran\'s I - Per Capita Annual Payroll',
                 'go_rev':'Getis & Ord\'s G* - Per Capita Revenue',
                 'go_econ':'Getis & Ord\'s G* - Per Capita Annual Payroll'}

#Create plotting object
fig,ax=plt.subplots(2,2,figsize=(13,10))

#For each variable...
for i,mod in enumerate(summary_names):
    #...plot the coefficient estimates in a subplot...
    coef_mod(spat_summ_df,mod,0.1,ax=ax[i//2,i%2])
    #...and set titles
    ax[i//2,i%2].set_title(spat_title_dict[mod]+r'  ($R^2$='+'{0:.3f}'.format(spat_rsq_dict[mod])+')',fontsize=16)
    simpleaxis(ax[i//2,i%2])
    
plt.savefig('../out/figures/converge_LISAs.png')

# %%
#Create plotting object
fig,ax=plt.subplots(4,2,figsize=(15,15))

def coef_yr(var,p,df_in,fig=fig,ax=ax):
    '''Function isolates a variable and plots its estimated impact on intensity_stock for each annual
    cross-section.  The estimates are colored by p-value and sized by R-squared.'''
    #Subset to variable of interest
    df=df_in[df_in['var']==var].reset_index()
    #Identify percentile of the desired p-value
    thresh=perc_calc(df['pval'].values,p)
    #If the desired p-value is in the set...
    if thresh>0:
        #...create a diverging color scale that splits at the p-value...
        blue_clear_red = color.LinearColormap('blue_clear_red', bcr_rgba,
                                          index=[0, thresh, thresh, 1])
        #...and plot
        plot=ax.scatter(df['year'],df['est'],c=df['pval'],cmap=blue_clear_red,s=5000*df['rsq'])
    else:
        #...otherwise create a monochromatic scale...
        reds=color.LinearColormap('blue_clear_red', red_rgba,
                                          index=[0, 1])
        #...and plot
        plot=ax.scatter(df['year'],df['est'],c=df['pval'],cmap=reds,s=5000*df['rsq'])
    #Set title for plot
    ax.set_title(var,fontsize=18)
    #Set x-axis scope
    ax.set_xlim([df['year'].min()-.5,df['year'].max()+.5])
    #Generate an axis-specific colorbar
    fig.colorbar(plot,ax=ax,shrink=.9)
    
#Capture average R-squared
econ_rsq=slm_res[slm_res['model']=='slm_econ']['rsq'].mean()
    
#Set super title 
plt.suptitle('Spatial Lag Models by Year - Per Capita Annual Payroll'+r'  (Average $R^2$='+'{0:.3f}'.format(econ_rsq)+')',\
             fontsize=22)

for i,var in enumerate(sorted(set(slm_res[slm_res['model']=='slm_econ']['var']))):
    print var
    coef_yr(var,.1,slm_res[slm_res['model']=='slm_econ'],ax=ax[i//2,i%2])
    simpleaxis(ax[i//2,i%2])

#Get rid of unused subplot
fig.delaxes(ax[3,1])

#Increase vertical space between subplots
fig.subplots_adjust(hspace=.2)
plt.savefig('../out/figures/converge_slm_econ.png')
# Out:
# cty_rev_prop
# intensity_stock
# lpop_growth
# permit_rate
# prop_ratio
# r_all_gov_rev
# vac_rate

# %%
#Create plotting object
fig,ax=plt.subplots(4,2,figsize=(15,15))

#Capture average R-square
rev_rsq=slm_res[slm_res['model']=='slm_rev']['rsq'].mean()
    
#Set super title 
plt.suptitle('Spatial Lag Models by Year - Per Capita Revenue'+r'  (Average $R^2$='+'{0:.3f}'.format(rev_rsq)+')',\
             fontsize=22)
for i,var in enumerate(sorted(set(slm_res[slm_res['model']=='slm_rev']['var']))):
    coef_yr(var,.1,slm_res[slm_res['model']=='slm_rev'],ax=ax[i//2,i%2])
    simpleaxis(ax[i//2,i%2])
    
plt.savefig('../out/figures/converge_slm_rev.png')

# %% [markdown]
# To visualize the fixed effect models, it would be easiest to deal with existing infrastructure.  Consequently, we will subset to the parameters of interest, add a model variable, and concatenate so that we can use `coef_mod()`.

# %%
#Create model variables
fe_rev['model']='rev'
fe_econ['model']='econ'

#Throw subsets in a list
fe_results=[fe_rev[fe_rev['var'].isin([x for x in fe_rev['var'] if not x.startswith('FE')])],
            fe_econ[fe_econ['var'].isin([x for x in fe_econ['var'] if not x.startswith('FE')])]]

#Concatenate fixed effect results
fe_res=pd.concat(fe_results)

fe_res
# Out:
#                 var          est           pval       std err     t-stat       rsq model
# 0               gsp     0.000511   5.888039e-03  1.850742e-04   2.759850  0.958506   rev
# 1       lpop_growth   -29.018449   6.006953e-01  5.542453e+01  -0.523567  0.958506   rev
# 2         st_unempr    17.772265   1.309965e-04  4.628782e+00   3.839512  0.958506   rev
# 3       permit_rate  2911.949576   8.085577e-08  5.387254e+02   5.405257  0.958506   rev
# 4          vac_rate     3.969369   2.701242e-02  1.792375e+00   2.214586  0.958506   rev
# 5              pcap     0.033015   3.096910e-19  3.608180e-03   9.150020  0.958506   rev
# 6   intensity_stock   -41.543095   4.144617e-03  1.445714e+01  -2.873535  0.958506   rev
# 7        prop_ratio   -16.785470   7.537301e-01  5.348918e+01  -0.313811  0.958506   rev
# 8      cty_rev_prop  2973.785947  1.055576e-128  1.057990e+02  28.107887  0.958506   rev
# 9     r_all_gov_rev    -0.000000   1.046428e-02  7.061227e-08  -2.564922  0.958506   rev
# 73        intercept  -290.444350   9.720106e-03  1.121152e+02  -2.590588  0.958506   rev
# 0               gsp     0.024395   5.753105e-58  1.423282e-03  17.139830  0.952825  econ
# 1       lpop_growth  -535.619122   2.689533e-01  4.842466e+02  -1.106088  0.952825  econ
# 2         st_unempr   -61.949640   1.256705e-01  4.041927e+01  -1.532676  0.952825  econ
# 3       permit_rate -2625.838357   5.772275e-01  4.709004e+03  -0.557621  0.952825  econ
# 4          vac_rate    44.087614   4.825736e-03  1.560775e+01   2.824725  0.952825  econ
# 5   intensity_stock   604.101300   1.539891e-06  1.249447e+02   4.834948  0.952825  econ
# 6        prop_ratio   -74.557794   8.733524e-01  4.676158e+02  -0.159442  0.952825  econ
# 7      cty_rev_prop  4222.329233   4.479283e-06  9.152931e+02   4.613090  0.952825  econ
# 8     r_all_gov_rev     0.000007   1.522204e-27  5.820290e-07  11.205474  0.952825  econ
# 72        intercept -2698.369324   5.823853e-03  9.764490e+02  -2.763451  0.952825  econ

# %%
#Create plot objects
fig,ax=plt.subplots(2,figsize=(10,10))

#Plot FE results by dependent
coef_mod(fe_res,'rev',0.1,ax=ax[0])
coef_mod(fe_res,'econ',0.1,ax=ax[1])

#Set plot titles
ax[0].set_title('Fixed Effects - Per Capita Revenue '+\
                '($R^2$='+'{0:.3f}'.format(fe_res[fe_res['model']=='rev']['rsq'].mean())+')',
                fontsize=16)
simpleaxis(ax[0])
ax[1].set_title('Fixed Effects - Per Capita Annual Payroll '+\
                '($R^2$='+'{0:.3f}'.format(fe_res[fe_res['model']=='econ']['rsq'].mean())+')',
                fontsize=16)
simpleaxis(ax[1])

plt.savefig('../out/figures/converge_fe_panel.png')

# %% [markdown]
# ## Spot Checks

# %%
ols_res2=ols_res.set_index(['model','var']).sortlevel(0)

ols_res2
# Out:
#                                           est          pval       rsq
# model           var
# ols_econ        cty_rev_prop     2.878628e+03  6.328202e-02  0.372988
#                 gsp              2.819849e-02  3.246410e-10  0.372988
#                 intensity_stock  1.077703e+03  2.447028e-03  0.372988
#                 lpop_growth     -1.465286e+03  3.881418e-01  0.372988
#                 permit_rate      3.544505e+04  1.155154e-03  0.372988
#                 prop_ratio       2.570238e+03  4.302527e-08  0.372988
#                 r_all_gov_rev    5.516009e-06  5.435956e-60  0.372988
#                 st_unempr        2.019952e+01  8.844978e-01  0.372988
#                 vac_rate         3.558819e+01  2.101546e-03  0.372988
# ols_rev         cty_rev_prop     2.302839e+03  2.975194e-52  0.682272
#                 gsp             -5.247031e-04  3.494424e-01  0.682272
#                 intensity_stock -1.595762e+02  3.756120e-07  0.682272
#                 lpop_growth      5.179315e+01  7.535720e-01  0.682272
#                 pcap             4.121562e-02  5.245640e-46  0.682272
#                 permit_rate     -6.851308e+03  3.443773e-10  0.682272
#                 prop_ratio      -4.830888e+02  1.635463e-27  0.682272
#                 r_all_gov_rev   -8.618671e-10  9.787153e-01  0.682272
#                 st_unempr        1.286955e+01  3.299761e-01  0.682272
#                 vac_rate         2.401607e+01  3.780369e-88  0.682272
# ols_w_db_b_g    cty_rev_prop    -8.309145e-01  5.391420e-03  0.278513
#                 gsp             -1.221648e-06  2.985986e-01  0.278513
#                 intensity_stock  1.066972e-01  1.028759e-01  0.278513
#                 lpop_growth      9.025974e-03  9.791729e-01  0.278513
#                 pcap             4.409348e-05  3.971521e-14  0.278513
#                 permit_rate      3.136407e+00  1.660594e-01  0.278513
#                 prop_ratio      -5.003155e-01  3.813594e-08  0.278513
#                 r_all_gov_rev   -2.323077e-10  6.245138e-04  0.278513
#                 st_unempr       -5.659832e-03  8.379808e-01  0.278513
#                 vac_rate         3.199591e-02  3.642848e-41  0.278513
# ols_w_db_b_g_ap cty_rev_prop     6.527032e-01  1.601728e-02  0.033867
# ...                                       ...           ...       ...
# ols_w_rook_g    st_unempr       -1.533451e-02  5.676412e-01  0.263564
#                 vac_rate         2.497748e-02  3.827352e-28  0.263564
# ols_w_rook_g_ap cty_rev_prop     1.045426e+00  1.138571e-04  0.083685
#                 gsp             -1.688792e-07  8.724682e-01  0.083685
#                 intensity_stock -1.035710e-01  7.960638e-02  0.083685
#                 lpop_growth      9.412016e-03  9.760467e-01  0.083685
#                 permit_rate      2.959414e+00  1.471512e-01  0.083685
#                 prop_ratio      -4.229246e-02  6.005456e-01  0.083685
#                 r_all_gov_rev   -7.439919e-11  1.705211e-01  0.083685
#                 st_unempr       -3.280730e-03  8.960437e-01  0.083685
#                 vac_rate         8.508680e-03  3.604258e-05  0.083685
# ols_w_rook_i    cty_rev_prop     1.093696e+00  7.630518e-04  0.189249
#                 gsp              3.041995e-06  1.741139e-02  0.189249
#                 intensity_stock  3.239381e-02  6.485348e-01  0.189249
#                 lpop_growth     -1.147279e-01  7.601994e-01  0.189249
#                 pcap            -6.739171e-05  1.054312e-25  0.189249
#                 permit_rate      5.187026e+00  3.525118e-02  0.189249
#                 prop_ratio       5.339315e-01  6.669837e-08  0.189249
#                 r_all_gov_rev    1.081741e-10  1.418617e-01  0.189249
#                 st_unempr        1.893875e-03  9.498168e-01  0.189249
#                 vac_rate         1.212419e-02  1.027377e-06  0.189249
# ols_w_rook_i_ap cty_rev_prop     3.495726e-01  3.895048e-02  0.030577
#                 gsp             -6.748652e-07  3.061935e-01  0.030577
#                 intensity_stock  2.718014e-02  4.626398e-01  0.030577
#                 lpop_growth     -2.181404e-02  9.115890e-01  0.030577
#                 permit_rate     -1.760096e+00  1.689005e-01  0.030577
#                 prop_ratio       2.087374e-02  6.800752e-01  0.030577
#                 r_all_gov_rev    5.835259e-11  8.641094e-02  0.030577
#                 st_unempr       -5.722126e-03  7.161507e-01  0.030577
#                 vac_rate        -5.160894e-03  6.347105e-05  0.030577
#
# [209 rows x 3 columns]

# %%
slm_res2=slm_res.set_index(['model','var','year']).sortlevel(0)
slm_res2.ix['slm_rev'].ix['permit_rate']
# Out:
#       Unnamed: 0           est      pval       rsq  st_unempr
# year
# 1995           3   -882.958639  0.784764  0.760454        4.0
# 1996           3   4305.325233  0.278799  0.706865        4.2
# 1997           3  -7766.303620  0.016667  0.709514        3.4
# 1998           3 -12433.150111  0.002116  0.732122        3.5
# 1999           3  -6545.275622  0.158427  0.706364        3.0
# 2000           3 -21430.156880  0.197352  0.729199        2.7
# 2001           3 -10871.942355  0.024026  0.688222        3.8
# 2002           3  -6059.887785  0.355570  0.703960        5.7
# 2003           3  -6976.505310  0.166184  0.714712        6.1
# 2004           3 -14332.753739  0.018775  0.744544        5.6
# 2005           3 -17048.859587  0.029544  0.721709        5.1
# 2006           3  -3911.413676  0.624837  0.694582        4.3
# 2007           3  -3371.978235  0.700520  0.718731        3.8
# 2008           3 -16260.010080  0.216006  0.700978        4.8
# 2009           3 -39812.133963  0.014378  0.690383        8.1

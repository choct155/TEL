# %% [markdown]
# # GeoPandas Demonstration

# %% [markdown]
# I have just discovered the [GeoPandas](https://github.com/kjordahl/geopandas) project on Github.  This could be a big time tool for me insofar as it streamlines the data management by keeping all information in analogous data structures (those defined in the [pandas](https://github.com/pydata/pandas) project.  This script will follow along with the examples in the GeoPandas [user guide](https://github.com/kjordahl/geopandas/blob/master/doc/source/user.rst), and also test suitability for plotting choropleths.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from geopandas import *
from IPython.display import HTML
import pysal

# %% [markdown]
# We will start with explicitly defined polygons.

# %%
#Define Polygon objects
p1 = Polygon([(0, 0), (1, 0), (1, 1)])
p2 = Polygon([(0, 0), (1, 0), (1, 1), (0, 1)])
p3 = Polygon([(2, 0), (3, 0), (3, 1), (2, 1)])

#Capture Polygon objects in a GeoSeries
g = GeoSeries([p1, p2, p3])

# help(g)
dir(g)
#print help(p1)
#g.plot()
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_wrap__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__dict__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__hex__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

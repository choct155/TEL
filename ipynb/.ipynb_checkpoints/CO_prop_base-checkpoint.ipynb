# %% [markdown]
# # Measures of the Property Tax Base

# %% [markdown]
# The current problem with the very rough measure I have proposed (see *tabor_score* and *CO_TEL_convergence*), is that it does not capture any county specific tax base information.  I need to say something about the level of property value in a given county over time if this discussion about limiting property revenue is to insightful.  This script will evaluate sources of base measurement as they come available.

# %% [markdown]
# ## *Moody's Estimate of Median Home Value by County (1979-Present)*

# %% [markdown]
# The first data to be assessed come from [Moody's](https://www.moodys.com/) [Economy.com](http://www.economy.com/default.asp) - the Moody's estimate of median home value by year.  It is a rare thing to actually want the average value data and have it not be available, but such is life.  Perhaps I can capture this information elsewhere.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from IPython.display import HTML

#Enable R capability
# %load_ext rmagic

#Set print length
pd.set_option('line_width',140)

#Set chart aesthetic
pd.options.display.mpl_style='default'

#Establish data directory
data_dir='/home/choct155/Google Drive/Dissertation/Data/'

#Read in data
# med_homeval=pd.read_csv(data_dir+'CO_med_hv_cty_1979_.csv',skiprows=[0,1,2,4,5,6,7,8,9,10,11,12],\
#                         delimiter='\t',parse_dates=True)
m=pd.read_csv(data_dir+'CO_med_hv_cty_1979_.csv',skiprows=[0,1,2,4,5,6,7,8,9,10,11,12])

m[m.columns[:6]].head(20)
# Out:
#    Geography\tAdams County (CO)\tAlamosa County (CO)\tArapahoe County (CO)\tArchuleta County (CO)\tBaca County (CO)\tBent County (CO)\tBoulder County (CO)\tBroomfield County (CO)\tChaffee County (CO)\tCheyenne County (CO)\tClear Creek County (CO)\tConejos County (CO)\tCostilla County (CO)\tCrowley County (CO)\tCuster County (CO)\tDelta County (CO)\tDenver County (CO)\tDolores County (CO)\tDouglas County (CO)\tEagle County (CO)\tEl Paso County (CO)\tElbert County (CO)\tFremont County (CO)\tGarfield County (CO)\tGilpin County (CO)\tGrand County (CO)\tGunnison County (CO)\tHinsdale County (CO)\tHuerfano County (CO)\tJackson County (CO)\tJefferson County (CO)\tKiowa County (CO)\tKit Carson County (CO)\tLa Plata County (CO)\tLake County (CO)\tLarimer County (CO)\tLas Animas County (CO)\tLincoln County (CO)\tLogan County (CO)\tMesa County (CO)\tMineral County (CO)\tMoffat County (CO)\tMontezuma County (CO)\tMontrose County (CO)\tMorgan County (CO)\tOtero County (CO)\tOuray County (CO)\tPark County (CO)\tPhillips County (CO)\tPitkin County (CO)\tProwers County (CO)\tPueblo County (CO)\tRio Blanco County (CO)\tRio Grande County (CO)\tRoutt County (CO)\tSaguache County (CO)\tSan Juan County (CO)\tSan Miguel County (CO)\tSedgwick County (CO)\tSummit County (CO)\tTeller County (CO)\tWashington County (CO)\tWeld County (CO)\tYuma County (CO)\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t
# 0   1979Q1\t55.64\t35.16\t68.15\t51.36\t22.96\t22....
# 1   1979Q2\t57.71\t36.66\t70.88\t53.28\t23.89\t23....
# 2   1979Q3\t59.73\t38.13\t73.55\t55.15\t24.79\t23....
# 3   1979Q4\t61.14\t39.24\t75.49\t56.48\t25.46\t24....
# 4   1980Q1\t61.52\t39.68\t76.15\t56.86\t25.69\t24....
# 5   1980Q2\t61.27\t39.71\t76.02\t56.64\t25.66\t24....
# 6   1980Q3\t64.52\t42.09\t80.42\t59.89\t27.13\t25....
# 7   1980Q4\t64.66\t42.46\t80.97\t60.29\t27.31\t25....
# 8   1981Q1\t66.32\t42.96\t83.25\t60.91\t27.62\t26....
# 9   1981Q2\t67.97\t43.15\t85.36\t61.18\t27.74\t26....
# 10  1981Q3\t69.95\t45.17\t87.85\t64.04\t29.04\t27....
# 11  1981Q4\t69.7\t45.22\t87.68\t64.12\t29.08\t27.4...
# 12  1982Q1\t71.77\t46.84\t90.54\t66.31\t30.07\t28....
# 13  1982Q2\t72.08\t47.68\t91.22\t67.43\t30.56\t28....
# 14  1982Q3\t73.98\t48.18\t93.9\t68.06\t30.84\t28.8...
# 15  1982Q4\t77.16\t50.82\t98.22\t71.75\t32.49\t30....
# 16  1983Q1\t74.9\t49.73\t95.6\t70.18\t31.75\t29.53...
# 17  1983Q2\t73.32\t48.32\t93.82\t68.17\t30.81\t28....
# 18  1983Q3\t73.16\t48.89\t93.86\t68.96\t31.14\t28....
# 19  1983Q4\t70.14\t46.62\t90.18\t65.78\t29.66\t27....

# %% [markdown]
# Well that was unexpected... there is only one column of data.  Evidently Moody's lied to me, and the data are not comma delimited.  In fact, they are in a rather awkward arrangement (which can be seen when viewing the data as a text file).  Each row is tab-delimited, but all of the values in each row are grouped and displayed as a wrapped block of text, before moving on to the next row.
#
# This is certainly awkward, but by no means insurmountable.  We need to parse out the different columns by splitting on the tabs and creating an ndarray, which flows naturally into a DataFrame.  A bit of trial and error was used to determine the appropriate index calls to get at the data hidden in this weird format.

# %%
#Initiate container with headers
m_array=[m.columns[0].split('\t')]

#For each row in m...
for i in range(len(m)):
    #...split the value on tabs, and append the resulting list to the above container
    m_array.append(m.ix[i].str.split('\t')[0])

#Inspect date covereage
dates=[]
#For each row...
for row in m_array:
    #...throw the first element in the dates list
    dates.append(row[0])

print dates[:5]
print dates[-5:]
# Out:
# ['Geography', '1979Q1', '1979Q2', '1979Q3', '1979Q4']
# ['2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2']

# %% [markdown]
# So, it looks like we have full coverage and can transition into a DataFrame.  Note that there are many empty columns on the back end, but they are easy enough to dispose of from the DataFrame object.

# %%
#Convert to DF (first element of m_array contains header info)
mhv_temp=DataFrame(m_array[1:])

#Clean up column names (drop County (CO))
##Define function to replace multiple elements
def replace_all(s,dct):
    for i,j in dct.iteritems():
        s=s.replace(i,j)
    return s
##Define substrings to be removed
replace_dict={'(CO)':'',
              'County':''}
##Create container for new county names
new_cty_list=[]
##For each county in the header array...
for cty in m_array[0]:
    #...replace the relevant substrings
    new_cty_list.append(replace_all(cty,replace_dict).strip())
##Set new county names as column names
mhv_temp.columns=new_cty_list

#Drop extraneous columns
mhv=mhv_temp[mhv_temp.columns[:65]]

mhv[mhv.columns[:14]].head()
# Out:
#   Geography  Adams Alamosa Arapahoe Archuleta   Baca   Bent Boulder Broomfield Chaffee Cheyenne Clear Creek Conejos Costilla
# 0    1979Q1  55.64   35.16    68.15     51.36  22.96  22.21   89.04      61.59   47.42    22.69       65.82   22.93    21.27
# 1    1979Q2  57.71   36.66    70.88     53.28  23.89  23.05    92.6       64.2   48.99    23.74        68.6   23.68    22.18
# 2    1979Q3  59.73   38.13    73.55     55.15  24.79  23.87   96.09      66.77   50.49    24.81       71.33    24.4    23.08
# 3    1979Q4  61.14   39.24    75.49     56.48  25.46  24.44   98.63       68.7   51.46    25.65       73.36   24.87    23.76
# 4    1980Q1  61.52   39.68    76.15     56.86  25.69  24.59    99.5      69.47   51.54    26.06       74.14   24.91    24.04

# %%
print 256*256
# Out:
# 65536

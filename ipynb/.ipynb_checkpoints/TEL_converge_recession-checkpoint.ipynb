# %% [markdown]
# # Tax and Expenditure Limitations in Recessions

# %% [markdown]
# We have already looked at fiscal and economic capacity county-wise convergence over time in *CO_TEL_convergence*.  For the APPAM Conference, this message must take on a decidedly business cycle feel.  The purpose of this script is to explore whether or not the convergence we have already observed behaves differently at different times.  This script will also provide a more detailed comparison of revenue and economic convergence, as well as feature a new method of measuring TEL impact.
#
# To fulfill these tasks, we need to integrate demographic data with dataset produced in *CO_TEL_convergence* upfront.  Once this is done, we will also pull in the assessment base information.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from IPython.display import HTML
import pandas.io.data as web
import pysal
import seaborn as sb
from statsmodels.graphics.gofplots import *

#Establish working directory
workdir='/home/choct155/projects/gdrive_data/Google Drive/Dissertation/Data/spatial/US/'
# workdir='/home/choct155/Google Drive/Dissertation/Data/spatial/US/'

#Establish secondary data location
wd2='/home/choct155/projects/gdrive_data/Google Drive/Google Drive/Dissertation/Data/'
# wd2='/home/choct155/Google Drive/Dissertation/Data/'

#Set print width
pd.set_option('line_width', 140)

def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %% [markdown]
# The dataset from *CO_TEL_convergence* contains both fiscal and spatial attributes.

# %%
co_sf=pd.read_csv(wd2+'CO_sf.csv')

co_sf.head().T
# Out:
#                                             0             1              2                3               4
# Unnamed: 0                                  0             1              2                3               4
# ALAND                              2893573835    2957922894      388229141       3177803460      4179563675
# AWATER                               15324680      16953424         941898          8828904        18750018
# CBSAFP                                    NaN           NaN          19740              NaN             NaN
# CLASSFP                                    H1            H1             H1               H1              H1
# COUNTYFP                                   53            29             47               23              57
# COUNTYNS                               198142        198130         198139           198127          198144
# CSAFP                                     NaN           NaN            216              NaN             NaN
# FUNCSTAT                                    A             A              A                A               A
# GEOID                                    8053          8029           8047             8023            8057
# INTPTLAT                             37.81167      38.86176       39.86108         37.27755        40.66343
# INTPTLON                            -107.3833     -107.8648      -105.5289        -105.4289       -106.3292
# LSAD                                        6             6              6                6               6
# METDIVFP                                  NaN           NaN            NaN              NaN             NaN
# MTFCC                                   G4020         G4020          G4020            G4020           G4020
# NAME                                 Hinsdale         Delta         Gilpin         Costilla         Jackson
# NAMELSAD                      Hinsdale County  Delta County  Gilpin County  Costilla County  Jackson County
# STATEFP                                     8             8              8                8               8
# sort_id                                     0             1              2                3               4
# index                                     902           626            833              516             948
# FNAME                                Hinsdale         Delta         Gilpin         Costilla         Jackson
# AUDIT_YEAR                               1992          1992           1992             1992            1992
# REV_TOTAL                             2150077    1.5551e+07        5350040          7743135         3351476
# REV_INTGOVT                           1052781       8120230        1118319          5290419         1974958
# EXP_TOTAL                             2389006  1.528072e+07        5432505          7695992         3972800
# TOTAL_DEBT                                  0       2900387       638173.4         112912.9        21404.13
# CTY_POP                                   457         22809           3237             3191            1528
# intensity                                   3             3              3                3               3
# pcrev                                4704.764      681.7923       1652.777         2426.554        2193.374
# pcexp                                5227.583      669.9425       1678.253         2411.781            2600
# ...                                       ...           ...            ...              ...             ...
# EXP_INTEREST_GEN                     11903.76        322493              0          12266.1               0
# NAME_x                        Hinsdale County  Delta County  Gilpin County  Costilla County  Jackson County
# NAME_y                               Hinsdale         Delta         Gilpin         Costilla         Jackson
# EXP_OTHER_PUBLIC_SAFETY              2273.425      373488.4         102616         8339.968        23527.73
# REV_CHARGES                          156780.7       1078797       334997.6         224650.1          141810
# EXP_TOTAL_PUBLIC_WORKS                1085578       3426897       863378.6          1922318         1017257
# DFL                                         1             1              1                1               1
# REV_TOTAL_TAX                        666121.1       5713265        3235252          2033799        845999.9
# LGTYPE_ID                                   1             1              1                1               1
# REV_SALES_USE_TAX                    243461.3       2854697              0         57511.38        212605.7
# REV_LICENSES                         11568.93      84260.43       121552.5           1255.2        8286.458
# REV_REAL_ESTATE_TRANSFER_TAX                0             0              0                0               0
# Unnamed: 0.1                              927           507            822              402             997
# REV_MISC                             262734.2      554448.1       504859.3         192988.8        379619.1
# REV_PROPERTY_TAX                     393764.2       2457638        1826214          1785146        547990.2
# REV_SO_TAX                           25920.41      339958.8       180306.9         89002.98        83378.28
# LGID                                    27001         15006          24005            12003           29001
# REV_FINES                              91.732             0       35059.97           22.933         802.655
# ASSETS                                1641495       8625259        1764968          1370510         6107584
# SALES_TAX_RATE                       6.115467      3.057733              0         1.528867          4.5866
# REV_OCCUPATION_TAX                          0             0              0                0               0
# REV_CIGARETTE_TAX                    1683.282      17040.75       911.2046         4750.189        2458.418
# REV_INTEREST                         62704.94      263030.8       86157.75         67947.42        238006.3
# EXP_TOTAL_OPERATING                   1973996  1.358534e+07        4267761          6949221         2881874
# EXP_TRASH                               73910      330375.9              0                0        40433.94
# int_temp                                    3             3              3                3               3
# EXP_STREET                            1011668       3096521       863378.6          1922318        976823.5
# RETAIL_SALES                         11501.66      308424.4       53839.04         14247.51        26811.74
# REV_SOCIAL_SERVICE                          0       4234762       408401.6          1432923        180027.1
# REV_HUT                              633719.8       1793307       471578.9          2272131         1037405
#
# [124 rows x 5 columns]

# %% [markdown]
# The demographic data are taken from the [Colorado County Profile query tool](https://dola.colorado.gov/demog_webapps/psc_parameters.jsf) maintained by the Department of Local Affairs.  Note that the data are arranged in long format, with variable and value columns.

# %%
#Read in data
co_dem=pd.read_csv(wd2+'CO_cty_profile.csv',delimiter='\t')

#Rename columns
co_dem.columns=['AUDIT_YEAR','FNAME','var','value']
co_dem
# Out:
#        AUDIT_YEAR       FNAME                               var      value
# 0            2011       Adams            Average Household Size       2.85
# 1            2011       Adams                            Births    7244.00
# 2            2011       Adams                            Deaths    2462.00
# 3            2011       Adams  Group Quarters Population (July)    4024.00
# 4            2011       Adams       Household Population (July)  447552.00
# 5            2011       Adams              Housing Vacancy Rate       3.84
# 6            2011       Adams                   July Population  451576.00
# 7            2011       Adams       Natural Population Increase    4782.00
# 8            2011       Adams              Net Building Permits     226.00
# 9            2011       Adams                     Net Migration    3083.00
# 10           2011       Adams   Population (U.S. Census Bureau)  451443.00
# 11           2011       Adams                  Total Households  157264.00
# 12           2011       Adams               Total Housing Units  163550.00
# 13           2011       Adams              Vacant Housing Units    6286.00
# 14           2011     Alamosa            Average Household Size       2.45
# 15           2011     Alamosa                            Births     234.00
# 16           2011     Alamosa                            Deaths     131.00
# 17           2011     Alamosa  Group Quarters Population (July)     740.00
# 18           2011     Alamosa       Household Population (July)   14902.00
# 19           2011     Alamosa              Housing Vacancy Rate       7.95
# 20           2011     Alamosa                   July Population   15642.00
# 21           2011     Alamosa       Natural Population Increase     103.00
# 22           2011     Alamosa              Net Building Permits       8.00
# 23           2011     Alamosa                     Net Migration      65.00
# 24           2011     Alamosa   Population (U.S. Census Bureau)   15710.00
# 25           2011     Alamosa                  Total Households    6075.00
# 26           2011     Alamosa               Total Housing Units    6600.00
# 27           2011     Alamosa              Vacant Housing Units     525.00
# 28           2011    Arapahoe            Average Household Size       2.53
# 29           2011    Arapahoe                            Births    7721.00
# ...           ...         ...                               ...        ...
# 24162        1985  Washington               Total Housing Units    2555.00
# 24163        1985  Washington              Vacant Housing Units     447.00
# 24164        1985        Weld            Average Household Size       2.58
# 24165        1985        Weld                            Births    2262.00
# 24166        1985        Weld                            Deaths     830.00
# 24167        1985        Weld  Group Quarters Population (July)    4514.00
# 24168        1985        Weld       Household Population (July)  125886.00
# 24169        1985        Weld              Housing Vacancy Rate       3.20
# 24170        1985        Weld                   July Population  130400.00
# 24171        1985        Weld       Natural Population Increase    1432.00
# 24172        1985        Weld              Net Building Permits     878.00
# 24173        1985        Weld                     Net Migration     -21.00
# 24174        1985        Weld   Population (U.S. Census Bureau)  130400.00
# 24175        1985        Weld                  Total Households   48812.00
# 24176        1985        Weld               Total Housing Units   50425.00
# 24177        1985        Weld              Vacant Housing Units    1613.00
# 24178        1985        Yuma            Average Household Size       2.53
# 24179        1985        Yuma                            Births     145.00
# 24180        1985        Yuma                            Deaths      95.00
# 24181        1985        Yuma  Group Quarters Population (July)     136.00
# 24182        1985        Yuma       Household Population (July)    9717.00
# 24183        1985        Yuma              Housing Vacancy Rate      11.60
# 24184        1985        Yuma                   July Population    9853.00
# 24185        1985        Yuma       Natural Population Increase      50.00
# 24186        1985        Yuma              Net Building Permits       1.00
# 24187        1985        Yuma                     Net Migration    -132.00
# 24188        1985        Yuma   Population (U.S. Census Bureau)    9853.00
# 24189        1985        Yuma                  Total Households    3840.00
# 24190        1985        Yuma               Total Housing Units    4343.00
# 24191        1985        Yuma              Vacant Housing Units     503.00
#
# [24192 rows x 4 columns]

# %% [markdown]
# To integrate this set with the original data, it is best to unstack the variable column.

# %%
#Temporarily set index to facilitate unstacking of 'var'
co_d_temp=co_dem.set_index(['AUDIT_YEAR','FNAME','var']).unstack('var')

#Rename columns (dropping value level from column names and abbreviating)
desired_cols=['hh_size','births','deaths','gq_pop','hh_pop','vac_rate','pop','npop_increase',\
              'permits','n_migr','cens_pop','hh_num','hu_num','vac_num']
co_d_temp.columns=desired_cols

#Reset index
co_d=co_d_temp.reset_index()

print co_d

co_d.head()
# Out:
#       AUDIT_YEAR        FNAME  hh_size  births  deaths  gq_pop  hh_pop  vac_rate     pop  npop_increase  permits  n_migr  cens_pop  \
# 0           1985        Adams     2.81    5210    1304    2256  266508      9.00  268764           3906     2741    -807    268764
# 1           1985      Alamosa     2.84     258      79     884   12127     16.40   13011            179       10     -85     13011
# 2           1985     Arapahoe     2.68    6458    1602    3536  377708      8.40  381244           4856     5069    9246    381244
# 3           1985    Archuleta     2.84     101      22       0    5213     45.60    5213             79        9     149      5213
# 4           1985         Baca     2.61      83      62       0    4873     27.70    4873             21        1    -195      4873
# 5           1985         Bent     2.66      80      64     424    5275     21.60    5699             16        6    -155      5699
# 6           1985      Boulder     2.54    3326    1064    8600  200844     10.30  209444           2262     1953   -3005    209444
# 7           1985   Broomfield     0.00       0       0       0       0      0.00       0              0        0       0         0
# 8           1985      Chaffee     2.58     156     107     612   11737     29.00   12349             49       73    -538     12349
# 9           1985     Cheyenne     2.36      55      21      14    2280      9.00    2294             34        3      23      2294
# 10          1985  Clear Creek     2.55     140      40      45    7891     32.70    7936            100       53      84      7936
# 11          1985      Conejos     3.13     143      60       0    7776     25.00    7776             83        1    -312      7776
# 12          1985     Costilla     2.88      50      20       0    3363     27.70    3363             30        0      73      3363
# 13          1985      Crowley     2.33      51      36      53    2944      3.60    2997             15        1      94      2997
# 14          1985       Custer     2.49      22      22      18    2048     36.70    2066              0        0     160      2066
# 15          1985        Delta     2.50     323     245     331   23135      7.40   23466             78       10    -617     23466
# 16          1985       Denver     2.13    8952    4541   13031  483400      5.00  496431           4411     1272   -4595    496431
# 17          1985      Dolores     2.71      27       9       0    1548     37.70    1548             18        0    -154      1548
# 18          1985      Douglas     3.37     679     129     163   39885     22.30   40048            550     2160    3214     40048
# 19          1985        Eagle     2.40     386      41       6   18023     44.80   18029            345       74     923     18029
# 20          1985      El Paso     2.63    7055    1851   17384  351122     10.60  368506           5204     6499    8645    368506
# 21          1985       Elbert     2.93     109      42      35    8525     17.40    8560             67      184     233      8560
# 22          1985      Fremont     2.61     364     374    2749   28617     16.30   31366            -10      259      93     31366
# 23          1985     Garfield     2.68     467     172     444   25270     25.50   25714            295       56    -238     25714
# 24          1985       Gilpin     2.69      41      17      51    3030     48.40    3081             24       36      31      3081
# 25          1985        Grand     2.45     144      41       9    9203     62.30    9212            103      160     218      9212
# 26          1985     Gunnison     2.21     140      50    1399    8991     43.20   10390             90       87    -117     10390
# 27          1985     Hinsdale     2.81       5       0       0     472     81.10     472              5       20    -116       472
# 28          1985     Huerfano     2.40      85      81     144    6665     32.60    6809              4       38     165      6809
# 29          1985      Jackson     2.85      28       7      19    1710     48.50    1729             21        7     -85      1729
# ...          ...          ...      ...     ...     ...     ...     ...       ...     ...            ...      ...     ...       ...
# 1698        2011         Lake     2.43     104      41     133    7263     30.39    7396             63      -26      51      7427
# 1699        2011      Larimer     2.42    3313    1861    8541  296768      8.20  305309           1452      420    3325    305525
# 1700        2011   Las Animas     2.29     149     196     861   14130     25.23   14991            -47        2    -369     15037
# 1701        2011      Lincoln     2.28      64      52     979    4420     19.85    5399             12       -6     -87      5454
# 1702        2011        Logan     2.34     212     182    3461   18732     10.90   22193             30       12    -130     22619
# 1703        2011         Mesa     2.46    1908    1296    4330  143423      7.86  147753            612      446     554    147083
# 1704        2011      Mineral     2.00       5       3       0     709     70.67     709              2       -6       2       708
# 1705        2011       Moffat     2.51     187      67     102   13332     14.30   13434            120       10    -492     13451
# 1706        2011    Montezuma     2.40     308     288     237   25176     13.65   25413             20       70    -139     25442
# 1707        2011     Montrose     2.47     492     399     542   40483     10.70   41025             93      106    -256     41011
# 1708        2011       Morgan     2.68     460     277     564   27774     10.05   28338            183       10     -41     28175
# 1709        2011        Otero     2.38     245     216     433   18433     13.71   18866             29      -16      -1     18865
# 1710        2011        Ouray     2.19      29      19       0    4355     36.10    4355             10       40    -101      4356
# 1711        2011         Park     2.25     117      83      92   15987     49.42   16079             34      130    -217     16089
# 1712        2011     Phillips     2.41      51      61      60    4327     14.10    4387            -10        2     -68      4399
# 1713        2011       Pitkin     2.10     175      53      72   17022     37.56   17094            122      158    -184     17102
# 1714        2011      Prowers     2.48     142     149     315   12188     17.32   12503             -7      -30     -21     12549
# 1715        2011       Pueblo     2.46    1865    1651    4327  156066      9.20  160393            214      352     683    160545
# 1716        2011   Rio Blanco     2.43     106      40     235    6550     19.14    6785             66       28     102      6782
# 1717        2011   Rio Grande     2.47     143     122     198   11717     28.60   11915             21      -14    -107     11956
# 1718        2011        Routt     2.34     228      88     335   22881     40.77   23216            140      144    -363     23239
# 1719        2011     Saguache     2.31      79      37      18    6240     30.44    6258             42       22      72      6228
# 1720        2011     San Juan     2.03       8       8       0     691     55.15     691              0        2     -18       692
# 1721        2011   San Miguel     2.13      76      18       9    7487     47.48    7496             58       56      82      7490
# 1722        2011     Sedgwick     2.14      29      41      35    2323     23.46    2358            -12        0       3      2364
# 1723        2011       Summit     2.36     308      54     273   27691     60.83   27964            254      130    -363     27972
# 1724        2011       Teller     2.37     222     134     132   23246     22.69   23378             88       52    -151     23356
# 1725        2011   Washington     2.34      40      53     184    4575     19.90    4759            -13        6     -43      4770
# 1726        2011         Weld     2.76    3749    1434    5874  252574      5.91  258448           2315      600    1903    258638
# 1727        2011         Yuma     2.49     155     118     196    9874     11.26   10070             37       -2       1     10100
#
#       hh_num  hu_num  vac_num
# 0      94949  104376     9427
# 1       4277    5113      836
# 2     140787  153726    12939
# 3       1837    3379     1542
# 4       1867    2581      714
# 5       1986    2532      546
# 6      79100   88178     9078
# 7          0       0        0
# 8       4543    6402     1859
# 9        965    1060       95
# 10      3093    4596     1503
# 11      2486    3316      830
# 12      1167    1614      447
# 13      1262    1309       47
# 14       823    1300      477
# 15      9237    9974      737
# 16    226540  238346    11806
# 17       571     916      345
# 18     11824   15225     3401
# 19      7498   13585     6087
# 20    133562  149466    15904
# 21      2908    3520      612
# 22     10955   13085     2130
# 23      9426   12647     3221
# 24      1128    2185     1057
# 25      3751    9948     6197
# 26      4072    7165     3093
# 27       168     888      720
# 28      2778    4123     1345
# 29       600    1166      566
# ...      ...     ...      ...
# 1698    2987    4291     1304
# 1699  122620  133572    10952
# 1700    6158    8236     2078
# 1701    1942    2423      481
# 1702    8015    8996      981
# 1703   58268   63239     4971
# 1704     354    1207      853
# 1705    5321    6209      888
# 1706   10490   12148     1658
# 1707   16383   18346     1963
# 1708   10360   11517     1157
# 1709    7743    8973     1230
# 1710    1986    3108     1122
# 1711    7117   14072     6955
# 1712    1797    2092      295
# 1713    8123   13010     4887
# 1714    4916    5946     1030
# 1715   63502   69933     6431
# 1716    2695    3333      638
# 1717    4752    6655     1903
# 1718    9768   16491     6723
# 1719    2706    3890     1184
# 1720     340     758      418
# 1721    3517    6697     3180
# 1722    1083    1415      332
# 1723   11740   29975    18235
# 1724    9817   12699     2882
# 1725    1956    2442      486
# 1726   91377   97114     5737
# 1727    3963    4466      503
#
# [1728 rows x 16 columns]
#    AUDIT_YEAR      FNAME  hh_size  births  deaths  gq_pop  hh_pop  vac_rate     pop  npop_increase  permits  n_migr  cens_pop  hh_num  \
# 0        1985      Adams     2.81    5210    1304    2256  266508       9.0  268764           3906     2741    -807    268764   94949
# 1        1985    Alamosa     2.84     258      79     884   12127      16.4   13011            179       10     -85     13011    4277
# 2        1985   Arapahoe     2.68    6458    1602    3536  377708       8.4  381244           4856     5069    9246    381244  140787
# 3        1985  Archuleta     2.84     101      22       0    5213      45.6    5213             79        9     149      5213    1837
# 4        1985       Baca     2.61      83      62       0    4873      27.7    4873             21        1    -195      4873    1867
#
#    hu_num  vac_num
# 0  104376     9427
# 1    5113      836
# 2  153726    12939
# 3    3379     1542
# 4    2581      714

# %% [markdown]
# From here we can merge these sets on ['AUDIT_YEAR','FNAME']...

# %%
co_sfd=pd.merge(co_sf,co_d,on=['AUDIT_YEAR','FNAME'])

print co_sfd

co_sfd.columns
# Out:
#       Unnamed: 0        ALAND    AWATER  CBSAFP CLASSFP  COUNTYFP  COUNTYNS  CSAFP FUNCSTAT  GEOID  ...    hh_pop  vac_rate     pop  \
# 0              0   2893573835  15324680     NaN      H1        53    198142    NaN        A   8053  ...       504      83.5     504
# 1              1   2957922894  16953424     NaN      H1        29    198130    NaN        A   8029  ...     21181      10.1   21869
# 2              2    388229141    941898   19740      H1        47    198139    216        A   8047  ...      3242      44.1    3244
# 3              3   3177803460   8828904     NaN      H1        23    198127    NaN        A   8023  ...      3188      31.4    3190
# 4              4   4179563675  18750018     NaN      H1        57    198144    NaN        A   8057  ...      1564      55.0    1574
# 5              5   2624702134   4013482     NaN      H1        15    198123    NaN        A   8015  ...     11833      23.6   13121
# 6              6   4793688729    442148   19740      H1        39    198136    216        A   8039  ...     10719      12.7   10766
# 7              7   1442738671   4944573   17820      H1       119    198175    NaN        A   8119  ...     13603      34.1   13670
# 8              8   4243419913  15352633     NaN      H1        99    198165    NaN        A   8099  ...     12950      16.0   13105
# 9              9   1419419287   3530746     NaN      H1       115    198173    NaN        A   8115  ...      2598      21.4    2629
# 10            10    396198354   4222992   19740      H6        31    198131    216        C   8031  ...    476507       7.2  488258
# 11            11   2361929110    984917     NaN      H1       105    198168    NaN        A   8105  ...     10739      19.2   10940
# 12            12   5256407750  27516850     NaN      H1        83    198157    NaN        A   8083  ...     19496      14.1   19651
# 13            13  12284921637  19806932     NaN      H1        81    198156    NaN        A   8081  ...     11559      17.6   11692
# 14            14   3334263504   9235291     NaN      H1        21    198126    NaN        A   8021  ...      7485      31.7    7514
# 15            15   4382658416  19545450   20420      H1        67    198148    NaN        A   8067  ...     32713      20.0   34429
# 16            16   2763645279   2716141     NaN      H1        33    198132    NaN        A   8033  ...      1403      47.3    1403
# 17            17   5596501541   2251930     NaN      H1        63    198147    NaN        A   8063  ...      7167      14.9    7232
# 18            18  10326885138  76675362   24540      H1       123    198177    216        A   8123  ...    135827       3.8  140122
# 19            19   4578600049  47032937     NaN      H1        61    198146    NaN        A   8061  ...      1647      19.1    1695
# 20            20   8207226426   4454545     NaN      H1       109    198170    NaN        A   8109  ...      4690      22.9    4788
# 21            21   6521817532  15207414     NaN      H1       121    198176    NaN        A   8121  ...      4848       7.4    4886
# 22            22   3496904695  13827548     NaN      H1         7    198119    NaN        A   8007  ...      5880      47.5    5880
# 23            23   6617316468   6142193     NaN      H1         9    198120    NaN        A   8009  ...      4231      26.4    4302
# 24            24   2176207910   6769100   19740      H1        35    198133    216        A   8035  ...     75090       0.3   75361
# 25            25   6179976224  30284066   39380      H1       101    198166    NaN        A   8101  ...    121435       5.4  124410
# 26            26   4362916056  18803966   20780      H1        37    198134    NaN        A   8037  ...     24815      44.6   24940
# 27            27   1781724999    301808     NaN      H1        95    198163    NaN        A   8095  ...      4162       7.0    4231
# 28            28   8342198615   4868111     NaN      H1       103    198167    NaN        A   8103  ...      6008      17.8    6180
# 29            29   6117633825  15831696     NaN      H1       107    198169    NaN        A   8107  ...     14996      42.2   15149
# ...          ...          ...       ...     ...     ...       ...       ...    ...      ...    ...  ...       ...       ...     ...
# 1442        1442   7634471698  21430626     NaN      H1        45    198138    NaN        A   8045  ...     33728       6.7   34496
# 1443        1443   5508460909   7111548   17820      H1        41    198135    NaN        A   8041  ...    439263       4.2  456500
# 1444        1444   2268230027   5222170     NaN      H1        79    198155    NaN        A   8079  ...       646      78.5     646
# 1445        1445   5682134218  43530467   19740      H1        93    198162    216        A   8093  ...      9526      53.5    9526
# 1446        1446   4120753930   5792107     NaN      H1        55    198143    NaN        A   8055  ...      6791      30.4    6923
# 1447        1447   3918307819  73093700     NaN      H1        11    198121    NaN        A   8011  ...      4691      19.0    5400
# 1448        1448   1023554447   3280081   19740      H1        19    198125    216        A   8019  ...      8408      30.2    8458
# 1449        1449    976206766  18110615   20780      H1        65    198149    NaN        A   8065  ...      6342      27.2    6380
# 1450        1450   4605714106   8166145     NaN      H1        17    198124    NaN        A   8017  ...      2247      19.3    2291
# 1451        1451  12361253683   6929976     NaN      H1        71    198151    NaN        A   8071  ...     14322      16.7   14754
# 1452        1452   1913033457   3364740     NaN      H1        27    198129    NaN        A   8027  ...      2417      58.3    2418
# 1453        1453   1871620246   1847609     NaN      H1         3    198117    NaN        A   8003  ...     13273       5.2   13823
# 1454        1454   6123751576  11134682     NaN      H1       125    198178    NaN        A   8125  ...      9152      12.3    9276
# 1455        1455   8622131029  31435336   24300      H1        77    198154    NaN        A   8077  ...    100262       3.9  102767
# 1456        1456   4781807818  60250181     NaN      H1        49    198140    NaN        A   8049  ...      9257      66.4    9339
# 1457        1457   1402725842   1599543     NaN      H1        91    198161    NaN        A   8091  ...      2898      31.4    2902
# 1458        1458   8389491951  53067063     NaN      H1        51    198141    NaN        A   8051  ...     10436      43.7   11671
# 1459        1459   3332207690   5213860     NaN      H1       113    198172    NaN        A   8113  ...      5227      37.9    5305
# 1460        1460   3316112929  34663780   22820      H1        87    198159    NaN        A   8087  ...     24570       2.5   25088
# 1461        1461   6723779313  98113981   22660      H1        69    198150    NaN        A   8069  ...    207549       6.1  214936
# 1462        1462   3268485084  20052353     NaN      H1        89    198160    NaN        A   8089  ...     19955      10.9   20490
# 1463        1463   2514071663   6469378     NaN      H1        97    198164    NaN        A   8097  ...     14404      35.9   14539
# 1464        1464   6676208280  22780444     NaN      H1        73    198152    NaN        A   8073  ...      4854       8.9    5939
# 1465        1465   2039409780  33430387     NaN      H1        25    198128    NaN        A   8025  ...      3072      12.5    4207
# 1466        1466   1003640124   2035929     NaN      H1       111    198171    NaN        A   8111  ...       563      57.8     566
# 1467        1467   3970604102   2235391   15860      H1        43    198137    NaN        A   8043  ...     31874      12.4   38705
# 1468        1468   1979243247  25485250   19740      H1        59    198145    216        A   8059  ...    476589       3.8  483433
# 1469        1469   2066605764  19528578   19740      H1         5    198118    216        A   8005  ...    433209       2.4  436405
# 1470        1470     85415592   1464123   19740      H6        14   1945881    216        C   8014  ...         0       0.0       0
# 1471        1471   1881236301  36605899   14500      H1        13    198122    216        A   8013  ...    243256       4.2  252725
#
#       npop_increase permits n_migr cens_pop  hh_num  hu_num  vac_num
# 0                 4      12     47      503     210    1274     1064
# 1                10      40    630    22210    9070   10089     1019
# 2                10      34    145     3147    1382    2471     1089
# 3                21       0    -87     3203    1196    1743      547
# 4                11       3      7     1646     603    1339      736
# 5               -43      83    300    12977    5108    6687     1579
# 6               101     194    397    10831    3662    4196      534
# 7                90     189    868    13762    5076    7707     2631
# 8                98      -4     49    13140    4914    5852      938
# 9               -11       1    -30     2640    1115    1418      303
# 10             4242     283   8833   484110  222322  239474    17152
# 11               48      18     57    10656    4284    5303     1019
# 12              181      23    410    19530    6939    8077     1138
# 13               53       7    190    11566    4319    5239      920
# 14               31       1    -51     7447    2443    3575     1132
# 15              234     392    784    34541   12743   15921     3178
# 16                5       4    -39     1391     502     953      451
# 17               32       6     39     7217    2750    3230      480
# 18             1399     506   2992   135936   49801   51756     1955
# 19               -4       4     16     1632     710     878      168
# 20               45      20     11     4786    1779    2306      527
# 21               11       2     92     4599    2143    2314      171
# 22               45     107    209     5729    2147    4086     1939
# 23              -16       4   -123     4431    1794    2438      644
# 24             1179    2946   7494    73049   25714   25794       80
# 25              546     228    378   123685   48410   51199     2789
# 26              387     556   1095    24617    9157   16524     7367
# 27               -9       7     31     4142    1830    1968      138
# 28               34      21    119     6208    2310    2809      499
# 29              109     223    309    15038    5533    9569     4036
# ...             ...     ...    ...      ...     ...     ...      ...
# 1442            253     533   1669    34038   12737   13648      911
# 1443           5118    3764  14247   453216  166447  173741     7294
# 1444              0      16     46      617     269    1253      984
# 1445             68     426    877     9475    3694    7948     4254
# 1446             -3      60    487     6155    2777    3992     1215
# 1447             14      12     36     5409    1896    2342      446
# 1448             74      81    347     8520    3485    4990     1505
# 1449             53      22     56     6093    2595    3563      968
# 1450             -1       4    -14     2315     885    1097      212
# 1451              3      59    539    13965    5953    7143     1190
# 1452             22      87     73     2503     986    2363     1377
# 1453            120      45     46    13973    5147    5430      283
# 1454             15       8     95     9079    3596    4100      504
# 1455            330     924   2534   103405   39552   41172     1620
# 1456             51     273    363     8703    3465   10327     6862
# 1457             16      90    233     2861    1174    1712      538
# 1458             81     339    279    11593    4565    8113     3548
# 1459             40     353    401     4817    2076    3343     1267
# 1460            209     191    638    23669    9139    9373      234
# 1461           1649    3170   6443   212289   79859   85053     5194
# 1462             51       4      4    20449    7816    8771      955
# 1463            129     192    349    13567    6615   10321     3706
# 1464              7       1     54     5505    2087    2290      203
# 1465            -27       1     89     4125    1240    1417      177
# 1466              7       2     14      546     209     495      286
# 1467            -12     277   2210    38561   12565   14336     1771
# 1468           3802    4093   3423   476787  182527  189667     7140
# 1469           4027    4198   4908   441042  171232  175437     4205
# 1470              0       0      0        0       0       0        0
# 1471           1961    2191   3489   249030   98566  102888     4322
#
# [1472 rows x 138 columns]
# Index([u'Unnamed: 0', u'ALAND', u'AWATER', u'CBSAFP', u'CLASSFP', u'COUNTYFP', u'COUNTYNS', u'CSAFP', u'FUNCSTAT', u'GEOID', u'INTPTLAT', u'INTPTLON', u'LSAD', u'METDIVFP', u'MTFCC', u'NAME', u'NAMELSAD', u'STATEFP', u'sort_id', u'index', u'FNAME', u'AUDIT_YEAR', u'REV_TOTAL', u'REV_INTGOVT', u'EXP_TOTAL', u'TOTAL_DEBT', u'CTY_POP', u'intensity', u'pcrev', u'pcexp', u'pcintgov', u'pcdebt', u'pc_ap', u'w_rook_i', u'w_queen_i', u'w_db_b_i', u'w_db_c_i', u'w_kern_i', u'w_rook_i_ap', u'w_queen_i_ap', u'w_db_b_i_ap', u'w_db_c_i_ap', u'w_kern_i_ap', u'w_rook_g', u'w_queen_g', u'w_db_b_g', u'w_db_c_g', u'w_kern_g', u'w_rook_g_ap', u'w_queen_g_ap', u'w_db_b_g_ap', u'w_db_c_g_ap', u'w_kern_g_ap', u'fipsc', u'fipscty', u'year', u'ap', u'pcap', u'pcap_mean', u'pcap_rel', u'gsp', u'pcap_rel2', u'LG_ID', u'REV_CTF', u'EXP_DEBT_SERVICE_GEN', u'EXP_TRANSFER_OUT', u'ST_SALES_TAX_PAID', u'EXP_CAPITAL_OUTLAY', u'EXP_JUDICIAL', u'db', u'EXP_HEALTH', u'EXP_FIRE', u'EXP_OTHER_PUBLIC_WORKS', u'REV_FRANCHISE_TAX', u'POPULATION', u'EXP_GEN_GOVT', u'LIABILITIES', u'EXP_TOTAL_PUBLIC_SAFETY', u'REV_LODGING_TAX', u'ALL_OTHER_INTGOVT', u'REVENUE_DEBT_GEN', u'EXP_MISC', u'REV_OTHER_TAX', u'REV_UNCLASS_TAX', u'db_temp', u'GO_DEBT_GEN', u'OTHER_DEBT_GEN', u'sorting_id', u'EXP_SOCIAL_SERVICE', u'EXP_PRINCIPAL_GEN', u'REV_MOTOR_VEH_FEE', u'REV_TRANSFER_IN', u'EXP_RECREATION', u'EXP_POLICE', u'EXP_INTEREST_GEN', u'NAME_x', u'NAME_y', u'EXP_OTHER_PUBLIC_SAFETY', u'REV_CHARGES', u'EXP_TOTAL_PUBLIC_WORKS', ...], dtype='object')

# %% [markdown]
# Moving on to assessment data, we can leverage the file provided by the Colorado Division of Local Affairs that provides time series data on assessment base by county and class of property.  The data were summarized into residential and non-residential categories in the script called *tabor_score*.  Further, the market values were estimated by leveraging residential and non-residential rate history.  *This is an imperfect measure insofar as applying the rate to these group portions of the base ignores both exempt property value and the differential treatment of personal property*.  The former issue is not a big deal, because we really only care about the growth in the taxable base.  The latter, however, is an issue since we do not know how much of the base personal property commands.
#
# I should ask whether personal property is housed solely under the Residential class, or if it occurs elsewhere as well.
#
# In any event, here is the summary data...

# %%
co_asmt=pd.read_csv(wd2+'co_cty_asmt.csv')[pd.read_csv(wd2+'co_cty_asmt.csv').columns[1:]]
co_asmt['cty'].replace('Park\\','Park',inplace=True)

print co_asmt

HTML(co_asmt.head(10).to_html())
# Out:
#           cty       resid       total  year   non_resid  res_rate  nonres_rate       res_val    nonres_val
# 0       Adams   705269720  1632609350  1993   927339630    0.1286         0.29  5.484212e+09  3.197723e+09
# 1       Adams   742865190  1684395240  1994   941530050    0.1286         0.29  5.776557e+09  3.246655e+09
# 2       Adams   813385250  1814600930  1995  1001215680    0.1036         0.29  7.851209e+09  3.452468e+09
# 3       Adams   853089120  1898365960  1996  1045276840    0.1036         0.29  8.234451e+09  3.604403e+09
# 4       Adams   955203880  2094081960  1997  1138878080    0.0974         0.29  9.807021e+09  3.927166e+09
# 5       Adams  1003073550  2204397180  1998  1201323630    0.0974         0.29  1.029850e+10  4.142495e+09
# 6       Adams  1181599650  2552946760  1999  1371347110    0.0974         0.29  1.213141e+10  4.728783e+09
# 7       Adams  1257611690  2706528490  2000  1448916800    0.0974         0.29  1.291182e+10  4.996265e+09
# 8       Adams  1568125310  3301114460  2001  1732989150    0.0915         0.29  1.713798e+10  5.975825e+09
# 9       Adams  1581702560  3343110670  2002  1761408110    0.0915         0.29  1.728637e+10  6.073821e+09
# 10      Adams  1730702090  3609794180  2003  1879092090    0.0796         0.29  2.174249e+10  6.479628e+09
# 11      Adams  1824215350  3765774100  2004  1941558750    0.0796         0.29  2.291728e+10  6.695030e+09
# 12      Adams  2005601680  4118305220  2005  2112703540    0.0796         0.29  2.519600e+10  7.285185e+09
# 13      Adams  2090024670  4246997040  2006  2156972370    0.0796         0.29  2.625659e+10  7.437836e+09
# 14      Adams  2136421180  4524060000  2007  2387638820    0.0796         0.29  2.683946e+10  8.233237e+09
# 15      Adams  2177583150  4659254010  2008  2481670860    0.0796         0.29  2.735657e+10  8.557486e+09
# 16      Adams  2005689060  4598155740  2009  2592466680    0.0796         0.29  2.519710e+10  8.939540e+09
# 17      Adams  2015295810  4601619680  2010  2586323870    0.0796         0.29  2.531779e+10  8.918358e+09
# 18      Adams  1966947450  4568563790  2011  2601616340    0.0796         0.29  2.471040e+10  8.971091e+09
# 19      Adams  1983416840  4622808830  2012  2639391990    0.0796         0.29  2.491730e+10  9.101352e+09
# 20    Alamosa    20978680    64233640  1993    43254960    0.1286         0.29  1.631313e+08  1.491550e+08
# 21    Alamosa    21551860    68170650  1994    46618790    0.1286         0.29  1.675883e+08  1.607544e+08
# 22    Alamosa    21090890    68533240  1995    47442350    0.1036         0.29  2.035800e+08  1.635943e+08
# 23    Alamosa    22275310    70148290  1996    47872980    0.1036         0.29  2.150126e+08  1.650792e+08
# 24    Alamosa    25394010    78460170  1997    53066160    0.0974         0.29  2.607188e+08  1.829868e+08
# 25    Alamosa    26214120    81288350  1998    55074230    0.0974         0.29  2.691388e+08  1.899111e+08
# 26    Alamosa    29715900    88056760  1999    58340860    0.0974         0.29  3.050914e+08  2.011754e+08
# 27    Alamosa    30653970    92072460  2000    61418490    0.0974         0.29  3.147225e+08  2.117879e+08
# 28    Alamosa    33900440    99209940  2001    65309500    0.0915         0.29  3.704966e+08  2.252052e+08
# 29    Alamosa    34958800   105082050  2002    70123250    0.0915         0.29  3.820634e+08  2.418043e+08
# ...       ...         ...         ...   ...         ...       ...          ...           ...           ...
# 1250     Weld   853159900  2482938090  2003  1629778190    0.0796         0.29  1.071809e+10  5.619925e+09
# 1251     Weld   918193420  2992560970  2004  2074367550    0.0796         0.29  1.153509e+10  7.152992e+09
# 1252     Weld  1051660420  3613201510  2005  2561541090    0.0796         0.29  1.321181e+10  8.832900e+09
# 1253     Weld  1133000390  4188145450  2006  3055145060    0.0796         0.29  1.423367e+10  1.053498e+10
# 1254     Weld  1216058280  4462988390  2007  3246930110    0.0796         0.29  1.527711e+10  1.119631e+10
# 1255     Weld  1259424810  4579338460  2008  3319913650    0.0796         0.29  1.582192e+10  1.144798e+10
# 1256     Weld  1147452920  5779693520  2009  4632240600    0.0796         0.29  1.441524e+10  1.597324e+10
# 1257     Weld  1161744960  4625444510  2010  3463699550    0.0796         0.29  1.459479e+10  1.194379e+10
# 1258     Weld  1110638520  5423868510  2011  4313229990    0.0796         0.29  1.395275e+10  1.487321e+10
# 1259     Weld  1126180660  6515719690  2012  5389539030    0.0796         0.29  1.414800e+10  1.858462e+10
# 1260     Yuma    14512870    94055820  1993    79542950    0.1286         0.29  1.128528e+08  2.742860e+08
# 1261     Yuma    14781260   101446700  1994    86665440    0.1286         0.29  1.149398e+08  2.988463e+08
# 1262     Yuma    12921110   104977800  1995    92056690    0.1036         0.29  1.247211e+08  3.174369e+08
# 1263     Yuma    13321400   122418660  1996   109097260    0.1036         0.29  1.285849e+08  3.761974e+08
# 1264     Yuma    15204940   138296270  1997   123091330    0.0974         0.29  1.561082e+08  4.244529e+08
# 1265     Yuma    16055980   147303690  1998   131247710    0.0974         0.29  1.648458e+08  4.525783e+08
# 1266     Yuma    18054860   158778450  1999   140723590    0.0974         0.29  1.853682e+08  4.852538e+08
# 1267     Yuma    18425700   155153980  2000   136728280    0.0974         0.29  1.891756e+08  4.714768e+08
# 1268     Yuma    20404760   172606220  2001   152201460    0.0915         0.29  2.230028e+08  5.248326e+08
# 1269     Yuma    20985700   173277400  2002   152291700    0.0915         0.29  2.293519e+08  5.251438e+08
# 1270     Yuma    20925610   155650790  2003   134725180    0.0796         0.29  2.628845e+08  4.645696e+08
# 1271     Yuma    21329220   197071380  2004   175742160    0.0796         0.29  2.679550e+08  6.060074e+08
# 1272     Yuma    23744240   213923030  2005   190178790    0.0796         0.29  2.982945e+08  6.557889e+08
# 1273     Yuma    24074760   268387290  2006   244312530    0.0796         0.29  3.024467e+08  8.424570e+08
# 1274     Yuma    26171380   300168970  2007   273997590    0.0796         0.29  3.287862e+08  9.448193e+08
# 1275     Yuma    26508680   327225690  2008   300717010    0.0796         0.29  3.330236e+08  1.036955e+09
# 1276     Yuma    27896690   420370550  2009   392473860    0.0796         0.29  3.504609e+08  1.353358e+09
# 1277     Yuma    28231110   272473200  2010   244242090    0.0796         0.29  3.546622e+08  8.422141e+08
# 1278     Yuma    28649160   290876520  2011   262227360    0.0796         0.29  3.599141e+08  9.042323e+08
# 1279     Yuma    28990550   280928960  2012   251938410    0.0796         0.29  3.642029e+08  8.687531e+08
#
# [1280 rows x 9 columns]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cty</th>
#       <th>resid</th>
#       <th>total</th>
#       <th>year</th>
#       <th>non_resid</th>
#       <th>res_rate</th>
#       <th>nonres_rate</th>
#       <th>res_val</th>
#       <th>nonres_val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> Adams</td>
#       <td>  705269720</td>
#       <td> 1632609350</td>
#       <td> 1993</td>
#       <td>  927339630</td>
#       <td> 0.1286</td>
#       <td> 0.29</td>
#       <td> 5.484212e+09</td>
#       <td> 3.197723e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> Adams</td>
#       <td>  742865190</td>
#       <td> 1684395240</td>
#       <td> 1994</td>
#       <td>  941530050</td>
#       <td> 0.1286</td>
#       <td> 0.29</td>
#       <td> 5.776557e+09</td>
#       <td> 3.246655e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> Adams</td>
#       <td>  813385250</td>
#       <td> 1814600930</td>
#       <td> 1995</td>
#       <td> 1001215680</td>
#       <td> 0.1036</td>
#       <td> 0.29</td>
#       <td> 7.851209e+09</td>
#       <td> 3.452468e+09</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> Adams</td>
#       <td>  853089120</td>
#       <td> 1898365960</td>
#       <td> 1996</td>
#       <td> 1045276840</td>
#       <td> 0.1036</td>
#       <td> 0.29</td>
#       <td> 8.234451e+09</td>
#       <td> 3.604403e+09</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td> Adams</td>
#       <td>  955203880</td>
#       <td> 2094081960</td>
#       <td> 1997</td>
#       <td> 1138878080</td>
#       <td> 0.0974</td>
#       <td> 0.29</td>
#       <td> 9.807021e+09</td>
#       <td> 3.927166e+09</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> Adams</td>
#       <td> 1003073550</td>
#       <td> 2204397180</td>
#       <td> 1998</td>
#       <td> 1201323630</td>
#       <td> 0.0974</td>
#       <td> 0.29</td>
#       <td> 1.029850e+10</td>
#       <td> 4.142495e+09</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td> Adams</td>
#       <td> 1181599650</td>
#       <td> 2552946760</td>
#       <td> 1999</td>
#       <td> 1371347110</td>
#       <td> 0.0974</td>
#       <td> 0.29</td>
#       <td> 1.213141e+10</td>
#       <td> 4.728783e+09</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td> Adams</td>
#       <td> 1257611690</td>
#       <td> 2706528490</td>
#       <td> 2000</td>
#       <td> 1448916800</td>
#       <td> 0.0974</td>
#       <td> 0.29</td>
#       <td> 1.291182e+10</td>
#       <td> 4.996265e+09</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td> Adams</td>
#       <td> 1568125310</td>
#       <td> 3301114460</td>
#       <td> 2001</td>
#       <td> 1732989150</td>
#       <td> 0.0915</td>
#       <td> 0.29</td>
#       <td> 1.713798e+10</td>
#       <td> 5.975825e+09</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td> Adams</td>
#       <td> 1581702560</td>
#       <td> 3343110670</td>
#       <td> 2002</td>
#       <td> 1761408110</td>
#       <td> 0.0915</td>
#       <td> 0.29</td>
#       <td> 1.728637e+10</td>
#       <td> 6.073821e+09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# These data must be deflated using the same CPI figures employed in deflating the fiscal data.  They come from the [FRED](http://research.stlouisfed.org/fred2/) database.

# %%
#Open feed to CPI info
#cpi=web.get_data_fred('USACPIBLS','1/1/1975','1/1/2009')

#Create copy in case offline work is occurring
#cpi.to_csv(workdir+'us_cpi_1975_2009.csv')

#Read in hard copy when API queries are exhausted
cpi=pd.read_csv(wd2+'us_cpi_1975_2009.csv')

#Create common index for later join with data
cpi['AUDIT_YEAR']=range(1975,2010)
cpi2=cpi.reset_index().set_index('AUDIT_YEAR')

#Rename columns
cpi2.columns=['index','DATE','CPI']

#Drop DATE and index
cpi2.pop('DATE')
cpi2.pop('index')

#Calculate deflator ratios
dfl=cpi2.div(cpi2.ix[2009])

#Reintegrate initial CPI figures
dfl['cpi']=cpi2['CPI']

#Calculate annual growth in inflation
dfl['cpi_growth']=dfl['cpi'].pct_change()

#Rename columns
dfl.columns=['defl','cpi','cpi_growth']

dfl.ix[1998:].head()
# Out:
#                 defl    cpi  cpi_growth
# AUDIT_YEAR
# 1998        0.759907  163.0    0.015576
# 1999        0.776690  166.6    0.022086
# 2000        0.802797  172.2    0.033613
# 2001        0.825641  177.1    0.028455
# 2002        0.838695  179.9    0.015810

# %% [markdown]
# Now the assessment data must actually be delated.

# %%
#Merge deflator info in with assessment data
co_asmt_temp=pd.merge(co_asmt,dfl.reset_index(),how='left',left_on='year',right_on='AUDIT_YEAR')

#Set index
co_asmt2=co_asmt_temp.set_index(['year','cty'])

#Divide the level columns ['resid','total','non_resid','res_val','nonres_va'] by the deflator
co_asmt_real=co_asmt2[['resid','total','non_resid','res_val','nonres_val']].div(co_asmt2['defl'],axis=0)

#Rename columns
co_asmt_real.columns=['real_resid','real_total','real_non_resid','real_res_val','real_nonres_val']

#Merge real values back in
co_asmt_r=pd.merge(co_asmt_real,co_asmt2,left_index=True,right_index=True)

# %% [markdown]
# These data must also be integrated into the master set.

# %%
co_sfda=pd.merge(co_sfd,co_asmt_r.reset_index(),how='left',left_on=['AUDIT_YEAR','FNAME'], \
                 right_on=['year','cty']).rename(columns={'AUDIT_YEAR_x':'AUDIT_YEAR'})

# for i in range(30):
#     print co_sfda[co_sfda.columns[i*5:(i+1)*5]].head(),'\n'
    
# HTML(co_sfda.describe().T.to_html())

#Write to disk
co_sfda.to_csv(workdir+'CO_sfda.csv')

# %% [markdown]
# Finally, we need business cycle information by county.  The county-specific unemployment rate data (1990-2012) provided by the [Bureau of Labor Statistics](http://www.bls.gov/lau/#cntyaa).

# %%
# def labor_data(year):
#     '''Reads BLS data from web source as fixed width, converts to DataFrame, and subset to Colorado'''
#     #Set column widths (from 2012 example)
#     column_width_list=[(0,9),(11,15),(18,22),(24,72),(73,78),(83,93),(95,105),(108,117),(121,126)]
    
#     #Read data from BLS website
#     ue=pd.read_fwf('http://www.bls.gov/lau/laucnty'+year+'.txt',colspecs=column_width_list,skiprows=5)
    
#     #Rename columns
#     ue.columns=['laus_code','st_fips','cty_fips','cty_name','AUDIT_YEAR','labforce','emp','unemp','unemp_rate']

#     #Subset to Colorado
#     if isinstance(ue['st_fips'],basestring):
#         ue_co=ue[ue['st_fips']=='08']
#     else:
#         ue_co=ue[ue['st_fips']==8]
#     print ue.head()
#     print ue_co.head()    
    
#     return ue_co

# #Create containers for year specific data
# labor_df_list=[]

# #For each year...
# for i in range(1990,2013):
#     print i
#     #...read and process data, and then throw it in the container
#     labor_df_list.append(labor_data(str(i)[2:]))

# #Concatenate to one DF
# co_labor=pd.concat(labor_df_list)

# print co_labor

# %% [markdown]
# In tinkering with the function, it looks like I have exhausted my BLS API calls for the day, so I just downloaded the table into an intermediate .csv.  Furthermore, rather than read and convert state unemplyment rates, it was easier just to grab the data via a dictionary.

# %%
#Read in data, and stack year values
co_bls=pd.read_csv(wd2+'CO_BLS_labor.csv').set_index('Series_ID').stack().reset_index()

#Rename columns
co_bls.columns=['Series_ID','AUDIT_YEAR_temp','val']

#Convert AUDIT_YEAR to int and drop temp
co_bls['AUDIT_YEAR']=co_bls['AUDIT_YEAR_temp'].astype(int)
co_bls.pop('AUDIT_YEAR_temp')

#Split out series indicator component of the Series ID
co_bls['indic_code']=co_bls['Series_ID'].apply(lambda x: x[-3:])

#Create dict to map descriptions to indic_code
indic_dict={'003':'unemp_rate',
            '004':'unemp',
            '005':'emp',
            '006':'labforce'}

#Define new indicator description variable
co_bls['indic']=co_bls['indic_code'].map(indic_dict)

#Split out county fips ID and area type from Series_ID
co_bls['fipscty_str']=co_bls['Series_ID'].apply(lambda x: x[7:10])
co_bls['fipscty']=co_bls['fipscty_str'].astype(int)
co_bls['atype']=co_bls['Series_ID'].apply(lambda x: x[3:5])

#Drop the now useless Series_ID and indic_code
co_bls.pop('Series_ID')
co_bls.pop('indic_code')

#Unstack indicators into separate columns
co_labor_temp=co_bls[co_bls['atype']=='CN'].set_index(['atype','fipscty','fipscty_str',\
                                                       'indic','AUDIT_YEAR']).unstack(level='indic')

#Rename columns (drop val level)
co_labor_temp.columns=['emp','labforce','unemp','unemp_rate']

#Reset index
co_labor=co_labor_temp.reset_index()

HTML(co_labor.head(10).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>atype</th>
#       <th>fipscty</th>
#       <th>fipscty_str</th>
#       <th>AUDIT_YEAR</th>
#       <th>emp</th>
#       <th>labforce</th>
#       <th>unemp</th>
#       <th>unemp_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1990</td>
#       <td> 132892</td>
#       <td> 140949</td>
#       <td> 8057</td>
#       <td> 5.7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1991</td>
#       <td> 134868</td>
#       <td> 142668</td>
#       <td> 7800</td>
#       <td> 5.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1992</td>
#       <td> 137948</td>
#       <td> 146510</td>
#       <td> 8562</td>
#       <td> 5.8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1993</td>
#       <td> 143050</td>
#       <td> 151092</td>
#       <td> 8042</td>
#       <td> 5.3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1994</td>
#       <td> 151859</td>
#       <td> 158830</td>
#       <td> 6971</td>
#       <td> 4.4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1995</td>
#       <td> 159186</td>
#       <td> 165754</td>
#       <td> 6568</td>
#       <td> 4.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1996</td>
#       <td> 162391</td>
#       <td> 169548</td>
#       <td> 7157</td>
#       <td> 4.2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1997</td>
#       <td> 167950</td>
#       <td> 173611</td>
#       <td> 5661</td>
#       <td> 3.3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1998</td>
#       <td> 174580</td>
#       <td> 180636</td>
#       <td> 6056</td>
#       <td> 3.4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td> CN</td>
#       <td> 1</td>
#       <td> 001</td>
#       <td> 1999</td>
#       <td> 178407</td>
#       <td> 183583</td>
#       <td> 5176</td>
#       <td> 2.8</td>
#     </tr>
#   </tbody>
# </table>

# %%
state_unemp_dict={1987:7.5,
                  1988:6.4,
                  1989:5.6,
                  1990:5.1,
                  1991:5.4,
                  1992:6.0,
                  1993:5.3,
                  1994:4.3,
                  1995:4.0,
                  1996:4.2,
                  1997:3.4,
                  1998:3.5,
                  1999:3.0,
                  2000:2.7,
                  2001:3.8,
                  2002:5.7,
                  2003:6.1,
                  2004:5.6,
                  2005:5.1,
                  2006:4.3,
                  2007:3.8,
                  2008:4.8,
                  2009:8.1,
                  2010:9.0,
                  2011:8.6,
                  2012:8.0}

# %%
for var in co_labor.columns:
    if 'fipscty' in var:
        print var
        
print co_sf.head()['fipscty']
# Out:
# fipscty
# fipscty_str
# 0    53
# 1    29
# 2    47
# 3    23
# 4    57
# Name: fipscty, dtype: int64

# %% [markdown]
# We can now integrate the labor force information, integrate statewide unemployment information, and conclude the primary data management portion of the script.

# %%
#Rename merge key
# co_sfda['fipscty']=co_sfda['fipscty_x']

#Drop extraneous variables
co_sfda2=co_sfda[[var for var in co_sfda.columns if var != 'fipscty']]

#Merge labor component in
co_sfdal=pd.merge(co_sfda.reset_index(),co_labor,how='left',on=['fipscty','AUDIT_YEAR'])

#Include state unemployment rate
co_sfdal['st_unempr']=co_sfdal['AUDIT_YEAR'].map(state_unemp_dict)

co_sfdal
#HTML(co_sfdal.describe().T.to_html())
# Out:
#       level_0  Unnamed: 0        ALAND    AWATER  CBSAFP CLASSFP  COUNTYFP  COUNTYNS  CSAFP FUNCSTAT   ...         defl    cpi  \
# 0           0           0   2893573835  15324680     NaN      H1        53    198142    NaN        A   ...          NaN    NaN
# 1           1           1   2957922894  16953424     NaN      H1        29    198130    NaN        A   ...          NaN    NaN
# 2           2           2    388229141    941898   19740      H1        47    198139    216        A   ...          NaN    NaN
# 3           3           3   3177803460   8828904     NaN      H1        23    198127    NaN        A   ...          NaN    NaN
# 4           4           4   4179563675  18750018     NaN      H1        57    198144    NaN        A   ...          NaN    NaN
# 5           5           5   2624702134   4013482     NaN      H1        15    198123    NaN        A   ...          NaN    NaN
# 6           6           6   4793688729    442148   19740      H1        39    198136    216        A   ...          NaN    NaN
# 7           7           7   1442738671   4944573   17820      H1       119    198175    NaN        A   ...          NaN    NaN
# 8           8           8   4243419913  15352633     NaN      H1        99    198165    NaN        A   ...          NaN    NaN
# 9           9           9   1419419287   3530746     NaN      H1       115    198173    NaN        A   ...          NaN    NaN
# 10         10          10    396198354   4222992   19740      H6        31    198131    216        C   ...          NaN    NaN
# 11         11          11   2361929110    984917     NaN      H1       105    198168    NaN        A   ...          NaN    NaN
# 12         12          12   5256407750  27516850     NaN      H1        83    198157    NaN        A   ...          NaN    NaN
# 13         13          13  12284921637  19806932     NaN      H1        81    198156    NaN        A   ...          NaN    NaN
# 14         14          14   3334263504   9235291     NaN      H1        21    198126    NaN        A   ...          NaN    NaN
# 15         15          15   4382658416  19545450   20420      H1        67    198148    NaN        A   ...          NaN    NaN
# 16         16          16   2763645279   2716141     NaN      H1        33    198132    NaN        A   ...          NaN    NaN
# 17         17          17   5596501541   2251930     NaN      H1        63    198147    NaN        A   ...          NaN    NaN
# 18         18          18  10326885138  76675362   24540      H1       123    198177    216        A   ...          NaN    NaN
# 19         19          19   4578600049  47032937     NaN      H1        61    198146    NaN        A   ...          NaN    NaN
# 20         20          20   8207226426   4454545     NaN      H1       109    198170    NaN        A   ...          NaN    NaN
# 21         21          21   6521817532  15207414     NaN      H1       121    198176    NaN        A   ...          NaN    NaN
# 22         22          22   3496904695  13827548     NaN      H1         7    198119    NaN        A   ...          NaN    NaN
# 23         23          23   6617316468   6142193     NaN      H1         9    198120    NaN        A   ...          NaN    NaN
# 24         24          24   2176207910   6769100   19740      H1        35    198133    216        A   ...          NaN    NaN
# 25         25          25   6179976224  30284066   39380      H1       101    198166    NaN        A   ...          NaN    NaN
# 26         26          26   4362916056  18803966   20780      H1        37    198134    NaN        A   ...          NaN    NaN
# 27         27          27   1781724999    301808     NaN      H1        95    198163    NaN        A   ...          NaN    NaN
# 28         28          28   8342198615   4868111     NaN      H1       103    198167    NaN        A   ...          NaN    NaN
# 29         29          29   6117633825  15831696     NaN      H1       107    198169    NaN        A   ...          NaN    NaN
# ...       ...         ...          ...       ...     ...     ...       ...       ...    ...      ...   ...          ...    ...
# 1442     1442        1442   7634471698  21430626     NaN      H1        45    198138    NaN        A   ...     0.690909  148.2
# 1443     1443        1443   5508460909   7111548   17820      H1        41    198135    NaN        A   ...     0.690909  148.2
# 1444     1444        1444   2268230027   5222170     NaN      H1        79    198155    NaN        A   ...     0.690909  148.2
# 1445     1445        1445   5682134218  43530467   19740      H1        93    198162    216        A   ...     0.690909  148.2
# 1446     1446        1446   4120753930   5792107     NaN      H1        55    198143    NaN        A   ...     0.690909  148.2
# 1447     1447        1447   3918307819  73093700     NaN      H1        11    198121    NaN        A   ...     0.690909  148.2
# 1448     1448        1448   1023554447   3280081   19740      H1        19    198125    216        A   ...     0.690909  148.2
# 1449     1449        1449    976206766  18110615   20780      H1        65    198149    NaN        A   ...     0.690909  148.2
# 1450     1450        1450   4605714106   8166145     NaN      H1        17    198124    NaN        A   ...     0.690909  148.2
# 1451     1451        1451  12361253683   6929976     NaN      H1        71    198151    NaN        A   ...     0.690909  148.2
# 1452     1452        1452   1913033457   3364740     NaN      H1        27    198129    NaN        A   ...     0.690909  148.2
# 1453     1453        1453   1871620246   1847609     NaN      H1         3    198117    NaN        A   ...     0.690909  148.2
# 1454     1454        1454   6123751576  11134682     NaN      H1       125    198178    NaN        A   ...     0.690909  148.2
# 1455     1455        1455   8622131029  31435336   24300      H1        77    198154    NaN        A   ...     0.690909  148.2
# 1456     1456        1456   4781807818  60250181     NaN      H1        49    198140    NaN        A   ...     0.690909  148.2
# 1457     1457        1457   1402725842   1599543     NaN      H1        91    198161    NaN        A   ...     0.690909  148.2
# 1458     1458        1458   8389491951  53067063     NaN      H1        51    198141    NaN        A   ...     0.690909  148.2
# 1459     1459        1459   3332207690   5213860     NaN      H1       113    198172    NaN        A   ...     0.690909  148.2
# 1460     1460        1460   3316112929  34663780   22820      H1        87    198159    NaN        A   ...     0.690909  148.2
# 1461     1461        1461   6723779313  98113981   22660      H1        69    198150    NaN        A   ...     0.690909  148.2
# 1462     1462        1462   3268485084  20052353     NaN      H1        89    198160    NaN        A   ...     0.690909  148.2
# 1463     1463        1463   2514071663   6469378     NaN      H1        97    198164    NaN        A   ...     0.690909  148.2
# 1464     1464        1464   6676208280  22780444     NaN      H1        73    198152    NaN        A   ...     0.690909  148.2
# 1465     1465        1465   2039409780  33430387     NaN      H1        25    198128    NaN        A   ...     0.690909  148.2
# 1466     1466        1466   1003640124   2035929     NaN      H1       111    198171    NaN        A   ...     0.690909  148.2
# 1467     1467        1467   3970604102   2235391   15860      H1        43    198137    NaN        A   ...     0.690909  148.2
# 1468     1468        1468   1979243247  25485250   19740      H1        59    198145    216        A   ...     0.690909  148.2
# 1469     1469        1469   2066605764  19528578   19740      H1         5    198118    216        A   ...     0.690909  148.2
# 1470     1470        1470     85415592   1464123   19740      H6        14   1945881    216        C   ...     0.690909  148.2
# 1471     1471        1471   1881236301  36605899   14500      H1        13    198122    216        A   ...     0.690909  148.2
#
#       cpi_growth  atype  fipscty_str     emp labforce unemp  unemp_rate  st_unempr
# 0            NaN     CN          053     437      469    32         6.8        6.0
# 1            NaN     CN          029    7992     8797   805         9.2        6.0
# 2            NaN     CN          047    2691     2831   140         4.9        6.0
# 3            NaN     CN          023    1446     1610   164        10.2        6.0
# 4            NaN     CN          057     909      972    63         6.5        6.0
# 5            NaN     CN          015    5752     6179   427         6.9        6.0
# 6            NaN     CN          039    5923     6274   351         5.6        6.0
# 7            NaN     CN          119    8229     8856   627         7.1        6.0
# 8            NaN     CN          099    5599     5974   375         6.3        6.0
# 9            NaN     CN          115    1156     1204    48         4.0        6.0
# 10           NaN    NaN          NaN     NaN      NaN   NaN         NaN        6.0
# 11           NaN     CN          105    4465     5088   623        12.2        6.0
# 12           NaN     CN          083    9013    10000   987         9.9        6.0
# 13           NaN     CN          081    5688     6217   529         8.5        6.0
# 14           NaN     CN          021    2758     3150   392        12.4        6.0
# 15           NaN     CN          067   18017    19343  1326         6.9        6.0
# 16           NaN     CN          033     608      728   120        16.5        6.0
# 17           NaN     CN          063    3131     3278   147         4.5        6.0
# 18           NaN    NaN          NaN     NaN      NaN   NaN         NaN        6.0
# 19           NaN     CN          061     782      820    38         4.6        6.0
# 20           NaN     CN          109    2048     2371   323        13.6        6.0
# 21           NaN     CN          121    2092     2174    82         3.8        6.0
# 22           NaN     CN          007    2597     2833   236         8.3        6.0
# 23           NaN     CN          009    1990     2061    71         3.4        6.0
# 24           NaN     CN          035   40163    41767  1604         3.8        6.0
# 25           NaN    NaN          NaN     NaN      NaN   NaN         NaN        6.0
# 26           NaN     CN          037   13202    14147   945         6.7        6.0
# 27           NaN     CN          095    1676     1737    61         3.5        6.0
# 28           NaN     CN          103    3306     3528   222         6.3        6.0
# 29           NaN     CN          107    8304     8920   616         6.9        6.0
# ...          ...    ...          ...     ...      ...   ...         ...        ...
# 1442    0.025606     CN          045   19019    19831   812         4.1        4.3
# 1443    0.025606    NaN          NaN     NaN      NaN   NaN         NaN        4.3
# 1444    0.025606     CN          079     344      379    35         9.2        4.3
# 1445    0.025606     CN          093    6298     6579   281         4.3        4.3
# 1446    0.025606     CN          055    2832     3041   209         6.9        4.3
# 1447    0.025606     CN          011    2183     2253    70         3.1        4.3
# 1448    0.025606     CN          019    4687     4928   241         4.9        4.3
# 1449    0.025606     CN          065    2896     3087   191         6.2        4.3
# 1450    0.025606     CN          017    1110     1135    25         2.2        4.3
# 1451    0.025606     CN          071    5855     6164   309         5.0        4.3
# 1452    0.025606     CN          027    1278     1332    54         4.1        4.3
# 1453    0.025606     CN          003    7116     7563   447         5.9        4.3
# 1454    0.025606     CN          125    4019     4123   104         2.5        4.3
# 1455    0.025606    NaN          NaN     NaN      NaN   NaN         NaN        4.3
# 1456    0.025606     CN          049    4954     5121   167         3.3        4.3
# 1457    0.025606     CN          091    1498     1563    65         4.2        4.3
# 1458    0.025606     CN          051    7152     7590   438         5.8        4.3
# 1459    0.025606     CN          113    3980     4127   147         3.6        4.3
# 1460    0.025606     CN          087   11981    12492   511         4.1        4.3
# 1461    0.025606    NaN          NaN     NaN      NaN   NaN         NaN        4.3
# 1462    0.025606     CN          089    8145     8639   494         5.7        4.3
# 1463    0.025606     CN          097    8625     9054   429         4.7        4.3
# 1464    0.025606     CN          073    2465     2530    65         2.6        4.3
# 1465    0.025606     CN          025    1199     1257    58         4.6        4.3
# 1466    0.025606     CN          111     271      317    46        14.5        4.3
# 1467    0.025606     CN          043   15177    16106   929         5.8        4.3
# 1468    0.025606     CN          059  276736   286536  9800         3.4        4.3
# 1469    0.025606    NaN          NaN     NaN      NaN   NaN         NaN        4.3
# 1470    0.025606     CN          014   16280    16761   481         2.9        4.3
# 1471    0.025606     CN          013  142961   148680  5719         3.8        4.3
#
# [1472 rows x 164 columns]

# %% [markdown]
# **LATE EDITION:** Adding in expenditures and revenues for all governments in the county from CenStats data.

# %%
#Establish all gov data location
all_gov_dir='../censtat/'

#Read in county aggregate finances (across all govs in county)
agd=pd.read_csv(all_gov_dir+'tot_cty_fin.csv').rename(columns={'year':'AUDIT_YEAR',
                                                               'cty':'FNAME'})

#Set index
agd.set_index(['FNAME','AUDIT_YEAR'],inplace=True)

#Set index of co_sfdal
co_sfdal2=co_sfdal.set_index(['FNAME','AUDIT_YEAR']).sortlevel(0)

#Join in data
for col in agd.columns:
    co_sfdal2[col]=agd[col].ix[co_sfdal2.index].values

co_sfdal2[co_sfdal2['all_gov_exp'].notnull()][co_sfdal2.columns[:3]+agd.columns].head(20)
# Out:
#                          ALAND  Unnamed: 0  all_gov_exp  all_gov_rev  level_0
# FNAME   AUDIT_YEAR
# Adams   1992        3024201147          31     580640.0     582779.0       31
#         1993        3024201147          95     606366.0     621025.0       95
#         1994        3024201147        1439     632092.0     659271.0     1439
#         1995        3024201147         479     657817.0     697518.0      479
#         1996        3024201147         287     683543.0     735764.0      287
#         1997        3024201147         351     709269.0     774010.0      351
#         1998        3024201147         671     818231.0     861324.0      671
#         1999        3024201147         735     927192.0     948638.0      735
#         2000        3024201147        1119    1036154.0    1035952.0     1119
#         2001        3024201147        1055    1145115.0    1123266.0     1055
#         2002        3024201147        1247    1254077.0    1210580.0     1247
#         2003        3024201147        1183    1321420.7    1273360.1     1183
#         2004        3024201147         863    1388764.4    1336140.2      863
#         2005        3024201147         799    1456108.1    1398920.3      799
#         2006        3024201147         991    1523451.8    1461700.4      991
#         2007        3024201147         927    1590795.5    1524480.5      927
#         2008        3024201147        1375    1658139.2    1587260.6     1375
#         2009        3024201147        1311    1725482.9    1650040.7     1311
# Alamosa 1992        1871620246          45      35778.0      28767.0       45
#         1993        1871620246         109      38229.0      31084.2      109

# %% [markdown]
# ## Model Specification

# %% [markdown]
# The model used in the initial stab (*CO_TEL_convergence*) at explaining variance in revenue yield was very limited, both in terms of the regressors included and the explanatory power of the model.  Rehashing this analysis provides an opportunity to think more deeply about the relationships we may exploit.
#
# In general, there are three phenomenon we wish to explain as a function of TEL intensity:
#
# 1. **Economic Capacity** - *Regardless of the explicit fiscal choices made, what is the economic carrying capacity within a given jurisdiction?*
#
#     + Ultimately, the dynamic impact of TELs on economic growth is the top line goal of this inquiry.  This is a somewhat brute force method of exploring that impact, but it is likely to blunt an instrument to sufficiently capture the causal mechanism.
#     + Additional Regressors:
#         + Previous year's capacity
#         + Weighted average of local neighborhood's capacities
#         + Gross state product
#         + Business cycle
#             + State unemployment rate
#         + Demand for housing in jurisdiction
#             + Housing permits/Housing units
#             + Vacancy rate
#         + Labor concentration
#             + Labor force/Population (for now, incomplete county coverage prohibits inclusion)
#
# 2. **Revenue Yield** - *How much revenue is generated per capita in a given jurisdiction?*
#
#     + There are actually two ways to think about this.  The most direct method would be as an autonomous model, that may then be compared to the economic capacity model.  The second method seeks to integrate both economic capacity and revenue yield via a hierarchical model.  Given the "carrying capacity" of a given jurisdiction, the yield per capita may be represented as tax effort.
#     + Additional Regressors:
#         + Previous year's revenue
#         + Weighted average of local neighborhood's yields
#         + Gross state product
#         + Demand for services
#             + Lagged natural population growth
#         + Business cycle
#             + State unemployment rate
#         + Demand for housing in jurisdiction
#             + Housing permits/Housing units
#             + Vacancy rate
#         + Economic capacity
#             + Annual payroll per capita
#         + Labor concentration
#             + Labor force/Population (for now, incomplete county coverage prohibits inclusion)
#
# 3. **Spatial Clustering** - *How much does a given jurisdiction look like its local neighborhood?*
#
#     + From an operational standpoint, we want to know 1) if TELs cause a jurisdiction to look more or less like it's local neighborhood, and 2) if TELs are more likely to cause clustering among low capacity jurisdictions or high capacity jurisdictions.  Local Moran's I and Getis & Ord's G* estimates provide the means to evaluate these statements, respectively.  This would, of course, need to be run for both contiguity and distance based weight matrices.
#     + Additional Regressors:
#         + Previous year's clustering value
#         + Gross state product
#         + Demand for services
#             + Lagged natural population growth
#         + Business cycle
#             + State unemployment rate
#         + Demand for housing in jurisdiction and the local neighborhood
#             + Housing permits/Housing units
#             + Vacancy rate
#         + Economic capacity
#             + Annual payroll per capita
#         + Labor concentration
#             + Labor force/Population (for now, incomplete county coverage prohibits inclusion)
#
# Furthermore, we must explore whether or not these behaviors change with different economic starting conditions.  Consequently, after the initial runs on the full set, we will run the same analyses on subsets of the data split by per capita annual payroll quintiles in year 0.

# %% [markdown]
# #### TEL Intensity

# %% [markdown]
# We also need to develop a method of evaluating TEL intensity on a given county.  To borrow from the *tabor_score* Notebook, measuring the impact of TELs requires four components:
#
#
# 1. Comparison between the growth in the total property tax base (residential and commercial) with the statewide property tax growth limitation of 5.5% annually.  We can measure the rate of growth of the assessment base.
#     + Total Property Tax Base Growth = $\frac{resid_t + non\_resid_t}{resid_{t-1} + non\_resid_{t-1}} - 1$
# 2. Comparison between the growth in total property base and the percentage growth value attributable to inflation plus new construction. (Note that the growth factor for school districts is actually enrollment figures, so this measure would be imperfect pending greater jurisdictional resolution.)  This is quite similar to the first component, except that the limit is variable instead of fixed at 5.5%.  In practice, the composite limit (Statewide Property Tax Growth Limitation and TABOR) is governed by this relationship below. This limit is modified only when De-Brucing occurs.  De-Brucing may lead the limit to reduce to one of the two arguments in the minimum function, or to disappear entirely.  Either way, the property tax growth is calculated in the same way, and then compared with whichever version of the limit exists for a given county.
#
#    $$PRlimit = min[.055,inflation + construction]$$
#
#
# 3. Comparison the market value growth in residential and non-residential property tax base. This is needed for both the state and county levels. The former is needed only to understand the shift in assessment rates (which are set statewide), and thus could be circumvented by just getting the assessment rates by year. The latter is critical so that we may be able to see the impact of drops in the residential assessment rate by county.  One way to get at this concept would be to compare the ratio of residential to non-residential assessment bases across years.  An increase in the ratio would indicate greater growth in residential assessment value relative to non-residential.
#
# $$ASMT\_RATIO = \frac{Res\_ASMT}{NonRes\_ASMT} = \frac{Res\_VALUE * Res\_RATE}{NonRes\_VALUE * NonRes\_RATE}$$
#
# Maybe I just want the ratio because it tells me about residential concentration as a characteristic of the county.  A residential concentration increases the difficulty of matching revenue growth to the increase in the property-based activity that might benefit from public provision of infrastructure and other services.
#
# Since equivalent increases in market value growth yield slower growth for residential assessment value
#
# 4. State aid allocations by county. These should be available from budgetary information.
#
# To validate these as measures, it would be useful to explore the dynamics of these components over time.

# %% [markdown]
# #### Assessment Base Growth

# %% [markdown]
# The first step is calculating the base growth for residential, non-residential, and total property assessment levels.  Note that we want to avoid the percentage change calculation at the boundary between counties.  Enter the old split-apply-combine.  To keep within county integrity, we will do the following:
#
# 1. Split the data by county
# 2. Calculate the percentage change
# 3. Replace any *inf* with *NaN* (*inf* occurs when a zero value transitions to a non-zero value)
# 4. Concatenate the DF pieces back together into one large DF
#
# We will need housing unit growth later in the script as well, so we might as well calculate that now.

# %%
sorted(co_sfdal2.columns)
# Out:
# ['ALAND',
#  'ALL_OTHER_INTGOVT',
#  'ASSETS',
#  'AUDIT_YEAR',
#  'AUDIT_YEAR_y',
#  'AWATER',
#  'CBSAFP',
#  'CLASSFP',
#  'COUNTYFP',
#  'COUNTYNS',
#  'CSAFP',
#  'CTY_POP',
#  'DFL',
#  'EXP_CAPITAL_OUTLAY',
#  'EXP_DEBT_SERVICE_GEN',
#  'EXP_FIRE',
#  'EXP_GEN_GOVT',
#  'EXP_HEALTH',
#  'EXP_INTEREST_GEN',
#  'EXP_JUDICIAL',
#  'EXP_MISC',
#  'EXP_OTHER_PUBLIC_SAFETY',
#  'EXP_OTHER_PUBLIC_WORKS',
#  'EXP_POLICE',
#  'EXP_PRINCIPAL_GEN',
#  'EXP_RECREATION',
#  'EXP_SOCIAL_SERVICE',
#  'EXP_STREET',
#  'EXP_TOTAL',
#  'EXP_TOTAL_OPERATING',
#  'EXP_TOTAL_PUBLIC_SAFETY',
#  'EXP_TOTAL_PUBLIC_WORKS',
#  'EXP_TRANSFER_OUT',
#  'EXP_TRASH',
#  'FNAME',
#  'FUNCSTAT',
#  'GEOID',
#  'GO_DEBT_GEN',
#  'INTPTLAT',
#  'INTPTLON',
#  'LGID',
#  'LGTYPE_ID',
#  'LG_ID',
#  'LIABILITIES',
#  'LSAD',
#  'METDIVFP',
#  'MTFCC',
#  'NAME',
#  'NAMELSAD',
#  'NAME_x',
#  'NAME_y',
#  'OTHER_DEBT_GEN',
#  'POPULATION',
#  'RETAIL_SALES',
#  'REVENUE_DEBT_GEN',
#  'REV_CHARGES',
#  'REV_CIGARETTE_TAX',
#  'REV_CTF',
#  'REV_FINES',
#  'REV_FRANCHISE_TAX',
#  'REV_HUT',
#  'REV_INTEREST',
#  'REV_INTGOVT',
#  'REV_LICENSES',
#  'REV_LODGING_TAX',
#  'REV_MISC',
#  'REV_MOTOR_VEH_FEE',
#  'REV_OCCUPATION_TAX',
#  'REV_OTHER_TAX',
#  'REV_PROPERTY_TAX',
#  'REV_REAL_ESTATE_TRANSFER_TAX',
#  'REV_SALES_USE_TAX',
#  'REV_SOCIAL_SERVICE',
#  'REV_SO_TAX',
#  'REV_TOTAL',
#  'REV_TOTAL_TAX',
#  'REV_TRANSFER_IN',
#  'REV_UNCLASS_TAX',
#  'SALES_TAX_RATE',
#  'STATEFP',
#  'ST_SALES_TAX_PAID',
#  'TOTAL_DEBT',
#  'Unnamed: 0',
#  'Unnamed: 0.1',
#  'ap',
#  'atype',
#  'births',
#  'cens_pop',
#  'cpi',
#  'cpi_growth',
#  'cty',
#  'db',
#  'db_temp',
#  'deaths',
#  'defl',
#  'emp',
#  'fipsc',
#  'fipscty',
#  'fipscty_str',
#  'gq_pop',
#  'gsp',
#  'hh_num',
#  'hh_pop',
#  'hh_size',
#  'hu_num',
#  'index',
#  'int_temp',
#  'intensity',
#  'labforce',
#  'level_0',
#  'n_migr',
#  'non_resid',
#  'nonres_rate',
#  'nonres_val',
#  'npop_increase',
#  'pc_ap',
#  'pcap',
#  'pcap_mean',
#  'pcap_rel',
#  'pcap_rel2',
#  'pcdebt',
#  'pcexp',
#  'pcintgov',
#  'pcrev',
#  'permits',
#  'pop',
#  'real_non_resid',
#  'real_nonres_val',
#  'real_res_val',
#  'real_resid',
#  'real_total',
#  'res_rate',
#  'res_val',
#  'resid',
#  'sort_id',
#  'sorting_id',
#  'st_unempr',
#  'total',
#  'unemp',
#  'unemp_rate',
#  'vac_num',
#  'vac_rate',
#  'w_db_b_g',
#  'w_db_b_g_ap',
#  'w_db_b_i',
#  'w_db_b_i_ap',
#  'w_db_c_g',
#  'w_db_c_g_ap',
#  'w_db_c_i',
#  'w_db_c_i_ap',
#  'w_kern_g',
#  'w_kern_g_ap',
#  'w_kern_i',
#  'w_kern_i_ap',
#  'w_queen_g',
#  'w_queen_g_ap',
#  'w_queen_i',
#  'w_queen_i_ap',
#  'w_rook_g',
#  'w_rook_g_ap',
#  'w_rook_i',
#  'w_rook_i_ap',
#  'year_x',
#  'year_y']

# %%
#Subset to after 1992 (note that all change variables, including assessment, will be NaN in 1992)
co_92=co_sfdal2[co_sfdal2.index.get_level_values('AUDIT_YEAR')>1991]

#Create containers for DF components
co_DF_list=[]

#For every county...
for cty in set(co_92.reset_index()['FNAME']):
    #Create a county subset
    co_cty=co_92.ix[cty]
    #Create percentage change variables
    co_cty['d_resid']=co_cty['resid'].pct_change()
    co_cty['d_non_resid']=co_cty['non_resid'].pct_change()
    co_cty['d_total']=co_cty['total'].pct_change()
    co_cty['hu_growth']=co_cty['hu_num'].pct_change()
    co_cty['pop_growth']=co_cty['CTY_POP'].pct_change()
    #Replace any resultant 'inf' with 'NaN'
    co_cty2=co_cty.replace(inf,NaN)
    #Reset county name
    co_cty2['FNAME']=cty
    #Throw it back in the container
    co_DF_list.append(co_cty2)
    
#Concatenate pieces back together
co92_temp=pd.concat(co_DF_list).reset_index()

#Set index again
co93=co92_temp[co92_temp['AUDIT_YEAR']>1992].set_index(['FNAME','AUDIT_YEAR']).sortlevel(0)
    
print co93[['resid','d_resid','non_resid','d_non_resid','total','d_total']].head(10)
co93[['resid','d_resid','non_resid','d_non_resid','total','d_total']].describe()
# Out:
#                        resid   d_resid   non_resid  d_non_resid       total   d_total
# FNAME AUDIT_YEAR
# Adams 1993         705269720       NaN   927339630          NaN  1632609350       NaN
#       1994         742865190  0.053307   941530050     0.015302  1684395240  0.031720
#       1995         813385250  0.094930  1001215680     0.063392  1814600930  0.077301
#       1996         853089120  0.048813  1045276840     0.044008  1898365960  0.046162
#       1997         955203880  0.119700  1138878080     0.089547  2094081960  0.103097
#       1998        1003073550  0.050115  1201323630     0.054831  2204397180  0.052680
#       1999        1181599650  0.177979  1371347110     0.141530  2552946760  0.158116
#       2000        1257611690  0.064330  1448916800     0.056565  2706528490  0.060159
#       2001        1568125310  0.246907  1732989150     0.196058  3301114460  0.219686
#       2002        1581702560  0.008658  1761408110     0.016399  3343110670  0.012722
#               resid      d_resid     non_resid  d_non_resid         total      d_total
# count  1.088000e+03  1016.000000  1.088000e+03  1016.000000  1.088000e+03  1016.000000
# mean   4.088715e+08     0.072506  4.739104e+08     0.076939  8.827819e+08     0.076841
# std    8.365265e+08     0.088602  8.685433e+08     0.125075  1.659197e+09     0.106413
# min    0.000000e+00    -0.194075  0.000000e+00    -0.236877  0.000000e+00    -0.220550
# 25%    1.317100e+07     0.024101  4.804648e+07     0.004394  6.657231e+07     0.015231
# 50%    4.965357e+07     0.050673  1.144799e+08     0.045165  1.815781e+08     0.046211
# 75%    2.813840e+08     0.106665  4.187223e+08     0.119831  7.443404e+08     0.118784
# max    4.546922e+09     0.533770  7.476110e+09     1.008305  1.202303e+10     0.842019

# %% [markdown]
# To get a sense of how much assessment values move around, let's examine Adams County.

# %%
plt.rcParams['figure.figsize']=15,5
co93.ix['Adams'][['d_total','d_resid','d_non_resid']].plot(kind='bar',title='Assessment Base - Annual % Change')

# %% [markdown]
# It is immediately apparent that the 5.5% statewide limit is a binding constraint with some frequency in Adams County.  A boxplot of each of these indicators over time would provide some sense of how the overall distribution looks for all counties.

# %%
plt.rcParams['figure.figsize']=15,10
for i in range(1993,2010):
    y1=co93.xs(i,level='AUDIT_YEAR')['d_total'].dropna()
    y2=co93.xs(i,level='AUDIT_YEAR')['d_resid'].dropna()
    y3=co93.xs(i,level='AUDIT_YEAR')['d_non_resid'].dropna()
    x1=np.random.normal(i,.04,size=len(y1))
    x2=np.random.normal(i,.04,size=len(y2))
    x3=np.random.normal(i,.04,size=len(y3))
    plot(x1,y1,'r.',alpha=.2)
    plot(x2,y2,'b.',alpha=.2)
    plot(x3,y3,'g.',alpha=.2)

# %%
co93[co93['d_total'].notnull()][['d_total','AUDIT_YEAR_y']]
# sorted(co93.columns)
# Out:
#                      d_total  AUDIT_YEAR_y
# FNAME   AUDIT_YEAR
# Adams   1994        0.031720          1994
#         1995        0.077301          1995
#         1996        0.046162          1996
#         1997        0.103097          1997
#         1998        0.052680          1998
#         1999        0.158116          1999
#         2000        0.060159          2000
#         2001        0.219686          2001
#         2002        0.012722          2002
#         2003        0.079771          2003
#         2004        0.043210          2004
#         2005        0.093615          2005
#         2006        0.031249          2006
#         2007        0.065237          2007
#         2008        0.029883          2008
#         2009       -0.013113          2009
# Alamosa 1994        0.061292          1994
#         1995        0.005319          1995
#         1996        0.023566          1996
#         1997        0.118490          1997
#         1998        0.036046          1998
#         1999        0.083264          1999
#         2000        0.045604          2000
#         2001        0.077520          2001
#         2002        0.059189          2002
#         2003        0.005978          2003
#         2004        0.000463          2004
#         2005        0.070374          2005
#         2006        0.020324          2006
#         2007        0.112419          2007
# ...                      ...           ...
# Weld    1996       -0.014221          1996
#         1997        0.114732          1997
#         1998        0.056818          1998
#         1999        0.041285          1999
#         2000        0.079996          2000
#         2001        0.268734          2001
#         2002        0.084539          2002
#         2003        0.023311          2003
#         2004        0.205250          2004
#         2005        0.207394          2005
#         2006        0.159123          2006
#         2007        0.065624          2007
#         2008        0.026070          2008
#         2009        0.262124          2009
# Yuma    1994        0.078580          1994
#         1995        0.034807          1995
#         1996        0.166139          1996
#         1997        0.129699          1997
#         1998        0.065131          1998
#         1999        0.077899          1999
#         2000       -0.022827          2000
#         2001        0.112483          2001
#         2002        0.003889          2002
#         2003       -0.101725          2003
#         2004        0.266112          2004
#         2005        0.085510          2005
#         2006        0.254597          2006
#         2007        0.118417          2007
#         2008        0.090138          2008
#         2009        0.284650          2009
#
# [1016 rows x 2 columns]

# %%
#Create mask to screen out missing values
nn_mask=co93[co93['d_total'].notnull()][['d_total','AUDIT_YEAR_y']].index

#Generate figure
fig,ax=plt.subplots(3,figsize=(15,20))

#For each assessment concept...
for i,asmt in enumerate(['d_total','d_resid','d_non_resid']):
        sb.violinplot(co93.ix[nn_mask][asmt],co93.ix[nn_mask]['AUDIT_YEAR_y'],ax=ax[i])

# %% [markdown]
# It is evident that many counties beat the 5.5% growth limit with some frequency.

# %% [markdown]
# Now it would be useful to understand the nature of the composite limit.  The local property tax growth limitation imposed by TABOR is inflation plus new construction.  We can use housing units growth to measure new construction and simply add in the CPI growth to create this dynamic limit.  The Statewide Limit can be included trivially.

# %%
#Create TABOR Limit variable
co93['tabor_lim']=Series(co93['cpi_growth']+co93['hu_growth']).where(Series(co93['cpi_growth']+co93['hu_growth'])>0,0)

#Create Statewide Limit variable
co93['state_lim']=.055

co93[['hu_num','cpi','cpi_growth','hu_growth','tabor_lim','state_lim']].head(15)
# Out:
#                   hu_num    cpi  cpi_growth  hu_growth  tabor_lim  state_lim
# FNAME AUDIT_YEAR
# Adams 1993        109367  144.5    0.029936   0.011964   0.041900      0.055
#       1994        111800  148.2    0.025606   0.022246   0.047852      0.055
#       1995        114742  152.4    0.028340   0.026315   0.054655      0.055
#       1996        117691  156.9    0.029528   0.025701   0.055229      0.055
#       1997        120682  160.5    0.022945   0.025414   0.048359      0.055
#       1998        124925  163.0    0.015576   0.035159   0.050735      0.055
#       1999        129403  166.6    0.022086   0.035846   0.057931      0.055
#       2000        128717  172.2    0.033613  -0.005301   0.028312      0.055
#       2001        133917  177.1    0.028455   0.040399   0.068854      0.055
#       2002        139734  179.9    0.015810   0.043437   0.059248      0.055
#       2003        144635  184.0    0.022790   0.035074   0.057864      0.055
#       2004        149648  188.9    0.026630   0.034660   0.061290      0.055
#       2005        154113  195.3    0.033880   0.029837   0.063717      0.055
#       2006        157948  201.6    0.032258   0.024884   0.057142      0.055
#       2007        160651  207.3    0.028274   0.017113   0.045387      0.055

# %% [markdown]
# Again looking at Adams County as the spot check, which limit is binding more often?

# %%
plt.rcParams['axes.edgecolor']='k'
plt.rcParams['axes.linewidth']=1
plt.rcParams
# Out:
# RcParams({u'agg.path.chunksize': 0,
#           u'animation.avconv_args': u'',
#           u'animation.avconv_path': u'avconv',
#           u'animation.bitrate': -1,
#           u'animation.codec': u'mpeg4',
#           u'animation.convert_args': u'',
#           u'animation.convert_path': u'convert',
#           u'animation.ffmpeg_args': u'',
#           u'animation.ffmpeg_path': u'ffmpeg',
#           u'animation.frame_format': u'png',
#           u'animation.mencoder_args': u'',
#           u'animation.mencoder_path': u'mencoder',
#           u'animation.writer': u'ffmpeg',
#           u'axes.axisbelow': True,
#           u'axes.color_cycle': [(0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.3333333333333333,
#                                  0.6588235294117647,
#                                  0.40784313725490196),
#                                 (0.7686274509803922,
#                                  0.3058823529411765,
#                                  0.3215686274509804),
#                                 (0.5058823529411764,
#                                  0.4470588235294118,
#                                  0.6980392156862745),
#                                 (0.8, 0.7254901960784313, 0.4549019607843137),
#                                 (0.39215686274509803,
#                                  0.7098039215686275,
#                                  0.803921568627451),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.3333333333333333,
#                                  0.6588235294117647,
#                                  0.40784313725490196),
#                                 (0.7686274509803922,
#                                  0.3058823529411765,
#                                  0.3215686274509804),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.3333333333333333,
#                                  0.6588235294117647,
#                                  0.40784313725490196),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.3333333333333333,
#                                  0.6588235294117647,
#                                  0.40784313725490196),
#                                 (0.7686274509803922,
#                                  0.3058823529411765,
#                                  0.3215686274509804),
#                                 (0.2980392156862745,
#                                  0.4470588235294118,
#                                  0.6901960784313725),
#                                 (0.3333333333333333,
#                                  0.6588235294117647,
#                                  0.40784313725490196)],
#           u'axes.edgecolor': 'k',
#           u'axes.facecolor': '#EAEAF2',
#           u'axes.formatter.limits': [-7, 7],
#           u'axes.formatter.use_locale': False,
#           u'axes.formatter.use_mathtext': False,
#           u'axes.formatter.useoffset': True,
#           u'axes.grid': True,
#           u'axes.grid.which': u'major',
#           u'axes.hold': True,
#           u'axes.labelcolor': '.15',
#           u'axes.labelsize': 11,
#           u'axes.labelweight': u'normal',
#           u'axes.linewidth': 1.0,
#           u'axes.titlesize': 12,
#           u'axes.titleweight': u'normal',
#           u'axes.unicode_minus': True,
#           u'axes.xmargin': 0,
#           u'axes.ymargin': 0,
#           u'axes3d.grid': True,
#           u'backend': 'module://IPython.kernel.zmq.pylab.backend_inline',
#           u'backend.qt4': u'PyQt4',
#           u'backend.qt5': u'PyQt5',
#           u'backend_fallback': True,
#           u'contour.negative_linestyle': u'dashed',
#           u'datapath': u'/home/choct155/analysis_tools/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data',
#           u'docstring.hardcopy': False,
#           u'examples.directory': u'',
#           u'figure.autolayout': False,
#           u'figure.dpi': 80,
#           u'figure.edgecolor': (1, 1, 1, 0),
#           u'figure.facecolor': (1, 1, 1, 0),
#           u'figure.figsize': [15.0, 10.0],
#           u'figure.frameon': True,
#           u'figure.max_open_warning': 20,
#           u'figure.subplot.bottom': 0.125,
#           u'figure.subplot.hspace': 0.2,
#           u'figure.subplot.left': 0.125,
#           u'figure.subplot.right': 0.9,
#           u'figure.subplot.top': 0.9,
#           u'figure.subplot.wspace': 0.2,
#           u'font.cursive': [u'Apple Chancery',
#                             u'Textile',
#                             u'Zapf Chancery',
#                             u'Sand',
#                             u'cursive'],
#           u'font.family': 'sans-serif',
#           u'font.fantasy': [u'Comic Sans MS',
#                             u'Chicago',
#                             u'Charcoal',
#                             u'ImpactWestern',
#                             u'fantasy'],
#           u'font.monospace': [u'Bitstream Vera Sans Mono',
#                               u'DejaVu Sans Mono',
#                               u'Andale Mono',
#                               u'Nimbus Mono L',
#                               u'Courier New',
#                               u'Courier',
#                               u'Fixed',
#                               u'Terminal',
#                               u'monospace'],
#           u'font.sans-serif': ['Arial',
#                                'Liberation Sans',
#                                'Bitstream Vera Sans',
#                                'sans-serif'],
#           u'font.serif': [u'Bitstream Vera Serif',
#                           u'DejaVu Serif',
#                           u'New Century Schoolbook',
#                           u'Century Schoolbook L',
#                           u'Utopia',
#                           u'ITC Bookman',
#                           u'Bookman',
#                           u'Nimbus Roman No9 L',
#                           u'Times New Roman',
#                           u'Times',
#                           u'Palatino',
#                           u'Charter',
#                           u'serif'],
#           u'font.size': 10,
#           u'font.stretch': u'normal',
#           u'font.style': u'normal',
#           u'font.variant': u'normal',
#           u'font.weight': u'normal',
#           u'grid.alpha': 1.0,
#           u'grid.color': 'white',
#           u'grid.linestyle': '-',
#           u'grid.linewidth': 1,
#           u'image.aspect': u'equal',
#           u'image.cmap': 'Greys',
#           u'image.interpolation': u'bilinear',
#           u'image.lut': 256,
#           u'image.origin': u'upper',
#           u'image.resample': False,
#           u'interactive': True,
#           u'keymap.all_axes': u'a',
#           u'keymap.back': [u'left', u'c', u'backspace'],
#           u'keymap.forward': [u'right', u'v'],
#           u'keymap.fullscreen': (u'f', u'ctrl+f'),
#           u'keymap.grid': u'g',
#           u'keymap.home': [u'h', u'r', u'home'],
#           u'keymap.pan': u'p',
#           u'keymap.quit': (u'ctrl+w', u'cmd+w'),
#           u'keymap.save': (u's', u'ctrl+s'),
#           u'keymap.xscale': [u'k', u'L'],
#           u'keymap.yscale': u'l',
#           u'keymap.zoom': u'o',
#           u'legend.borderaxespad': 0.5,
#           u'legend.borderpad': 0.4,
#           u'legend.columnspacing': 2.0,
#           u'legend.fancybox': False,
#           u'legend.fontsize': 10,
#           u'legend.frameon': False,
#           u'legend.handleheight': 0.7,
#           u'legend.handlelength': 2.0,
#           u'legend.handletextpad': 0.8,
#           u'legend.isaxes': True,
#           u'legend.labelspacing': 0.5,
#           u'legend.loc': u'upper right',
#           u'legend.markerscale': 1.0,
#           u'legend.numpoints': 1,
#           u'legend.scatterpoints': 1,
#           u'legend.shadow': False,
#           u'lines.antialiased': True,
#           u'lines.color': u'b',
#           u'lines.dash_capstyle': u'butt',
#           u'lines.dash_joinstyle': u'round',
#           u'lines.linestyle': u'-',
#           u'lines.linewidth': 1.75,
#           u'lines.marker': u'None',
#           u'lines.markeredgewidth': 0,
#           u'lines.markersize': 7,
#           u'lines.solid_capstyle': 'round',
#           u'lines.solid_joinstyle': u'round',
#           u'mathtext.bf': u'serif:bold',
#           u'mathtext.cal': u'cursive',
#           u'mathtext.default': u'it',
#           u'mathtext.fallback_to_cm': True,
#           u'mathtext.fontset': u'cm',
#           u'mathtext.it': u'serif:italic',
#           u'mathtext.rm': u'serif',
#           u'mathtext.sf': u'sans\\-serif',
#           u'mathtext.tt': u'monospace',
#           u'patch.antialiased': True,
#           u'patch.edgecolor': u'k',
#           u'patch.facecolor': (0.2980392156862745,
#                                0.4470588235294118,
#                                0.6901960784313725),
#           u'patch.linewidth': 0.3,
#           u'path.effects': [],
#           u'path.simplify': True,
#           u'path.simplify_threshold': 0.1111111111111111,
#           u'path.sketch': None,
#           u'path.snap': True,
#           u'pdf.compression': 6,
#           u'pdf.fonttype': 3,
#           u'pdf.inheritcolor': False,
#           u'pdf.use14corefonts': False,
#           u'pgf.debug': False,
#           u'pgf.preamble': [u''],
#           u'pgf.rcfonts': True,
#           u'pgf.texsystem': u'xelatex',
#           u'plugins.directory': u'.matplotlib_plugins',
#           u'polaraxes.grid': True,
#           u'ps.distiller.res': 6000,
#           u'ps.fonttype': 3,
#           u'ps.papersize': u'letter',
#           u'ps.useafm': False,
#           u'ps.usedistiller': False,
#           u'savefig.bbox': None,
#           u'savefig.directory': u'~',
#           u'savefig.dpi': 72,
#           u'savefig.edgecolor': u'w',
#           u'savefig.extension': u'png',
#           u'savefig.facecolor': u'w',
#           u'savefig.format': u'png',
#           u'savefig.frameon': True,
#           u'savefig.jpeg_quality': 95,
#           u'savefig.orientation': u'portrait',
#           u'savefig.pad_inches': 0.1,
#           u'savefig.transparent': False,
#           u'svg.embed_char_paths': True,
#           u'svg.fonttype': u'path',
#           u'svg.image_inline': True,
#           u'svg.image_noscale': False,
#           u'text.antialiased': True,
#           u'text.color': '.15',
#           u'text.dvipnghack': None,
#           u'text.hinting': True,
#           u'text.hinting_factor': 8,
#           u'text.latex.preamble': [u''],
#           u'text.latex.preview': False,
#           u'text.latex.unicode': False,
#           u'text.usetex': False,
#           u'timezone': u'UTC',
#           u'tk.pythoninspect': False,
#           u'tk.window_focus': False,
#           u'toolbar': u'toolbar2',
#           u'verbose.fileo': u'sys.stdout',
#           u'verbose.level': u'silent',
#           u'webagg.open_in_browser': True,
#           u'webagg.port': 8988,
#           u'webagg.port_retries': 50,
#           u'xtick.color': '.15',
#           u'xtick.direction': 'out',
#           u'xtick.labelsize': 10,
#           u'xtick.major.pad': 7,
#           u'xtick.major.size': 0,
#           u'xtick.major.width': 1,
#           u'xtick.minor.pad': 4,
#           u'xtick.minor.size': 0,
#           u'xtick.minor.width': 0.5,
#           u'ytick.color': '.15',
#           u'ytick.direction': 'out',
#           u'ytick.labelsize': 10,
#           u'ytick.major.pad': 7,
#           u'ytick.major.size': 0,
#           u'ytick.major.width': 1,
#           u'ytick.minor.pad': 4,
#           u'ytick.minor.size': 0,
#           u'ytick.minor.width': 0.5})

# %%
#Generate plot object
fig,ax=plt.subplots(figsize=(15,5))

#Subset data
lim_plot_sub=co93.ix['Adams'][['tabor_lim','state_lim']]

#Change variable names
lim_plot_sub.columns=['TABOR','SLPTR']

#Plot binding limits
lim_plot_sub.plot(kind='line',ax=ax,color=['orange','grey'],linewidth=4)

#Fix axis
simpleaxis(ax)

#Fix labels
ax.set_xlabel('Year')
ax.set_yticklabels(['{:.0%}'.format(num/100.) for num in range(8)])
ax.set_ylabel('Permissible Annual Growth')

plt.savefig('TABOR_vs_SLPTR.png')

# %% [markdown]
# It appears neither limit is likely to be dominant, but we can get a better global view by calculating the difference and looking at boxplots over time.

# %%
Series(co93['tabor_lim']-co93['state_lim']).reset_index().boxplot(column=0,by='AUDIT_YEAR')
plt.title('Distribution of Difference Between TABOR and SLPTR Limits')
plt.savefig('TABOR_less_SLPTR_dist.png')

# %% [markdown]
# This is interesting.  The median position of the difference between the two limits is consistently negative, indicating that the TABOR limit is generally lower (and thus more binding) than the Statewide limit.  There is, however, sufficient variation to preclude any notion that suggests the Statewide limit is inconsequential.  Note that in 2009, CPI actually went down (which is the reason for the dramatically lower values).

# %% [markdown]
# $$
# \text{if TABOR & Statewide:}\\
# \hspace{4ex} \text{limit_diff}=\begin{cases}
# \text{asmt_growth - min(TABOR,Statewide)}& \text{if asmt_growth > min(TABOR,Statewide)},\\
# 0& \text{otherwise}.
# \end{cases}
# $$
# $$
# \text{elif TABOR & !Statewide:}\\
# \hspace{4ex} \text{limit_diff}=\begin{cases}
# \text{asmt_growth - TABOR}& \text{if asmt_growth > TABOR},\\
# 0& \text{otherwise}.
# \end{cases}
# $$
# $$
# \text{elif !TABOR & Statewide:}\\
# \hspace{4ex} \text{limit_diff}=\begin{cases}
# \text{asmt_growth - Statewide}& \text{if asmt_growth > Statewide},\\
# 0& \text{otherwise}.
# \end{cases}
# $$
# $$
# \text{else:}\\
# \hspace{4ex} \text{limit_diff}=0
# $$

# %% [markdown]
# There are two components to the limit dynamic.  Within year, revenue growth (which can be proxied by assessment growth in a single year) cannot exceed the composite limit.  But, there is also this persistent effect, that is a function of the distance between potential and realized revenue.  Assessment growth increases this revenue potential quite independently of revenue growth *once the composite limit has been breached*.  If we were to measure the revenue potential (rev_pot) as the product of the tax rate and the assessment base, we could determine whether or not the revenue potential is greater than the composite limit distance from the prior year's realized revenue.  If it is, then the limit_diff must then be calculated as the difference between the composite limit and percentage growth in revenue required to exhaust the assessment base in a given year.  If it isn't, then the composite limit is not binding.  Assessment growth is not the right comparison, because it only tells the flow component of the story.  The above method must be modified to also take account of the stock.
#
# One problem is, if we were to index assessment potential to compare it realized revenue, we would need a start year. That start year should probably be when TABOR was implemented, so ultimately I will need more assessment data.
#
# **UPDATE:** The assessment data has been updated to incorporate assessment manual data back to 1993.  This was a manual extract from (gasp!) PDF storage.  The Notebook responsible for the processing of this data was *asmt_add* (in the data directory).
#
# I can initialize the series with the median rate in the start year.  If I were to just start the clock at zero, all counties would be in the same boat from an accumulated effect standpoint.  Employing the median rate to simulate revenue potential permits variation in starting conditions. Note that the [annual reports](http://www.colorado.gov/cs/Satellite/DOLA-Main/CBON/1251591547549) have average mill rates by county, but the reports available online only go back to 2004.
#
# With the update, we can go back to 1993, but we still fall victim to the staggered start because the statewide growth limitation was in place prior to 1993.  We need the median rates from 1993, but this requires a copy of the 1993 annual report (which is not available online).  I have requested hard copies of reports in 1993 and 1987 (to accomodate the full range of finance data), but it will not be ready in time for the conference.  Consequently, we will assume uniform starting points at the inception of TABOR.  This is less than ideal, but it can be asserted that there was a categorical change at the inception of TABOR.  It masks previous deficits, but the bias is less than it might have been with a start year of 1998.
#
# To operationalize this information, 1993 serves as $YEAR_0$.  The 1993 assessment levels are treated as indicative of allowable revenues, an assumption we hope to remedy once the relevant data become available.  In $YEAR_1$, we must calculate the distance between the growth in the assessment base and the baseline imposed by the composite limit.  At this point, assessment value serves as our proxy for revenue yield.  If the assessment value in $YEAR_1$ exceeds the sum of $YEAR_0$ assessment *and the growth permitted by the composite limit*, the TEL is actively constraining the county in question at a magnitude defined by said distance.  If the assessment value growth does not exceed that which is allowable, then there is no active constraint imposed by the TEL.
#
# So far we have addressed only the flow portion of the equation.  The stock portion becomes material in $YEAR_2$.  At this point we again calculate the annual distance between the assessment growth and the growth allowed by the composite limit.  However, to capture the stock effect, we employ the cumulative sum of these annual distances in an additional variable.  This cumulative sum measures the extent to which fiscal capacity is hindered by the growth limitations imposed by TABOR and the Statewide Property Tax Revenue Limit.
#
# The implicit assumption that drives this model is that prior to TABOR, each countied levied taxes at rates that reflected the preferences of the county in question.  Once TABOR was enacted,forced reductions in levies are actually wedges imposed by state law rather than county-specific preference.
#
# De-Brucing enters as a pressure release, eliminating one or both growth constraints.  In the previous analysis (*CO_TEL_convergence*), TEL intensity was measured as a score, so the impact of De-Brucing was captured as a positive integer subtracted from the number of overlapping policies.  In this analysis, De-Brucing will determine whether or not a given limit is present (TABOR or Statewide Limit on Property Tax Revenue) in the calculation of the composite limit.  From a programmatic standpoint, the De-Brucing information must be entered upstream of the cumulative impact.  We will leverage the same De-Brucing dictionary used in *CO_TEL_convergence*.

# %%
debruce_dict={'Adams':[2002,1], 'Alamosa':[1997,1], 'Archuleta':[1994,0], 'Baca':[1995,0],
              'Bent':[1993,0], 'Boulder':[2005,0], 'Chaffee':[1993,0], 'Cheyenne':[1996,0],
              'Clear Creek':[1999,1], 'Conejos':[1996,0], 'Costilla':[1997,0], 'Crowley':[1994,0],
              'Custer':[1997,1], 'Dolores':[2000,1], 'Douglas':[1997,1], 'Eagle':[1995,0],
              'Garfield':[1994,0], 'Grand':[1996,1], 'Gunnison':[2000,0], 'Hinsdale':[2006,1],
              'Huerfano':[2007,1], 'Jackson':[1999,1], 'Kiowa':[1997,0], 'Kit Carson':[1997,0],
              'La Plata':[2002,1], 'Lake':[2011,1], 'Larimer':[1999,1], 'Lincoln':[1995,0],
              'Logan':[1997,0], 'Mineral':[1995,0], 'Moffat':[1996,0], 'Montezuma':[2002,1],
              'Morgan':[1996,0], 'Otero':[1995,0], 'Ouray':[2002,1], 'Phillips':[1995,0],
              'Pitkin':[1994,0], 'Prowers':[1994,0], 'Rio Blanco':[1996,1], 'Rio Grande':[1999,1],
              'Saguache':[1996,1], 'San Juan':[1995,1], 'San Miguel':[2005,0], 'Sedgwick':[1996,1],
              'Summit':[1998,0], 'Teller':[1997,1], 'Washington':[1996,1], 'Yuma':[2004,1]}

# %% [markdown]
# We need to create indicator variables signifying whether or not the TABOR and SLPTR are active in a given county/year.  The above dictionary provides the means to determine this.  The first position in each value array indicates the year in which TABOR was waived.  The second indicates whether or not the SLPTR was also waived along with TABOR.  We can use this dictionary to generate both binary variables, with 1 indicating active and 100,000 indicating inactive.  Why use 100,000 to indicate that the limit is inactive?  Recall that our ultimate measure of interest is the cumulative distance between assessment value growth and the limited growth allowed by TELs, *when the distance is positive*.  If allowable growth is so high that actual assessment growth has no hope of matching it, the limit is effectively inactive.  (The inactive value was initially 100, but some limit values were too small for this to be a sufficient markup.)
#
# Note that all counties start with both limits active in 1993.  The waiver years for each county turn the relevant limits off.  For more discussion on the limitations of these data, see *CO_TEL_convergence*.
#
# The selection of the appropriate data is a little tricky.  We want a slice of years *within* each county.  The standard selection operators do not appear to capture such views easily, so rather than assign values to entire vector subsections at a time, we will assign values to individual year/county rows.

# %%
#Create new active status variables
co93['TABOR_active']=1
co93['SL_active']=1

#For each county...
for key in debruce_dict.keys():
    #...if both limits were waived...
    if debruce_dict[key][1]==1:
        #...for each year from the waiver year until 2009
        for i in range(debruce_dict[key][0],2010):
            #...turn off both limits
            co93.loc[(key,i),'TABOR_active']=100000
            co93.loc[(key,i),'SL_active']=100000
    #...otherwise...
    else:
        #...for each year after the waiver year...
        for i in range(debruce_dict[key][0],2010):
            #...change only the TABOR status to off
            co93.loc[(key,i),'TABOR_active']=100000

# %%
HTML(co93[['hu_num','cpi','cpi_growth','hu_growth','tabor_lim','state_lim','TABOR_active','SL_active']].head(15).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>hu_num</th>
#       <th>cpi</th>
#       <th>cpi_growth</th>
#       <th>hu_growth</th>
#       <th>tabor_lim</th>
#       <th>state_lim</th>
#       <th>TABOR_active</th>
#       <th>SL_active</th>
#     </tr>
#     <tr>
#       <th>FNAME</th>
#       <th>AUDIT_YEAR</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="15" valign="top">Adams</th>
#       <th>1993</th>
#       <td> 109367</td>
#       <td> 144.5</td>
#       <td> 0.029936</td>
#       <td> 0.011964</td>
#       <td> 0.041900</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1994</th>
#       <td> 111800</td>
#       <td> 148.2</td>
#       <td> 0.025606</td>
#       <td> 0.022246</td>
#       <td> 0.047852</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1995</th>
#       <td> 114742</td>
#       <td> 152.4</td>
#       <td> 0.028340</td>
#       <td> 0.026315</td>
#       <td> 0.054655</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1996</th>
#       <td> 117691</td>
#       <td> 156.9</td>
#       <td> 0.029528</td>
#       <td> 0.025701</td>
#       <td> 0.055229</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1997</th>
#       <td> 120682</td>
#       <td> 160.5</td>
#       <td> 0.022945</td>
#       <td> 0.025414</td>
#       <td> 0.048359</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1998</th>
#       <td> 124925</td>
#       <td> 163.0</td>
#       <td> 0.015576</td>
#       <td> 0.035159</td>
#       <td> 0.050735</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>1999</th>
#       <td> 129403</td>
#       <td> 166.6</td>
#       <td> 0.022086</td>
#       <td> 0.035846</td>
#       <td> 0.057931</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td> 128717</td>
#       <td> 172.2</td>
#       <td> 0.033613</td>
#       <td>-0.005301</td>
#       <td> 0.028312</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>2001</th>
#       <td> 133917</td>
#       <td> 177.1</td>
#       <td> 0.028455</td>
#       <td> 0.040399</td>
#       <td> 0.068854</td>
#       <td> 0.055</td>
#       <td>      1</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>2002</th>
#       <td> 139734</td>
#       <td> 179.9</td>
#       <td> 0.015810</td>
#       <td> 0.043437</td>
#       <td> 0.059248</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#     <tr>
#       <th>2003</th>
#       <td> 144635</td>
#       <td> 184.0</td>
#       <td> 0.022790</td>
#       <td> 0.035074</td>
#       <td> 0.057864</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#     <tr>
#       <th>2004</th>
#       <td> 149648</td>
#       <td> 188.9</td>
#       <td> 0.026630</td>
#       <td> 0.034660</td>
#       <td> 0.061290</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#     <tr>
#       <th>2005</th>
#       <td> 154113</td>
#       <td> 195.3</td>
#       <td> 0.033880</td>
#       <td> 0.029837</td>
#       <td> 0.063717</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#     <tr>
#       <th>2006</th>
#       <td> 157948</td>
#       <td> 201.6</td>
#       <td> 0.032258</td>
#       <td> 0.024884</td>
#       <td> 0.057142</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#     <tr>
#       <th>2007</th>
#       <td> 160651</td>
#       <td> 207.3</td>
#       <td> 0.028274</td>
#       <td> 0.017113</td>
#       <td> 0.045387</td>
#       <td> 0.055</td>
#       <td> 100000</td>
#       <td> 100000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we can define to new variables (*T_constraint* & *S_constraint*) that capture the interaction between active status and the actual value of the limit.

# %%
co93['T_constraint']=co93['tabor_lim']*co93['TABOR_active']
co93['S_constraint']=co93['state_lim']*co93['SL_active']

co93[['tabor_lim','state_lim','TABOR_active','SL_active','S_constraint','T_constraint','d_total']].head(15)
# Out:
#                   tabor_lim  state_lim  TABOR_active  SL_active  S_constraint  T_constraint   d_total
# FNAME AUDIT_YEAR
# Adams 1993         0.041900      0.055             1          1         0.055      0.041900       NaN
#       1994         0.047852      0.055             1          1         0.055      0.047852  0.031720
#       1995         0.054655      0.055             1          1         0.055      0.054655  0.077301
#       1996         0.055229      0.055             1          1         0.055      0.055229  0.046162
#       1997         0.048359      0.055             1          1         0.055      0.048359  0.103097
#       1998         0.050735      0.055             1          1         0.055      0.050735  0.052680
#       1999         0.057931      0.055             1          1         0.055      0.057931  0.158116
#       2000         0.028312      0.055             1          1         0.055      0.028312  0.060159
#       2001         0.068854      0.055             1          1         0.055      0.068854  0.219686
#       2002         0.059248      0.055        100000     100000      5500.000   5924.762967  0.012722
#       2003         0.057864      0.055        100000     100000      5500.000   5786.422218  0.079771
#       2004         0.061290      0.055        100000     100000      5500.000   6129.009531  0.043210
#       2005         0.063717      0.055        100000     100000      5500.000   6371.704340  0.093615
#       2006         0.057142      0.055        100000     100000      5500.000   5714.240263  0.031249
#       2007         0.045387      0.055        100000     100000      5500.000   4538.703666  0.065237

# %% [markdown]
# We can now calculate the following values:
#
# 1. The composite constraint (*comp_constraint*), which is just min(*S_constraint,T_constraint*)
# 2. The annual distance (*intensity_flow*) between total assessment growth (*d_total*) and the composite constraint (*comp_constraint*)
# 3. The cumulative distance (*intensity_stock*) between total assessment growth (*d_total*) and the composite constraint (*comp_constraint*)
#
# Note that each of these is a conditional assignment.  *comp_constraint* is the minimum of two pre-existing Series.  *intensity_flow* and *intensity_stock* only have non-zero values only if said values are positive.  The latter is a bit tricky because it must reset whenever the potential is non-existent, ignoring any subsequent negative values.  To spell this out more explicitly, there are three behavioral components for the stock values:
#
# 1. If stock is already zero, negative flow values are irrelevant.
# 2. If stock is positive, negative flow values must reduce said stock.
# 3. Positive flow values always increase stock.

# %%
print co93['pop_growth']
# Out:
# FNAME  AUDIT_YEAR
# Adams  1993          0.014064
#        1994          0.027418
#        1995          0.031000
#        1996          0.024262
#        1997          0.030077
#        1998          0.026010
#        1999          0.024978
#        2000          0.101212
#        2001         -0.007132
#        2002          0.039080
#        2003          0.026325
#        2004          0.014359
#        2005          0.028956
#        2006          0.024332
#        2007          0.022149
# ...
# Yuma   1995          0.018692
#        1996          0.005334
#        1997          0.021753
#        1998          0.014332
#        1999          0.002048
#        2000          0.005518
#        2001          0.005995
#        2002          0.001111
#        2003          0.010796
#        2004         -0.005790
#        2005          0.001807
#        2006          0.003107
#        2007         -0.003597
#        2008         -0.007921
#        2009          0.014352
# Name: pop_growth, Length: 1088, dtype: float64

# %%
#Calculate composite constraint
co93['comp_constraint']=co93['S_constraint'].where(co93['S_constraint'] < co93['T_constraint'],co93['T_constraint'])

#Calculate annual distance
co93['intensity_flow']=Series(co93['d_total']-co93['comp_constraint']).where(co93['d_total']>co93['comp_constraint'],0)

#Initialize cumulative distance
co93['intensity_stock']=co93['intensity_flow']

##Calculate cumulative distance (split, apply, combine)
#Create simple intensity difference
co93['intensity_diff']=Series(co93['d_total']-co93['comp_constraint']).replace(NaN,0)

#Create container for processed DF subsets
cs_df_list=[]

#Create list of counties
cty_list=sorted(list(set(co93.index.get_level_values(level='FNAME'))))

#For each county...
for cty in cty_list:
    #...generate county-specific subset...
    cty_df=co93.ix[cty]
    #...for each year within county...
    for i in range(1993,2010):
        if (i==1993):
            cty_df.loc[i,'intensity_stock']=0
        else:
            if (cty_df.ix[i-1]['intensity_stock']==0) & (cty_df.ix[i]['intensity_diff']<0):
               cty_df.loc[i,'intensity_stock']=0
            elif (cty_df.ix[i-1]['intensity_stock']>0) & (cty_df.ix[i]['intensity_diff']<0): #Check this component
                cty_df.loc[i,'intensity_stock']=np.where(cty_df.ix[i-1]['intensity_stock']+cty_df.ix[i]['intensity_diff']>0,\
                                                         cty_df.ix[i-1]['intensity_stock']+cty_df.ix[i]['intensity_diff'],0)
            else:
                cty_df.loc[i,'intensity_stock']=cty_df.ix[i-1]['intensity_stock'] + cty_df.ix[i]['intensity_diff']
    #...re-integrate county name...
    cty_df['FNAME']=cty
    #...and throw processed DF subset into list
    cs_df_list.append(cty_df.reset_index())

#Concatenate sets back together
co_tel=pd.concat(cs_df_list).set_index(['FNAME','AUDIT_YEAR'])

# %%
HTML(co_tel.ix['Broomfield'][['tabor_lim','state_lim','TABOR_active','SL_active','S_constraint','T_constraint','d_total',\
      'comp_constraint','intensity_flow','intensity_diff','intensity_stock']].head(15).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabor_lim</th>
#       <th>state_lim</th>
#       <th>TABOR_active</th>
#       <th>SL_active</th>
#       <th>S_constraint</th>
#       <th>T_constraint</th>
#       <th>d_total</th>
#       <th>comp_constraint</th>
#       <th>intensity_flow</th>
#       <th>intensity_diff</th>
#       <th>intensity_stock</th>
#     </tr>
#     <tr>
#       <th>AUDIT_YEAR</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1993</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1994</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1995</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1996</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1997</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1998</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>1999</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td> 0.000000</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>      NaN</td>
#       <td> 0.000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>2001</th>
#       <td> 0.070393</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.070393</td>
#       <td>      NaN</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>2002</th>
#       <td> 0.070606</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.070606</td>
#       <td> 0.102509</td>
#       <td> 0.055</td>
#       <td> 0.047509</td>
#       <td> 0.047509</td>
#       <td> 0.047509</td>
#     </tr>
#     <tr>
#       <th>2003</th>
#       <td> 0.080658</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.080658</td>
#       <td> 0.092171</td>
#       <td> 0.055</td>
#       <td> 0.037171</td>
#       <td> 0.037171</td>
#       <td> 0.084680</td>
#     </tr>
#     <tr>
#       <th>2004</th>
#       <td> 0.071154</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.071154</td>
#       <td>-0.003857</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>-0.058857</td>
#       <td> 0.025823</td>
#     </tr>
#     <tr>
#       <th>2005</th>
#       <td> 0.103974</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.103974</td>
#       <td> 0.001123</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>-0.053877</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>2006</th>
#       <td> 0.082902</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.082902</td>
#       <td> 0.028180</td>
#       <td> 0.055</td>
#       <td> 0.000000</td>
#       <td>-0.026820</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>2007</th>
#       <td> 0.078859</td>
#       <td> 0.055</td>
#       <td> 1</td>
#       <td> 1</td>
#       <td> 0.055</td>
#       <td> 0.078859</td>
#       <td> 0.115620</td>
#       <td> 0.055</td>
#       <td> 0.060620</td>
#       <td> 0.060620</td>
#       <td> 0.060620</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# What does the dynamic of flow versus stock TEL constraints look like?  Again, Adams County serves as our test bed.

# %%
fig,axes=plt.subplots(2)
co_tel.ix['Adams']['intensity_flow'].plot(kind='bar',ax=axes[0])
co_tel.ix['Adams']['intensity_stock'].plot(kind='line',ax=axes[1])

# %% [markdown]
# The Gallagher Amendment is comparatively easy to model.  Given that the restriction sets assessment rates based upon the statewide ratio of residential and non-residential property value, differential impacts by county can be modeled as the county-level ratios.  To the extent that an individual county features a different mix of property, the impact of GA on said county will differ from the statewide effect (and other counties).  Since assessment rates apply statewide (and thus are uniform modifiers of market value), we can model this ratio as residual over non-residual assessment value.

# %%
#Generate plot object
fig,ax=plt.subplots(figsize=(12,6))

#Generate property ratio variable
co_tel['prop_ratio']=co_tel['resid']/co_tel['non_resid']

#Generate subset for plot
asmt_dist_sub=co_tel['prop_ratio'].reset_index()[['prop_ratio','AUDIT_YEAR']]

#Change column names
asmt_dist_sub.columns=['prop','year']

#Plot distribution of proportions over time
sb.boxplot(asmt_dist_sub['prop'],groupby=asmt_dist_sub['year'],ax=ax,color='#F06418')

#Fix labels
ax.set_xlabel('Year')
ax.set_ylabel('Ratio of Residential to Non-Residential')

#Fix axis
simpleaxis(ax)

plt.savefig('prop_ratio_dist.png')

# %% [markdown]
# ***NOTE:*** Check Regional Directory at BEA for county level business investment.  If I can't find it, ask Wendy about it in an email.

# %% [markdown]
# We are now in a position to restrict the DataFrame to the variables we need.
#
# + Per Capita Annual Payroll (*pcap*)
# + Per Capita Revenue (*pcrev*)
# + LISAs (*w_rook,w_queen,w_db_b,w_db_b,w_kern* for all LISA-base suffixes)
# + Gross State Product (*gsp*)
# + State Unemployment Rate (*st_unempr*)
# + Housing Permits/Housing Units (*permits/hu_num*)
# + Vacancy Rate (*vac_rate*)
# + Labor Force/Population (*labforce/CTY_POP*)
# + Lagged Population Growth (lag(diff(*CTY_POP*)/(*CTY_POP*)))
# + TEL Intensity Flow (*intensity_flow*)
# + TEL Intensity Stock (*intensity_stock*)
# + Gallagher Ratio (*prop_ratio*)
# + Integovernmental transfers (*pcintgov*)
# + Total Revenue from All Govs (*all_gov_rev*)
# + Total Expenditure from All Govs (*all_gov_exp*)
# + County Proportion of All Revenue (*cty_rev_prop*)
# + County Proportion of All Expenditure (*cty_exp_prop*)

# %% [markdown]
# **LATE ADDITION:** We need to create the county proportions of revenue/expenditure from all governments in the county.

# %%
co_tel['cty_rev_prop']=co_tel['REV_TOTAL']/co_tel['all_gov_rev']
co_tel['cty_exp_prop']=co_tel['EXP_TOTAL']/co_tel['all_gov_exp']

co_tel[['REV_TOTAL','all_gov_rev','cty_rev_prop','EXP_TOTAL','all_gov_exp','cty_exp_prop']].head(10)
# Out:
#                      REV_TOTAL  all_gov_rev  cty_rev_prop     EXP_TOTAL  all_gov_exp  cty_exp_prop
# FNAME AUDIT_YEAR
# Adams 1993        1.724961e+08       621025    277.760365  1.732694e+08       606366    285.750470
#       1994        1.789587e+08       659271    271.449379  1.604820e+08       632092    253.890317
#       1995        1.862831e+08       697518    267.065698  1.628397e+08       657817    247.545618
#       1996        1.926911e+08       735764    261.892568  1.812153e+08       683543    265.111755
#       1997        1.878079e+08       774010    242.642761  1.844613e+08       709269    260.072380
#       1998        1.828566e+08       861324    212.297129  1.694714e+08       818231    207.119313
#       1999        2.065297e+08       948638    217.711768  2.050956e+08       927192    221.200839
#       2000        2.602143e+08      1035952    251.183719  2.351329e+08      1036154    226.928547
#       2001        2.746671e+08      1123266    244.525419  2.468840e+08      1145115    215.597596
#       2002        2.969835e+08      1210580    245.323314  3.009926e+08      1254077    240.011227

# %%
print sorted(co_tel.columns)
# Out:
# ['ALAND', 'ALL_OTHER_INTGOVT', 'ASSETS', 'AUDIT_YEAR_y', 'AWATER', 'CBSAFP', 'CLASSFP', 'COUNTYFP', 'COUNTYNS', 'CSAFP', 'CTY_POP', 'DFL', 'EXP_CAPITAL_OUTLAY', 'EXP_DEBT_SERVICE_GEN', 'EXP_FIRE', 'EXP_GEN_GOVT', 'EXP_HEALTH', 'EXP_INTEREST_GEN', 'EXP_JUDICIAL', 'EXP_MISC', 'EXP_OTHER_PUBLIC_SAFETY', 'EXP_OTHER_PUBLIC_WORKS', 'EXP_POLICE', 'EXP_PRINCIPAL_GEN', 'EXP_RECREATION', 'EXP_SOCIAL_SERVICE', 'EXP_STREET', 'EXP_TOTAL', 'EXP_TOTAL_OPERATING', 'EXP_TOTAL_PUBLIC_SAFETY', 'EXP_TOTAL_PUBLIC_WORKS', 'EXP_TRANSFER_OUT', 'EXP_TRASH', 'FUNCSTAT', 'GEOID', 'GO_DEBT_GEN', 'INTPTLAT', 'INTPTLON', 'LGID', 'LGTYPE_ID', 'LG_ID', 'LIABILITIES', 'LSAD', 'METDIVFP', 'MTFCC', 'NAME', 'NAMELSAD', 'NAME_x', 'NAME_y', 'OTHER_DEBT_GEN', 'POPULATION', 'RETAIL_SALES', 'REVENUE_DEBT_GEN', 'REV_CHARGES', 'REV_CIGARETTE_TAX', 'REV_CTF', 'REV_FINES', 'REV_FRANCHISE_TAX', 'REV_HUT', 'REV_INTEREST', 'REV_INTGOVT', 'REV_LICENSES', 'REV_LODGING_TAX', 'REV_MISC', 'REV_MOTOR_VEH_FEE', 'REV_OCCUPATION_TAX', 'REV_OTHER_TAX', 'REV_PROPERTY_TAX', 'REV_REAL_ESTATE_TRANSFER_TAX', 'REV_SALES_USE_TAX', 'REV_SOCIAL_SERVICE', 'REV_SO_TAX', 'REV_TOTAL', 'REV_TOTAL_TAX', 'REV_TRANSFER_IN', 'REV_UNCLASS_TAX', 'SALES_TAX_RATE', 'SL_active', 'STATEFP', 'ST_SALES_TAX_PAID', 'S_constraint', 'TABOR_active', 'TOTAL_DEBT', 'T_constraint', 'Unnamed: 0', 'Unnamed: 0.1', 'all_gov_exp', 'all_gov_rev', 'ap', 'atype', 'births', 'cens_pop', 'comp_constraint', 'cpi', 'cpi_growth', 'cty', 'd_non_resid', 'd_resid', 'd_total', 'db', 'db_temp', 'deaths', 'defl', 'emp', 'fipsc', 'fipscty', 'fipscty_str', 'gq_pop', 'gsp', 'hh_num', 'hh_pop', 'hh_size', 'hu_growth', 'hu_num', 'index', 'int_temp', 'intensity', 'intensity_diff', 'intensity_flow', 'intensity_stock', 'labforce', 'level_0', 'n_migr', 'non_resid', 'nonres_rate', 'nonres_val', 'npop_increase', 'pc_ap', 'pcap', 'pcap_mean', 'pcap_rel', 'pcap_rel2', 'pcdebt', 'pcexp', 'pcintgov', 'pcrev', 'permits', 'pop', 'pop_growth', 'prop_ratio', 'real_non_resid', 'real_nonres_val', 'real_res_val', 'real_resid', 'real_total', 'res_rate', 'res_val', 'resid', 'sort_id', 'sorting_id', 'st_unempr', 'state_lim', 'tabor_lim', 'total', 'unemp', 'unemp_rate', 'vac_num', 'vac_rate', 'w_db_b_g', 'w_db_b_g_ap', 'w_db_b_i', 'w_db_b_i_ap', 'w_db_c_g', 'w_db_c_g_ap', 'w_db_c_i', 'w_db_c_i_ap', 'w_kern_g', 'w_kern_g_ap', 'w_kern_i', 'w_kern_i_ap', 'w_queen_g', 'w_queen_g_ap', 'w_queen_i', 'w_queen_i_ap', 'w_rook_g', 'w_rook_g_ap', 'w_rook_i', 'w_rook_i_ap', 'year_x', 'year_y']

# %%
#Define desired columns
tel_cols=['pcap','pcrev','w_db_b_g','w_db_b_g_ap','w_db_b_i','w_db_b_i_ap', \
          'w_db_c_g','w_db_c_g_ap','w_db_c_i','w_db_c_i_ap','w_kern_g','w_kern_g_ap','w_kern_i', \
          'w_kern_i_ap','w_queen_g','w_queen_g_ap','w_queen_i','w_queen_i_ap','w_rook_g','w_rook_g_ap',\
          'w_rook_i','w_rook_i_ap','gsp','st_unempr','permits','hu_num','vac_rate','labforce',\
          'CTY_POP','intensity_flow','intensity_stock','prop_ratio','pcintgov','pop_growth',\
          'all_gov_exp','all_gov_rev']

#Subset to desired columns
co_TEL=co_tel.reindex(columns=tel_cols)

#Create new variables
co_TEL['permit_rate']=co_TEL['permits']/co_TEL['hu_num']
co_TEL['lfp_rat']=co_TEL['labforce']/co_TEL['CTY_POP']
# co_TEL['pop_growth']=co_TEL['CTY_POP'].pct_change()
co_TEL['lpop_growth']=co_TEL['pop_growth'].shift(1)

#Write final set to disk
co_TEL.to_csv(workdir+'co_TEL_df.csv')

co_TEL.head().T
# Out:
# FNAME                    Adams
# AUDIT_YEAR                1993           1994           1995           1996           1997
# pcap               8363.248319    8420.640636    8659.319256    9692.246662    9903.654147
# pcrev               613.581370     619.581576     625.547804     631.738963     597.750806
# w_db_b_g             -0.667833      -0.704338      -0.685286      -0.692598      -0.635539
# w_db_b_g_ap          -0.218274      -0.218873      -0.216583      -0.217908      -0.215921
# w_db_b_i              0.728318       0.779780       0.755767       0.757675       0.733613
# w_db_b_i_ap           0.104662       0.105187       0.106142       0.098868       0.096035
# w_db_c_g             -0.861310      -0.922639      -0.926496      -0.920364      -0.895479
# w_db_c_g_ap          -0.208552      -0.206386      -0.204023      -0.201905      -0.198523
# w_db_c_i              0.907102       0.986268       0.991425       0.977924       1.014843
# w_db_c_i_ap           0.093388       0.091513       0.093373       0.091338       0.089784
# w_kern_g             -1.788379      -1.932326      -1.925073      -1.830761      -1.853308
# w_kern_g_ap          -0.422883      -0.420770      -0.419070      -0.421344      -0.420837
# w_kern_i              1.779933       1.979626       1.987285       1.862576       2.015202
# w_kern_i_ap           0.155331       0.154045       0.156434       0.154136       0.155640
# w_queen_g            -0.805887      -0.847838      -0.774327      -0.717091      -0.658565
# w_queen_g_ap         -0.309191      -0.310134      -0.306786      -0.310544      -0.305603
# w_queen_i             0.743570       0.839219       0.767566       0.693639       0.688213
# w_queen_i_ap          0.108901       0.112079       0.112616       0.109592       0.109579
# w_rook_g             -0.792528      -0.833170      -0.759832      -0.702563      -0.646417
# w_rook_g_ap          -0.304398      -0.303962      -0.300816      -0.305684      -0.300889
# w_rook_i              0.736908       0.822138       0.747087       0.676470       0.673392
# w_rook_i_ap           0.113826       0.105730       0.112921       0.112053       0.112822
# gsp              103457.000000  110529.000000  116821.000000  123144.000000  157345.000000
# st_unempr             5.300000       4.300000       4.000000       4.200000       3.400000
# permits            2439.000000    2906.000000    2944.000000    2764.000000    4155.000000
# hu_num           109367.000000  111800.000000  114742.000000  117691.000000  120682.000000
# vac_rate              6.000000       5.900000       5.500000       5.500000       5.100000
# labforce         151092.000000  158830.000000  165754.000000  169548.000000  173611.000000
# CTY_POP          281130.000000  288838.000000  297792.000000  305017.000000  314191.000000
# intensity_flow        0.000000       0.000000       0.022646       0.000000       0.054739
# intensity_stock       0.000000       0.000000       0.022646       0.013808       0.068546
# prop_ratio            0.760530       0.788998       0.812398       0.816137       0.838724
# pcintgov            282.333128     265.877196     251.412599     243.214670     210.599472
# pop_growth            0.014064       0.027418       0.031000       0.024262       0.030077
# all_gov_exp      606366.000000  632092.000000  657817.000000  683543.000000  709269.000000
# all_gov_rev      621025.000000  659271.000000  697518.000000  735764.000000  774010.000000
# permit_rate           0.022301       0.025993       0.025658       0.023485       0.034429
# lfp_rat               0.537445       0.549893       0.556610       0.555864       0.552565
# lpop_growth                NaN       0.014064       0.027418       0.031000       0.024262

# %% [markdown]
# ## Estimating the Impact of Tax and Expenditure Limitation Constraints

# %% [markdown]
# This section will implement the actual models of concern.  Following the example set by *CO_TEL_convergence*, we will start by implementing the same models with different specifications.  In this case, we will be using the models described at the beginning of the **Model Specification** section above.
#
# + **Ordinary Least Squares**  - OLS will serve as a non-spatial pooled estimate
#
#    $$y=X\beta+\epsilon$$
#
#
# + **Spatial Error Model** - The error term in this model seeks to mitigate spatial dependency across counties
#
#    $y=X\beta+\epsilon$  and
#
#    $\epsilon=\gamma W \epsilon + u$
#
#    becomes  $y=\gamma Wy + X\beta-\gamma WX\beta + \epsilon$
#
#
# + **Spatial Lag Model** - This model explicitly incorporates the weighted average of neighborhood values
#
#    $y = \rho Wy + X\beta + \epsilon$
#
#    becomes $y=(I - \rho W)^{-1} X\beta + (I - \rho W)^{-1} \epsilon$
#
#
# + **Fixed Effect Spatial Lag Model** - This model both incorporates the weighted average of neighborhood values and the value of the observation in the preceding time period
#
#    $$y=\lambda (I_T \otimes W_N)y + (\iota_T \otimes I_N)\mu + X\beta + \epsilon$$

# %% [markdown]
# ### Ordinary Least Squares

# %% [markdown]
# The first model to be run ignores spatial association and the panel structure of the data.  It is meant to serve purely as a baseline to better understand the impact of incorporating these features into the estimation process.
#
# A few items of note regarding modeling with [PySAL](http://pythonhosted.org/PySAL/index.html):
#
# + The dependent variable, $y$, must be structured as an $n \times 1$ numpy array
# + The regressor matrix, $X$, must be structured as a $n \times j$ numpy array, where $j$ is the number of independent variables
# + As a consequence of working with numpy arrays, labeling information must be explicitly entered as parameters to the model
#
# In keeping with the above practice, all weight matrices will be tested.

# %%
sorted(co_TEL.columns)
# Out:
# ['CTY_POP',
#  'gsp',
#  'hu_num',
#  'intensity_flow',
#  'intensity_stock',
#  'labforce',
#  'lfp_rat',
#  'lpop_growth',
#  'pcap',
#  'pcintgov',
#  'pcrev',
#  'permit_rate',
#  'permits',
#  'pop_growth',
#  'prop_ratio',
#  'st_unempr',
#  'vac_rate',
#  'w_db_b_g',
#  'w_db_b_g_ap',
#  'w_db_b_i',
#  'w_db_b_i_ap',
#  'w_db_c_g',
#  'w_db_c_g_ap',
#  'w_db_c_i',
#  'w_db_c_i_ap',
#  'w_kern_g',
#  'w_kern_g_ap',
#  'w_kern_i',
#  'w_kern_i_ap',
#  'w_queen_g',
#  'w_queen_g_ap',
#  'w_queen_i',
#  'w_queen_i_ap',
#  'w_rook_g',
#  'w_rook_g_ap',
#  'w_rook_i',
#  'w_rook_i_ap']

# %%
#Define model dependents
y_econ='pcap'
y_rev='pcrev'
y_clust_econ=['w_rook_i_ap','w_queen_i_ap','w_db_b_i_ap','w_db_c_i_ap','w_kern_i_ap',\
              'w_rook_g_ap','w_queen_g_ap','w_db_b_g_ap','w_db_c_g_ap','w_kern_g_ap']
y_clust_rev=['w_rook_i','w_queen_i','w_db_b_i','w_db_c_i','w_kern_i',\
             'w_rook_g','w_queen_g','w_db_b_g','w_db_c_g','w_kern_g']

#Set list of regressors for each model
X_econ=['gsp','lpop_growth','st_unempr','permit_rate','vac_rate','intensity_stock','prop_ratio']
X_rev=['gsp','lpop_growth','st_unempr','permit_rate','vac_rate','pcap','intensity_stock','prop_ratio']
X_clust_econ=['gsp','lpop_growth','st_unempr','permit_rate','vac_rate','intensity_stock','prop_ratio']
X_clust_rev=['gsp','lpop_growth','st_unempr','permit_rate','vac_rate','pcap','intensity_stock','prop_ratio']

print co_TEL[pd.isnull(co_TEL[y_rev])][y_rev]
print co_TEL[pd.isnull(co_TEL[X_rev]).any(axis=1)][X_rev]
print co_TEL[(pd.notnull(co_TEL[X_rev]).all(axis=1)) & (pd.notnull(co_TEL[X_rev]).all(axis=1))][[y_rev]+X_rev].head()
# Out:
# Series([], name: pcrev, dtype: float64)
#                           gsp  lpop_growth  st_unempr  permit_rate  vac_rate         pcap  intensity_stock  prop_ratio
# FNAME      AUDIT_YEAR
# Adams      1993        103457          NaN        5.3     0.022301      6.00  8363.248319                0    0.760530
# Broomfield 1993        103457     0.009333        5.3          NaN      0.00          NaN                0         NaN
#            1994        110529     0.046005        4.3          NaN      0.00          NaN                0         NaN
#            1995        116821     0.063625        4.0          NaN      0.00          NaN                0         NaN
#            1996        123144     0.057359        4.2          NaN      0.00          NaN                0         NaN
#            1997        157345     0.040127        3.4          NaN      0.00          NaN                0         NaN
#            1998        166949     0.036281        3.5          NaN      0.00          NaN                0         NaN
#            1999        179848     0.058253        3.0          NaN      0.00          NaN                0         NaN
#            2000        195300     0.097379        2.7     0.007751      3.47          NaN                0         NaN
#            2001        201831    -0.025488        3.8     0.029623     -0.10          NaN                0    0.525363
#                        pcrev     gsp  lpop_growth  st_unempr  permit_rate  vac_rate          pcap  intensity_stock  prop_ratio
# FNAME AUDIT_YEAR
# Adams 1994        619.581576  110529     0.014064        4.3     0.025993       5.9   8420.640636         0.000000    0.788998
#       1995        625.547804  116821     0.027418        4.0     0.025658       5.5   8659.319256         0.022646    0.812398
#       1996        631.738963  123144     0.031000        4.2     0.023485       5.5   9692.246662         0.013808    0.816137
#       1997        597.750806  157345     0.024262        3.4     0.034429       5.1   9903.654147         0.068546    0.838724
#       1998        567.238215  166949     0.030077        3.5     0.035846       6.0  10643.771152         0.070491    0.834974

# %%
#Define variable that defines non-null subset
null_var='pcap'

#Define function to check for null values in regressor matrix
def count_missing(frame):
    return (frame.shape[0] * frame.shape[1]) - frame.count().sum()

def ols_pool(df,df_name,yvar,x_list,null_check):
    """This function is utility to facilitate looping through all weighting schemes.
    Note: data are subset to provide only non-null values in relative annual payroll per capita.
    The collection of annual payroll data in one county did not begin until 2002."""
    #Construct non-null mask
    nn=(pd.notnull(df[X_rev]).all(axis=1)) & (pd.notnull(df[y_rev]))
    #Set dependent variable
    #print '\nSETTING DEPENDENT:',yvar
    y=df[nn][yvar].values
    
    #Adhere to the structure constraints imposed by PySAL
    y.shape=(len(df[nn][yvar]),1)
    
    #Create container for regressors
    X=[]
    
    #Add regressors to container in turn
    #print '\nBUILDING REGRESSOR MATRIX'
    for reg in x_list:
        #print '\t',reg
        X.append(df[nn][reg].values)
    
    #Check for null values
    #print DataFrame(X)
    #null_series=DataFrame(X).groupby(DataFrame(X).index).apply(count_missing)
    #print null_series
    #print null_series[null_series>0]
        
    #Convert from j x n to n x j (again to adhere to PySAL structure constraints
    #print '\nTRANSPOSING REGRESSOR MATRIX'
    X=np.array(X).T
    
    #Run model
    #print '\nIMPLEMENTING OLS\n****************\n'
    ols=pysal.spreg.ols.OLS(y,X,name_y=yvar,name_x=x_list,name_ds=df_name)
    return ols
print '***TEST RUN - Dependent = Annual Payroll Per Capita (Economic Capacity)***\n'
print ols_pool(co_TEL,'co_TEL',y_econ,X_econ,null_var).summary
# Out:
# ***TEST RUN - Dependent = Annual Payroll Per Capita (Economic Capacity)***
#
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :      co_TEL
# Dependent Variable  :        pcap               Number of Observations:        1078
# Mean dependent var  :   8170.9548               Number of Variables   :           8
# S.D. dependent var  :   7004.9961               Degrees of Freedom    :        1070
# R-squared           :      0.1980
# Adjusted R-squared  :      0.1928
# Sum squared residual:42382413568.078               F-statistic           :     37.7467
# Sigma-square        :39609732.307               Prob(F-statistic)     :   1.885e-47
# S.E. of regression  :    6293.626               Log likelihood        :  -10955.182
# Sigma-square ML     :39315782.531               Akaike info criterion :   21926.365
# S.E of regression ML:   6270.2299               Schwarz criterion     :   21966.228
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    -1050.6504100    1087.2546380      -0.9663333       0.3340958
#                  gsp       0.0284422       0.0050174       5.6686751       0.0000000
#      intensity_stock    2952.6382651     732.8003974       4.0292531       0.0000599
#          lpop_growth      61.0006512    6001.1829616       0.0101648       0.9918917
#          permit_rate    26987.5815815    13340.2378312       2.0230210       0.0433193
#           prop_ratio    4927.8758166     487.0326762      10.1181626       0.0000000
#            st_unempr      92.1275910     156.9099626       0.5871367       0.5572358
#             vac_rate     -19.6659182      10.6926604      -1.8391979       0.0661630
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER        16.467503
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2      839.908897        0.0000000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                7      229.304364        0.0000000
# Koenker-Bassett test              7       89.091387        0.0000000
# ================================ END OF REPORT =====================================
# /home/choct155/analysis_tools/anaconda/lib/python2.7/site-packages/pysal/spreg/user_output.py:337: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if i == None:

# %% [markdown]
# The model executes, so let's pull some information into DataFrames for all dependents.  Note that lagged population growth does not have non-null values until 1995.

# %%
co_TEL95=co_TEL[co_TEL.index.get_level_values(level='AUDIT_YEAR').isin(range(1995,2010))]

# %%
sb.corrplot(co_TEL95[X_rev])
# Out:
# /home/choct155/analysis_tools/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# We need a general workflow for comparing estimates across models.  The function below captures critical information in DataFrame.

# %%
def ols_df(model,model_name,reg_list):
    print '***RUNNING',model_name,'***\n'
    
    #Create containers for estimates and p-values
    est_list=[]
    pval_list=[]
    col_list=[]
    
    #Populate estimate and p-value containers
    for col in model.name_x:
        col_list.append(col)
    for est in model.betas.tolist():
        est_list.append(est[0])
    for tstat_tuple in model.t_stat:
        pval_list.append(tstat_tuple[1])
        
    #Generate model DF
    ols_df=DataFrame({'var':col_list[1:],
                      'est':est_list[1:],
                      'pval':pval_list[1:]})
    
    #Include R^2
    ols_df['r2']=model.r2
    
    #Include model name
    ols_df['model']=model_name
    
    return ols_df

#Capture summary info
ols_econ_summary=ols_df(ols_pool(co_TEL,'co_TEL',y_econ,X_econ,null_var),'ols_econ',X_econ)

ols_econ_summary
# Out:
# ***RUNNING ols_econ ***
#             est          pval              var        r2     model
# 0      0.028442  1.849901e-08              gsp  0.198037  ols_econ
# 1     61.000651  9.918917e-01      lpop_growth  0.198037  ols_econ
# 2     92.127591  5.572358e-01        st_unempr  0.198037  ols_econ
# 3  26987.581581  4.331927e-02      permit_rate  0.198037  ols_econ
# 4    -19.665918  6.616303e-02         vac_rate  0.198037  ols_econ
# 5   2952.638265  5.991201e-05  intensity_stock  0.198037  ols_econ
# 6   4927.875817  4.805310e-23       prop_ratio  0.198037  ols_econ

# %% [markdown]
# We can run the revenue model the same way.

# %%
ols_rev_summary=ols_df(ols_pool(co_TEL95,'co_TEL',y_rev,X_rev,null_var),'ols_rev',X_rev)

ols_rev_summary
# Out:
# ***RUNNING ols_rev ***
#            est           pval              var        r2    model
# 0     0.000999   9.998783e-02              gsp  0.599852  ols_rev
# 1  -559.687132   4.105274e-01      lpop_growth  0.599852  ols_rev
# 2    19.308982   1.785172e-01        st_unempr  0.599852  ols_rev
# 3 -4881.559301   2.155566e-04      permit_rate  0.599852  ols_rev
# 4    32.375174  1.032227e-154         vac_rate  0.599852  ols_rev
# 5     0.044216   1.253257e-52             pcap  0.599852  ols_rev
# 6  -385.677194   2.772749e-09  intensity_stock  0.599852  ols_rev
# 7  -622.994861   1.235285e-37       prop_ratio  0.599852  ols_rev

# %% [markdown]
# We can also roll through each of the LISAs as dependents in this fashion.  Furthermore, we can capture each resultant DataFrame in a list.

# %%
#Create container for summary DFs
ols_summ_list=[ols_econ_summary,ols_rev_summary]

##Capture all models for revenue clustering
#For each clustering dependent variable...
for i in range(len(y_clust_rev)):
    #Run pooled ols and capture summary info
    summary_df_rev=ols_df(ols_pool(co_TEL95,'co_TEL',y_clust_rev[i],X_clust_rev,null_var),'ols_'+y_clust_rev[i],X_clust_rev)
    summary_df_econ=ols_df(ols_pool(co_TEL95,'co_TEL',y_clust_econ[i],X_clust_econ,null_var),'ols_'+y_clust_econ[i],X_clust_econ)
    #Dump summary info in the DF list
    ols_summ_list.append(summary_df_rev)
    ols_summ_list.append(summary_df_econ)

#Concatenate all sets together
ols_results=pd.concat(ols_summ_list).set_index(['var','model']).sortlevel(0)

HTML(ols_results.ix['intensity_stock'].head(15).to_html())
# Out:
# ***RUNNING ols_w_rook_i ***
#
# ***RUNNING ols_w_rook_i_ap ***
#
# ***RUNNING ols_w_queen_i ***
#
# ***RUNNING ols_w_queen_i_ap ***
#
# ***RUNNING ols_w_db_b_i ***
#
# ***RUNNING
#  ols_w_db_b_i_ap ***
#
# ***RUNNING ols_w_db_c_i ***
#
# ***RUNNING ols_w_db_c_i_ap ***
#
# ***RUNNING ols_w_kern_i ***
#
# ***RUNNING ols_w_kern_i_ap ***
#
# ***RUNNING ols_w_rook_g ***
#
# ***RUNNING
#  ols_w_rook_g_ap ***
#
# ***RUNNING ols_w_queen_g ***
#
# ***RUNNING ols_w_queen_g_ap ***
#
# ***RUNNING ols_w_db_b_g ***
#
# ***RUNNING ols_w_db_b_g_ap ***
#
# ***RUNNING ols_w_db_c_g ***
#
# ***RUNNING
#  ols_w_db_c_g_ap ***
#
# ***RUNNING ols_w_kern_g ***
#
# ***RUNNING ols_w_kern_g_ap ***
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>est</th>
#       <th>pval</th>
#       <th>r2</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ols_econ</th>
#       <td> 2952.638265</td>
#       <td> 5.991201e-05</td>
#       <td> 0.198037</td>
#     </tr>
#     <tr>
#       <th>ols_rev</th>
#       <td> -385.677194</td>
#       <td> 2.772749e-09</td>
#       <td> 0.599852</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_b_g</th>
#       <td>    0.310398</td>
#       <td> 1.028405e-02</td>
#       <td> 0.269805</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_b_g_ap</th>
#       <td>   -0.489188</td>
#       <td> 7.226648e-06</td>
#       <td> 0.032407</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_b_i</th>
#       <td>   -0.174133</td>
#       <td> 2.226566e-01</td>
#       <td> 0.161147</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_b_i_ap</th>
#       <td>    0.208039</td>
#       <td> 5.245256e-03</td>
#       <td> 0.027257</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_c_g</th>
#       <td>    0.380547</td>
#       <td> 2.945276e-03</td>
#       <td> 0.261928</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_c_g_ap</th>
#       <td>   -0.541429</td>
#       <td> 1.325739e-05</td>
#       <td> 0.031535</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_c_i</th>
#       <td>   -0.154265</td>
#       <td> 3.041570e-01</td>
#       <td> 0.179863</td>
#     </tr>
#     <tr>
#       <th>ols_w_db_c_i_ap</th>
#       <td>    0.219980</td>
#       <td> 3.398938e-03</td>
#       <td> 0.028175</td>
#     </tr>
#     <tr>
#       <th>ols_w_kern_g</th>
#       <td>   -0.043937</td>
#       <td> 7.263129e-01</td>
#       <td> 0.321614</td>
#     </tr>
#     <tr>
#       <th>ols_w_kern_g_ap</th>
#       <td>   -0.179799</td>
#       <td> 1.428048e-01</td>
#       <td> 0.039709</td>
#     </tr>
#     <tr>
#       <th>ols_w_kern_i</th>
#       <td>   -0.373182</td>
#       <td> 4.296370e-02</td>
#       <td> 0.132685</td>
#     </tr>
#     <tr>
#       <th>ols_w_kern_i_ap</th>
#       <td>   -0.080449</td>
#       <td> 7.810253e-01</td>
#       <td> 0.008040</td>
#     </tr>
#     <tr>
#       <th>ols_w_queen_g</th>
#       <td>    0.432240</td>
#       <td> 5.171213e-04</td>
#       <td> 0.199186</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We will wait to explore the results until after the other models have been run.

# %% [markdown]
# ### Spatial Lag Model

# %% [markdown]
# Spatial Lag Models (SLMs) seek to model the neighborhood impacts directly.  The time series equivalent of this task would be an autoregressive specification seeking to model the impact of preceding observations $y_{t-1},y_{t-2},...,y_{t-n}$ on the current observation $y_t$.
#
# $$Y_t=\alpha + \sum_{i=1}^p \rho_i Y_{t-i} + X\beta + \epsilon_t$$
#
# In the spatial context, this "autoregressive" impact captures the weighted average of the values for all neighboring geographies, $y_j \forall j \neq i$, in the neighborhood (defined by $W$) of geography unit $y_i$.
#
# $$y =\alpha + \rho Wy + X\beta + \epsilon$$
#
# The SLM is a cross-sectional model that must be run for each year.  First, however, we need to generate some weight matrices.  We will use the same approach taken in *CO_TEL_convergence*.  Note that the distance based thresholds, *distance band (db)* and *kernel (kern)*, required a minimum threshold distance.  That threshold will be set to ensure all geographies have at least one neighbor.

# %%
#Establish shapefile location
# shp_dir='/home/choct155/Google Drive/Dissertation/Data/spatial/US/'

#Generate rook weights
w_rook=pysal.rook_from_shapefile(workdir+'co_county.shp')

#Generate queen weights
w_queen=pysal.queen_from_shapefile(workdir+'co_county.shp')

#Calculate minimum distance at which each county has at least one neighbor
thresh=pysal.min_threshold_dist_from_shapefile(workdir+'co_county.shp')

#Calculate binary distance band weights
w_db_b=pysal.threshold_binaryW_from_shapefile(workdir+'co_county.shp',thresh)

#Calculate continous distance band weights
w_db_c=pysal.threshold_continuousW_from_shapefile(workdir+'co_county.shp',thresh)

#Generate kernel based weights
w_kern=pysal.kernelW_from_shapefile(workdir+'co_county.shp',function='gaussian')

#Create list of weight matrices
w_list=[w_rook,w_queen,w_db_b,w_db_c,w_kern]

# %% [markdown]
# Now we have the components required for an SLM, so we can define a function to facilitate the execution of multiple models.  First, however, we must deal with Broomfield County.  The county did not have assessment nor demographic profile information prior to 2001.  This has led to the existence of missing data that are confounding the matrix shape requirements for this estimator.  This is a less than ideal solution, but we are replacing missing data with within county means for each specific column.

# %%
for col in co_TEL95.ix['Broomfield'].columns:
    co_TEL95.ix['Broomfield'][col].replace(NaN,co_TEL95.ix['Broomfield'][col].mean(),inplace=True)
# Out:
# -c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %% [markdown]
# Now we can develop the SLM function.  Recall that its cross-sectional nature renders Gross State Product invariant.  Thus, it must be removed.

# %%
def slm_yr(df,df_name,yvar,x_list,yr,w,lag,null_check):
    """This function is utility to facilitate looping through all weighting schemes.
    Note: data are subset to provide only non-null values in relative annual payroll per capita.
    The collection of annual payroll data in one county did not begin until 2002."""
    #Set dependent variable
    #print '\nSETTING DEPENDENT:',yvar
    y=df[df[null_check].notnull()].xs(yr,level='AUDIT_YEAR')[yvar].values
    
    #Adhere to the structure constraints imposed by PySAL
    y.shape=(len(y),1)
    
    #Create container for regressors
    X=[]
    
    #Add regressors to container in turn
    #print '\nBUILDING REGRESSOR MATRIX'
    for reg in x_list:
#         print '\t',reg
        X.append(df[df[null_check].notnull()].xs(yr,level='AUDIT_YEAR')[reg].values)
    
    #Check for null values
    #print DataFrame(X)
    #null_series=DataFrame(X).groupby(DataFrame(X).index).apply(count_missing)
    #print null_series
    #print null_series[null_series>0]
        
    #Convert from j x n to n x j (again to adhere to PySAL structure constraints
    #print '\nTRANSPOSING REGRESSOR MATRIX'
    X=np.array(X).T
    
    #Row standardize weight matrix
    w.transform='r'
    
    #Run model
    slm=pysal.spreg.twosls_sp.GM_Lag(y,X,w=w,w_lags=lag,name_y=yvar,name_x=x_list,name_ds=df_name)
    return slm

#Define subset of cross-sectionally varying columns
cross_cty_econ=sorted(list(set(X_econ) - set(['gsp','st_unempr'])))
cross_cty_rev=sorted(list(set(X_rev) - set(['gsp','st_unempr'])))

slm_econ95=slm_yr(co_TEL95,'co_TEL',y_econ,cross_cty_econ[::-1],1995,w_list[0],2,null_var)

print slm_econ95.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      co_TEL
# Weights matrix      :     unknown
# Dependent Variable  :        pcap               Number of Observations:          64
# Mean dependent var  :   6576.1607               Number of Variables   :           7
# S.D. dependent var  :   5978.4921               Degrees of Freedom    :          57
# Pseudo R-squared    :      0.1501
# Spatial Pseudo R-squared:  0.1016
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    2829.6910649    2502.2399122       1.1308632       0.2581127
#               W_pcap       0.2011834       0.3367586       0.5974115       0.5502326
#      intensity_stock    2341.7294254    12851.5629312       0.1822136       0.8554151
#          lpop_growth    -8597.3517290    19965.1712513      -0.4306175       0.6667465
#          permit_rate    -7976.4814267    48644.3953063      -0.1639753       0.8697506
#           prop_ratio    4852.4393259    2162.2142734       2.2441991       0.0248196
#             vac_rate       3.9416562      37.8076796       0.1042554       0.9169666
# ------------------------------------------------------------------------------------
# Instrumented: W_pcap
# Instruments: W2_intensity_stock, W2_lpop_growth, W2_permit_rate,
#              W2_prop_ratio, W2_vac_rate, W_intensity_stock, W_lpop_growth,
#              W_permit_rate, W_prop_ratio, W_vac_rate
# ================================ END OF REPORT =====================================
# /home/choct155/analysis_tools/anaconda/lib/python2.7/site-packages/pysal/spreg/twosls.py:136: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if q==None and h==None:

# %% [markdown]
# With the specification modified to accommodate cross-sectional invariance in statewide indicators, we can attempt to extract the summary information into a DataFrame (much like the OLS summary process above).

# %%
def slm_df(model,model_name,yr):
    print '***RUNNING',model_name,'***\n'
    
    #Create containers for column names, estimates and p-values
    col_list=[]
    est_list=[]
    pval_list=[]
    
    #Populate estimate and p-value containers
    for col in model.name_x:
        col_list.append(col)
    for est in model.betas.tolist():
        est_list.append(est[0])
    for zstat_tuple in model.z_stat:
        pval_list.append(zstat_tuple[1])
        
    #Generate model DF (note that while W does not show up in the column names, it is in the estimates/pvals)
    slm_df=DataFrame({'var':col_list[1:],
                      'est':est_list[1:-1],
                      'pval':pval_list[1:-1]})
    
    #Include R^2
    slm_df['pr2']=model.pr2
    
    #Include model name
    slm_df['model']=model_name
    
    #Include model year
    slm_df['year']=yr
    
    return slm_df

slm_df(slm_econ95,'slm_econ95',1995)
# Out:
# ***RUNNING slm_econ95 ***
#            est      pval              var       pr2       model  year
# 0     3.941656  0.916967         vac_rate  0.150056  slm_econ95  1995
# 1  4852.439326  0.024820       prop_ratio  0.150056  slm_econ95  1995
# 2 -7976.481427  0.869751      permit_rate  0.150056  slm_econ95  1995
# 3 -8597.351729  0.666747      lpop_growth  0.150056  slm_econ95  1995
# 4  2341.729425  0.855415  intensity_stock  0.150056  slm_econ95  1995

# %% [markdown]
# Now we can execute this model for each year, within each model specification.

# %%
slm_list=[]
for year in range(1995,2010):
    slm_econ=slm_yr(co_TEL95,'co_TEL',y_econ,cross_cty_econ[::-1],year,w_list[0],2,null_var)
    slm_rev=slm_yr(co_TEL95,'co_TEL',y_rev,cross_cty_rev[::-1],year,w_list[0],2,null_var)
    slm_list.append(slm_df(slm_econ,'slm_econ',year))
    slm_list.append(slm_df(slm_rev,'slm_rev',year))
    
print slm_list[5]
# Out:
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING
#  slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING
#  slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING
#  slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING
#  slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING slm_econ ***
#
# ***RUNNING slm_rev ***
#
# ***RUNNING
#  slm_econ ***
#
# ***RUNNING slm_rev ***
#
#            est          pval              var       pr2    model  year
# 0    26.739097  1.880800e-21         vac_rate  0.662894  slm_rev  1997
# 1  -315.674329  7.564981e-02       prop_ratio  0.662894  slm_rev  1997
# 2 -8506.077737  2.733771e-02      permit_rate  0.662894  slm_rev  1997
# 3     0.025877  5.370525e-03             pcap  0.662894  slm_rev  1997
# 4  1720.029785  5.561948e-01      lpop_growth  0.662894  slm_rev  1997
# 5  -906.563954  3.380347e-02  intensity_stock  0.662894  slm_rev  1997

# %% [markdown]
# The same must be done for each clustering variable... (or should it?)

# %%
# ##Capture all models for revenue clustering
# #For each year...
# for year in range(1995,2010):
#     print year
# #... and each clustering dependent variable within year...
#     for i in range(len(y_clust_rev)):
#         print y_clust_rev[i]
#         #Run SLM and capture summary info
#         slm_clust_rev=slm_yr(co_TEL95,'co_TEL',y_clust_rev[i],cross_cty_rev,year,w_list[0],2,null_var)
#         slm_clust_econ=slm_yr(co_TEL95,'co_TEL',y_clust_econ[i],cross_cty_econ,year,w_list[0],2,null_var)
#         #Dump summary info in the DF list
#         slm_list.append(slm_df(slm_clust_rev,'slm_clust_rev'+str(year),year))
#         slm_list.append(slm_df(slm_clust_econ,'slm_clust_econ'+str(year),year))
        
# #Concatenate all sets together
# slm_results=pd.concat(slm_list).set_index(['var','model']).sortlevel(0)

# %%
#Concatenate all sets together
slm_results=pd.concat(slm_list)

#Integrate state unemployment rate
slm_results['st_unempr']=slm_results['year'].map(state_unemp_dict)

slm_results.head(20)
# Out:
#             est          pval              var       pr2     model  year  st_unempr
# 0      3.941656  9.169666e-01         vac_rate  0.150056  slm_econ  1995        4.0
# 1   4852.439326  2.481959e-02       prop_ratio  0.150056  slm_econ  1995        4.0
# 2  -7976.481427  8.697506e-01      permit_rate  0.150056  slm_econ  1995        4.0
# 3  -8597.351729  6.667465e-01      lpop_growth  0.150056  slm_econ  1995        4.0
# 4   2341.729425  8.554151e-01  intensity_stock  0.150056  slm_econ  1995        4.0
# 0     25.799060  1.135082e-18         vac_rate  0.674969   slm_rev  1995        4.0
# 1   -470.055251  4.747703e-03       prop_ratio  0.674969   slm_rev  1995        4.0
# 2  -6364.202976  7.586142e-02      permit_rate  0.674969   slm_rev  1995        4.0
# 3      0.027099  2.715553e-03             pcap  0.674969   slm_rev  1995        4.0
# 4   1312.640704  3.896742e-01      lpop_growth  0.674969   slm_rev  1995        4.0
# 5   -325.479324  7.241664e-01  intensity_stock  0.674969   slm_rev  1995        4.0
# 0     -6.900912  8.425517e-01         vac_rate  0.295701  slm_econ  1996        4.2
# 1   4874.784080  9.319793e-03       prop_ratio  0.295701  slm_econ  1996        4.2
# 2  89149.840039  3.982485e-02      permit_rate  0.295701  slm_econ  1996        4.2
# 3 -60641.082141  3.658465e-02      lpop_growth  0.295701  slm_econ  1996        4.2
# 4 -15248.428357  1.323968e-01  intensity_stock  0.295701  slm_econ  1996        4.2
# 0     27.687441  6.588370e-20         vac_rate  0.644088   slm_rev  1996        4.2
# 1   -471.685092  4.933895e-03       prop_ratio  0.644088   slm_rev  1996        4.2
# 2   2412.836247  5.163525e-01      permit_rate  0.644088   slm_rev  1996        4.2
# 3      0.022416  3.125443e-02             pcap  0.644088   slm_rev  1996        4.2

# %% [markdown]
# At this point, we should really be proceeding with the Spatial Panel Model.  This, however, requires some manipulation in R because such an estimator is not available in Python (at least not in the PySAL package, nor any other package that I have seen to date).  In the interests of time, at present we proceed to exploring the results of the OLS and SLM models.

# %%
ols_results.ix['pcap']
# Out:
#                     est          pval        r2
# model
# ols_rev        0.044216  1.253257e-52  0.599852
# ols_w_db_b_g   0.000033  1.367850e-10  0.269805
# ols_w_db_b_i  -0.000023  1.578248e-04  0.161147
# ols_w_db_c_g   0.000034  6.052608e-10  0.261928
# ols_w_db_c_i  -0.000027  1.927283e-05  0.179863
# ols_w_kern_g   0.000027  3.403620e-07  0.321614
# ols_w_kern_i  -0.000013  9.620661e-02  0.132685
# ols_w_queen_g  0.000010  6.151604e-02  0.199186
# ols_w_queen_i -0.000063  1.158508e-31  0.200965
# ols_w_rook_g   0.000008  9.716966e-02  0.234427
# ols_w_rook_i  -0.000061  1.321334e-26  0.184048

# %%
ols_results.to_csv(workdir+'tcr_ols_results.csv')
slm_results.to_csv(workdir+'tcr_slm_results.csv')

# %% [markdown]
# ### Panel Analysis

# %% [markdown]
# To round out the analysis, we can run fixed effect models seeking to tease out the impact of cumulative TEL intensity while avoiding county-specific unobservables.  Furthermore, this should help to isolate the impact on changes within county.  First we need to get the data in a panel structure.

# %%
#Create container for county specific subsets
cty_list=[]

#For each county...
for cty in co_TEL95[X_rev].index.get_level_values(level='FNAME'):
    #...throw the county-specific subset in the list
    cty_list.append(co_TEL[X_rev+['pcrev']].ix[cty])
    
#Create a dict of county subsets
TEL_panel_dict=dict(zip(co_TEL95[X_rev].index.get_level_values(level='FNAME'),cty_list))

#Create panel set
TEL_panel=pd.Panel(TEL_panel_dict)

TEL_panel['Adams']
# Out:
#                gsp  lpop_growth  st_unempr  permit_rate  vac_rate          pcap  intensity_stock  prop_ratio       pcrev
# AUDIT_YEAR
# 1993        103457          NaN        5.3     0.022301      6.00   8363.248319         0.000000    0.760530  613.581370
# 1994        110529     0.014064        4.3     0.025993      5.90   8420.640636         0.000000    0.788998  619.581576
# 1995        116821     0.027418        4.0     0.025658      5.50   8659.319256         0.022646    0.812398  625.547804
# 1996        123144     0.031000        4.2     0.023485      5.50   9692.246662         0.013808    0.816137  631.738963
# 1997        157345     0.024262        3.4     0.034429      5.10   9903.654147         0.068546    0.838724  597.750806
# 1998        166949     0.030077        3.5     0.035846      6.00  10643.771152         0.070491    0.834974  567.238215
# 1999        179848     0.026010        3.0     0.032039      7.00  11514.126175         0.173607    0.861634  625.061382
# 2000        195300     0.024978        2.7     0.011304      3.60  11250.274146         0.205453    0.867967  715.155339
# 2001        201831     0.101212        3.8     0.043452      5.37  11933.657567         0.370139    0.904867  760.298866
# 2002        204515    -0.007132        5.7     0.044069      6.48  11608.966914         0.000000    0.897976  791.154290
# 2003        205386     0.039080        6.1     0.041352      8.19  10621.392715         0.000000    0.921031  861.171666
# 2004        209357     0.026325        5.6     0.032149      9.49  10670.931488         0.000000    0.939562  801.900703
# 2005        217329     0.014359        5.1     0.034475     10.15  11283.720872         0.000000    0.949306  725.976340
# 2006        223154     0.028956        4.3     0.031200      9.78  11825.224451         0.000000    0.968962  736.563442
# 2007        228087     0.024332        3.8     0.020243      9.61  13942.315868         0.000000    0.894784  721.314030
# 2008        230987     0.022149        4.8     0.014113      8.52  13068.685856         0.000000    0.877467  778.398709
# 2009        225984     0.023864        8.1     0.005879      6.60  12042.226241         0.000000    0.773660  960.486903

# %% [markdown]
# Now we can define our model inputs and run our fixed effect model.

# %%
#Define dependents
ypan_rev=TEL_panel.ix[:,:,'pcrev']
ypan_econ=TEL_panel.ix[:,:,'pcap']

#Define independents
Xpan_rev=TEL_panel.ix[:,:,X_rev].swapaxes('items','minor')
Xpan_econ=TEL_panel.ix[:,:,X_econ].swapaxes('items','minor')

#Run models
fe_rev=pd.ols(y=ypan_rev,x=Xpan_rev,entity_effects=True)
fe_econ=pd.ols(y=ypan_econ,x=Xpan_econ,entity_effects=True)

#Capture results
fe_rev_res=fe_rev.summary_as_matrix.T
fe_econ_res=fe_econ.summary_as_matrix.T

#Capture mode fit
fe_rev_res['rsq']=fe_rev.r2
fe_econ_res['rsq']=fe_econ.r2

print fe_rev_res.head(8).to_latex()
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &         beta &       p-value &     std err &    t-stat &       rsq \\
# \midrule
# gsp             &     0.001062 &  3.112123e-05 &    0.000254 &  4.184171 &  0.922816 \\
# lpop\_growth     &  -151.486290 &  5.409105e-01 &  247.670040 & -0.611646 &  0.922816 \\
# st\_unempr       &    32.103323 &  3.194432e-07 &    6.238182 &  5.146262 &  0.922816 \\
# permit\_rate     &  1883.634246 &  1.177657e-02 &  746.474307 &  2.523375 &  0.922816 \\
# vac\_rate        &     6.791988 &  5.783343e-03 &    2.455758 &  2.765740 &  0.922816 \\
# pcap            &     0.039629 &  6.413903e-17 &    0.004659 &  8.506713 &  0.922816 \\
# intensity\_stock &  -102.841065 &  1.580228e-02 &   42.539371 & -2.417550 &  0.922816 \\
# prop\_ratio      &  -167.068602 &  2.137383e-02 &   72.483436 & -2.304921 &  0.922816 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Let's write these guys to disk.

# %%
fe_rev_res.to_csv(workdir+'fe_rev_results.csv')
fe_econ_res.to_csv(workdir+'fe_econ_results.csv')

# %%
#Grab residuals
rev_resid=DataFrame(fe_rev.resid.stack()).rename(columns={0:'resid'})
econ_resid=DataFrame(fe_econ.resid.stack()).rename(columns={0:'resid'})

#Grab observations
rev_obs=DataFrame(ypan_rev.stack()).rename(columns={0:'obs'})
econ_obs=DataFrame(ypan_econ.stack()).rename(columns={0:'obs'})

#Sync index level names
for df in [rev_obs,rev_resid,econ_obs,econ_resid]:
    df.index.names=['AUDIT_YEAR','CTY']

#Join residuals and observations
rev_resVobs_temp=rev_obs.join(rev_resid)
econ_resVobs_temp=econ_obs.join(econ_resid)

#Discard missing values
rev_resVobs=rev_resVobs_temp[pd.notnull(rev_resVobs_temp).all(axis=1)]
econ_resVobs=econ_resVobs_temp[pd.notnull(econ_resVobs_temp).all(axis=1)]

#Generate scatters
sb.lmplot('obs','resid',rev_resVobs)
sb.lmplot('obs','resid',econ_resVobs)

# %%
qqplot(rev_resid,line='q')

# %% [markdown]
# While the residual plots could certainly be worse, there is a certain non-linearity to them.  Let's see what taking the log of the dependents does for us.

# %%
#Define dependents
ypan_lrev=np.log(TEL_panel.ix[:,:,'pcrev'])
ypan_lecon=np.log(TEL_panel.ix[:,:,'pcap']).fillna(np.log(TEL_panel.ix[:,:,'pcap']).mean())

#Run models
fe_lrev=pd.ols(y=ypan_lrev,x=Xpan_rev,entity_effects=True)
fe_lecon=pd.ols(y=ypan_lecon,x=Xpan_econ,entity_effects=True)

#Capture results
fe_lrev_res=fe_lrev.summary_as_matrix.T
fe_lecon_res=fe_lecon.summary_as_matrix.T

#Capture mode fit
fe_lrev_res['rsq']=fe_lrev.r2
fe_lecon_res['rsq']=fe_lecon.r2

#Grab residuals
lrev_resid=DataFrame(fe_lrev.resid.stack()).rename(columns={0:'resid'})
lecon_resid=DataFrame(fe_lecon.resid.stack()).rename(columns={0:'resid'})

#Grab observations
lrev_obs=DataFrame(ypan_lrev.stack()).rename(columns={0:'obs'})
lecon_obs=DataFrame(ypan_lecon.stack()).rename(columns={0:'obs'})

#Sync up index names before join
for df in [lrev_resid,lrev_obs,lecon_resid,lecon_obs]:
    df.index.names=['AUDIT_YEAR','CTY']
    
#Join residuals and observations
lrev_resVobs_temp=lrev_obs.join(lrev_resid)
lecon_resVobs_temp=lecon_obs.join(lecon_resid)

#Discard missing values
lrev_resVobs=lrev_resVobs_temp[pd.notnull(lrev_resVobs_temp).all(axis=1)]
lecon_resVobs=lecon_resVobs_temp[pd.notnull(lecon_resVobs_temp).all(axis=1)]

#Generate scatters
sb.lmplot('obs','resid',lrev_resVobs)
sb.lmplot('obs','resid',lecon_resVobs)

# %%
[x for x in Xpan_econ.items[:2]]
# Out:
# ['gsp', 'lpop_growth']

# %%
print ypan_lrev.shape,ypan_lecon.shape
print ypan_lrev[pd.isnull(ypan_lrev).any(axis=1)]
print ypan_lecon[pd.isnull(ypan_lecon).any(axis=1)]
# Out:
# (17, 64) (17, 64)
# Empty DataFrame
# Columns: [Adams, Alamosa, Arapahoe, Archuleta, Baca, Bent, Boulder, Broomfield, Chaffee, Cheyenne, Clear Creek, Conejos, Costilla, Crowley, Custer, Delta, Denver, Dolores, Douglas, Eagle, El Paso, Elbert, Fremont, Garfield, Gilpin, Grand, Gunnison, Hinsdale, Huerfano, Jackson, Jefferson, Kiowa, Kit Carson, La Plata, Lake, Larimer, Las Animas, Lincoln, Logan, Mesa, Mineral, Moffat, Montezuma, Montrose, Morgan, Otero, Ouray, Park, Phillips, Pitkin, Prowers, Pueblo, Rio Blanco, Rio Grande, Routt, Saguache, San Juan, San Miguel, Sedgwick, Summit, Teller, Washington, Weld, Yuma]
# Index: []
#
# [0 rows x 64 columns]
# Empty DataFrame
# Columns: [Adams, Alamosa, Arapahoe, Archuleta, Baca, Bent, Boulder, Broomfield, Chaffee, Cheyenne, Clear Creek, Conejos, Costilla, Crowley, Custer, Delta, Denver, Dolores, Douglas, Eagle, El Paso, Elbert, Fremont, Garfield, Gilpin, Grand, Gunnison, Hinsdale, Huerfano, Jackson, Jefferson, Kiowa, Kit Carson, La Plata, Lake, Larimer, Las Animas, Lincoln, Logan, Mesa, Mineral, Moffat, Montezuma, Montrose, Morgan, Otero, Ouray, Park, Phillips, Pitkin, Prowers, Pueblo, Rio Blanco, Rio Grande, Routt, Saguache, San Juan, San Miguel, Sedgwick, Summit, Teller, Washington, Weld, Yuma]
# Index: []
#
# [0 rows x 64 columns]

# %% [markdown]
# ### Visualizing Estimation Results

# %% [markdown]
# Visualization of the results was actually performed in a standalone Notebook called *Converge_Viz*.

# %%
#%load_ext rmagic

# %%
pcrev_std=co_TEL95['pcrev'].std()
pcap_std=co_TEL95['pcap'].std()
int_std=co_TEL95['intensity_stock'].std()
prop_std=co_TEL95['prop_ratio'].std()

print pcrev_std,pcap_std,int_std,prop_std
# Out:
# 855.473506519 7453.75133508 0.295698042365 0.444724963409

# %%
print (fe_rev_res.ix['intensity_stock']['beta']/pcrev_std)/(1/int_std)
print (fe_rev_res.ix['prop_ratio']['beta']/pcrev_std)/(1/prop_std)
# Out:
# -0.0355474498543
# -0.086851991726
